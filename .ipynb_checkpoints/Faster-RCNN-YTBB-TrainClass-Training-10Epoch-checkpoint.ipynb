# %% [markdown]
# ## Faster R-CNN Training for YTBB Train Class - using Pretrained ResNet50 and 10 Epochs in Google Colab

# %%
from google.colab import drive

# %%
# !nvidia-smi
# Out:
# Sun Apr 24 11:51:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %%
# %tensorflow_version 2.x

# %%
# !pip install tensorflow==2.0.0
# Out:
# Collecting tensorflow==2.0.0
#   Downloading tensorflow-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (86.3 MB)
#      |████████████████████████████████| 86.3 MB 60 kB/s
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 8.2 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.14.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.8.1)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 97.5 MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.37.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.1.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.15.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.21.6)
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading tensorboard-2.0.2-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 91.0 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.0.0) (1.44.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0.0) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (4.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0.0) (3.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==2.0.0) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=4094f9d9e1658f493786c0312bf3eab6d1e372e56d4a45ad029dfaafbb3712e5
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-2.0.2 tensorflow-2.0.0 tensorflow-estimator-2.0.1

# %%
# !pip install Keras==2.3.1
# Out:
# Collecting Keras==2.3.1
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 14.4 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (3.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (1.21.6)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (1.0.8)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras==2.3.1) (1.4.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->Keras==2.3.1) (1.5.2)
# Installing collected packages: Keras
#   Attempting uninstall: Keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
# Successfully installed Keras-2.3.1

# %%
# !pip install gast==0.3.2
# Out:
# Collecting gast==0.3.2
#   Downloading gast-0.3.2.tar.gz (13 kB)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.3.2-py3-none-any.whl size=9694 sha256=d350a82070f164b1ce78f554fa2f512161267781f8b4193ef0524323a66f9653
#   Stored in directory: /root/.cache/pip/wheels/9b/7b/89/365a82e420c11db9b43d34918045faa8004748a1d97597930d
# Successfully built gast
# Installing collected packages: gast
#   Attempting uninstall: gast
#     Found existing installation: gast 0.2.2
#     Uninstalling gast-0.2.2:
#       Successfully uninstalled gast-0.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.0.0 requires gast==0.2.2, but you have gast 0.3.2 which is incompatible.
# Successfully installed gast-0.3.2

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.21.6)

# %%
# !pip install 'h5py==2.10.0'
# Out:
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 14.4 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
cd '/content/drive/MyDrive/DSA5204/Faster-RCNN'
# Out:
# /content/drive/MyDrive/DSA5204/Faster-RCNN

# %%
pwd
# Out:
# '/content/drive/MyDrive/DSA5204/Faster-RCNN'

# %%
# %run train_faster_rcnn-Y2BB-TRAIN-VEHICLE.ipynb
# Out:
# Streaming output truncated to the last 5000 lines.
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0eWtYZVw73g+00+0014000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 284.16, 'y1': 21.599999999999998, 'y2': 240.0}], 'imageset': 'test'}
# index is 9387
#  824/1000 [=======================>......] - ETA: 8:56 - rpn_cls: 1.0719 - rpn_regr: 0.1104 - detector_cls: 0.2065 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2HY22-cb4-I+00+0003000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 212.64000000000001, 'x2': 367.68, 'y1': 124.19999999999999, 'y2': 208.79999999999998}], 'imageset': 'test'}
# index is 9388
#  825/1000 [=======================>......] - ETA: 8:53 - rpn_cls: 1.0727 - rpn_regr: 0.1103 - detector_cls: 0.2066 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6dnETcotmM+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 399.35999999999996, 'x2': 480.0, 'y1': 34.2, 'y2': 360.0}], 'imageset': 'test'}
# index is 9389
#  826/1000 [=======================>......] - ETA: 8:50 - rpn_cls: 1.0780 - rpn_regr: 0.1102 - detector_cls: 0.2065 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2KGfQgVH85c+00+0046000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 115.52, 'x2': 187.2, 'y1': 99.99999840000001, 'y2': 145.600008}], 'imageset': 'test'}
# index is 9390
#  827/1000 [=======================>......] - ETA: 8:47 - rpn_cls: 1.0767 - rpn_regr: 0.1101 - detector_cls: 0.2065 - detector_regr: 0.1498X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2HaRwvJEOYA+02+0099000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 470.4, 'y1': 130.20000480000002, 'y2': 285.600006}], 'imageset': 'test'}
# index is 9391
#  828/1000 [=======================>......] - ETA: 8:44 - rpn_cls: 1.0820 - rpn_regr: 0.1100 - detector_cls: 0.2064 - detector_regr: 0.1498X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1wXL_g0Nl8Q+01+0051000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 19.2000006, 'y2': 360.0}], 'imageset': 'test'}
# index is 9392
#  829/1000 [=======================>......] - ETA: 8:41 - rpn_cls: 1.0807 - rpn_regr: 0.1100 - detector_cls: 0.2067 - detector_regr: 0.1497X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0mJwl9SmdVU+00+0021000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 11.52, 'x2': 320.0, 'y1': 52.8, 'y2': 186.799992}], 'imageset': 'test'}
# index is 9393
#  830/1000 [=======================>......] - ETA: 8:38 - rpn_cls: 1.0794 - rpn_regr: 0.1102 - detector_cls: 0.2070 - detector_regr: 0.1497X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+27aLyuHW_Rc+00+0026000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 24.4000008, 'y2': 239.5999992}], 'imageset': 'test'}
# index is 9394
#  831/1000 [=======================>......] - ETA: 8:35 - rpn_cls: 1.0847 - rpn_regr: 0.1102 - detector_cls: 0.2068 - detector_regr: 0.1496X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3HRw4jH7bSo+00+0015000+1.jpg', 'width': 640, 'height': 352, 'bboxes': [{'class': 'train', 'x1': 190.72, 'x2': 512.64, 'y1': 0.0, 'y2': 184.8}], 'imageset': 'test'}
# index is 9395
#  832/1000 [=======================>......] - ETA: 8:32 - rpn_cls: 1.0834 - rpn_regr: 0.1103 - detector_cls: 0.2071 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+08krZG0GN_8+01+0032000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 16.80000012, 'y2': 288.600012}], 'imageset': 'test'}
# index is 9396
#  833/1000 [=======================>......] - ETA: 8:29 - rpn_cls: 1.0821 - rpn_regr: 0.1102 - detector_cls: 0.2070 - detector_regr: 0.1506X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2i-EkPpOcgI+01+0055000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 96.60000600000001, 'y2': 317.3999976}], 'imageset': 'test'}
# index is 9397
#  834/1000 [========================>.....] - ETA: 8:26 - rpn_cls: 1.0808 - rpn_regr: 0.1106 - detector_cls: 0.2069 - detector_regr: 0.1506X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+05+0342000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 72.96, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9398
#  835/1000 [========================>.....] - ETA: 8:23 - rpn_cls: 1.0795 - rpn_regr: 0.1105 - detector_cls: 0.2067 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2E4Fp_kREe8+02+0192000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 428.64, 'y1': 100.80000000000001, 'y2': 179.39999880000002}], 'imageset': 'test'}
# index is 9399
#  836/1000 [========================>.....] - ETA: 8:20 - rpn_cls: 1.0782 - rpn_regr: 0.1106 - detector_cls: 0.2066 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1PG0dZgOUNk+00+0015000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 166.80000239999998, 'y2': 328.200012}], 'imageset': 'test'}
# index is 9400
#  837/1000 [========================>.....] - ETA: 8:17 - rpn_cls: 1.0769 - rpn_regr: 0.1107 - detector_cls: 0.2066 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0T75sYwrYa4+00+0032000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 106.56, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9401
#  838/1000 [========================>.....] - ETA: 8:14 - rpn_cls: 1.0756 - rpn_regr: 0.1106 - detector_cls: 0.2066 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-8ksJIqOgcA+00+0010000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 56.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9402
#  839/1000 [========================>.....] - ETA: 8:10 - rpn_cls: 1.0743 - rpn_regr: 0.1105 - detector_cls: 0.2068 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1tfRBloApqQ+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 31.68, 'x2': 320.0, 'y1': 88.4000016, 'y2': 194.4}], 'imageset': 'test'}
# index is 9403
#  840/1000 [========================>.....] - ETA: 8:07 - rpn_cls: 1.0731 - rpn_regr: 0.1105 - detector_cls: 0.2067 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-8ksJIqOgcA+00+0005000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 57.599999999999994, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9404
#  841/1000 [========================>.....] - ETA: 8:04 - rpn_cls: 1.0718 - rpn_regr: 0.1104 - detector_cls: 0.2066 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-5fitGNDJE8+02+0460000+0.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 9405
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0cHCONFAcRY+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.48, 'x2': 226.56, 'y1': 7.79999976, 'y2': 269.3999988}], 'imageset': 'test'}
# index is 9406
#  842/1000 [========================>.....] - ETA: 8:01 - rpn_cls: 1.0705 - rpn_regr: 0.1108 - detector_cls: 0.2066 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-GHxhfOfLKI+00+0016000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 266.24, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9407
#  843/1000 [========================>.....] - ETA: 7:58 - rpn_cls: 1.0692 - rpn_regr: 0.1107 - detector_cls: 0.2065 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1XKoeALBxt0+00+0039000+0.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 9408
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+07yqmNxwcYQ+00+0029000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 9.12, 'x2': 478.56, 'y1': 27.6000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 9409
#  844/1000 [========================>.....] - ETA: 7:56 - rpn_cls: 1.0680 - rpn_regr: 0.1106 - detector_cls: 0.2068 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+10+0574000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 197.28, 'x2': 348.0, 'y1': 137.3999976, 'y2': 226.1999988}], 'imageset': 'test'}
# index is 9410
#  845/1000 [========================>.....] - ETA: 7:52 - rpn_cls: 1.0686 - rpn_regr: 0.1106 - detector_cls: 0.2069 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3T1_hat2TUg+03+0231000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9411
#  846/1000 [========================>.....] - ETA: 7:49 - rpn_cls: 1.0738 - rpn_regr: 0.1106 - detector_cls: 0.2067 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-m6OhoJ4Q48+01+0043000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 439.20000000000005, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9412
#  847/1000 [========================>.....] - ETA: 7:46 - rpn_cls: 1.0725 - rpn_regr: 0.1105 - detector_cls: 0.2069 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3cXVQvGU8O8+00+0052000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.48, 'x2': 329.28000000000003, 'y1': 83.9999988, 'y2': 229.19999760000002}], 'imageset': 'test'}
# index is 9413
#  848/1000 [========================>.....] - ETA: 7:43 - rpn_cls: 1.0721 - rpn_regr: 0.1106 - detector_cls: 0.2069 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1Fmwh4rPvrA+00+0015000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 453.59999999999997, 'y1': 0.0, 'y2': 230.99999400000002}], 'imageset': 'test'}
# index is 9414
#  849/1000 [========================>.....] - ETA: 7:40 - rpn_cls: 1.0773 - rpn_regr: 0.1106 - detector_cls: 0.2069 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1JwmhncD4o4+00+0575000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 52.480000000000004, 'x2': 320.0, 'y1': 3.5999999999999996, 'y2': 199.59999599999998}], 'imageset': 'test'}
# index is 9415
#  850/1000 [========================>.....] - ETA: 7:37 - rpn_cls: 1.0760 - rpn_regr: 0.1106 - detector_cls: 0.2072 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-5fitGNDJE8+02+0453000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 120.0, 'y1': 46.399999199999996, 'y2': 115.9999968}], 'imageset': 'test'}
# index is 9416
#  851/1000 [========================>.....] - ETA: 7:34 - rpn_cls: 1.0812 - rpn_regr: 0.1106 - detector_cls: 0.2076 - detector_regr: 0.1507X is (1, 416, 508, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0n-lMeS_2fw+03+0174000+1.jpg', 'width': 352, 'height': 288, 'bboxes': [{'class': 'train', 'x1': 44.0, 'x2': 299.552, 'y1': 113.2800048, 'y2': 150.2399952}], 'imageset': 'test'}
# index is 9417
#  852/1000 [========================>.....] - ETA: 7:31 - rpn_cls: 1.0800 - rpn_regr: 0.1112 - detector_cls: 0.2074 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+00+0001000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 117.12, 'x2': 169.92, 'y1': 96.60000600000001, 'y2': 171.5999976}], 'imageset': 'test'}
# index is 9418
#  853/1000 [========================>.....] - ETA: 7:28 - rpn_cls: 1.0787 - rpn_regr: 0.1113 - detector_cls: 0.2075 - detector_regr: 0.1507X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+16EEcm5Ra_w+03+0336000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 235.8, 'y2': 279.0}], 'imageset': 'test'}
# index is 9419
#  854/1000 [========================>.....] - ETA: 7:25 - rpn_cls: 1.0775 - rpn_regr: 0.1125 - detector_cls: 0.2072 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-KHjb74Z5MY+00+0155000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 236.64, 'y1': 0.0, 'y2': 330.600006}], 'imageset': 'test'}
# index is 9420
#  855/1000 [========================>.....] - ETA: 7:22 - rpn_cls: 1.0827 - rpn_regr: 0.1127 - detector_cls: 0.2071 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2M1vWgwLuio+00+0002000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 37.120000000000005, 'x2': 320.0, 'y1': 61.999999200000005, 'y2': 136.399992}], 'imageset': 'test'}
# index is 9421
#  856/1000 [========================>.....] - ETA: 7:19 - rpn_cls: 1.0814 - rpn_regr: 0.1126 - detector_cls: 0.2070 - detector_regr: 0.1505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2UkWpZ_mzk4+00+0290000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 246.72, 'x2': 320.0, 'y1': 108.800004, 'y2': 172.79999999999998}], 'imageset': 'test'}
# index is 9422
#  857/1000 [========================>.....] - ETA: 7:16 - rpn_cls: 1.0913 - rpn_regr: 0.1125 - detector_cls: 0.2068 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2vpjj5R3Y9k+00+0029000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 1.60000008, 'y2': 182.79999840000002}], 'imageset': 'test'}
# index is 9423
#  858/1000 [========================>.....] - ETA: 7:12 - rpn_cls: 1.0900 - rpn_regr: 0.1125 - detector_cls: 0.2068 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-yKRVlWlbPc+00+0013000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 60.96, 'x2': 428.16, 'y1': 81.0, 'y2': 306.0}], 'imageset': 'test'}
# index is 9424
#  859/1000 [========================>.....] - ETA: 7:09 - rpn_cls: 1.0887 - rpn_regr: 0.1126 - detector_cls: 0.2068 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-sX1J_IwZrk+00+0030000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 197.28, 'x2': 480.0, 'y1': 20.400001200000002, 'y2': 303.599988}], 'imageset': 'test'}
# index is 9425
#  860/1000 [========================>.....] - ETA: 7:06 - rpn_cls: 1.0875 - rpn_regr: 0.1124 - detector_cls: 0.2068 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1yhbvw1c9tk+00+0027000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 473.28, 'y1': 0.0, 'y2': 221.4}], 'imageset': 'test'}
# index is 9426
#  861/1000 [========================>.....] - ETA: 7:03 - rpn_cls: 1.0862 - rpn_regr: 0.1124 - detector_cls: 0.2069 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-inbWsZ-4Ok+00+0106000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 185.92, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9427
#  862/1000 [========================>.....] - ETA: 7:00 - rpn_cls: 1.0850 - rpn_regr: 0.1124 - detector_cls: 0.2069 - detector_regr: 0.1502X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3TnNb5Oc--8+11+0047000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 273.59999999999997, 'y1': 24.600000599999998, 'y2': 269.3999988}], 'imageset': 'test'}
# index is 9428
#  863/1000 [========================>.....] - ETA: 6:57 - rpn_cls: 1.0837 - rpn_regr: 0.1124 - detector_cls: 0.2068 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+00iw45dQOBA+00+0001000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 142.72, 'x2': 173.12, 'y1': 89.2000008, 'y2': 116.8000032}], 'imageset': 'test'}
# index is 9429
#  864/1000 [========================>.....] - ETA: 6:54 - rpn_cls: 1.0826 - rpn_regr: 0.1125 - detector_cls: 0.2068 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2WVVqOkIHoA+00+0011000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 78.5999988, 'y2': 223.8000012}], 'imageset': 'test'}
# index is 9430
#  865/1000 [========================>.....] - ETA: 6:51 - rpn_cls: 1.0813 - rpn_regr: 0.1125 - detector_cls: 0.2069 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3P_b80TKV_0+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 84.6, 'y2': 236.400012}], 'imageset': 'test'}
# index is 9431
#  866/1000 [========================>.....] - ETA: 6:48 - rpn_cls: 1.0801 - rpn_regr: 0.1126 - detector_cls: 0.2068 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1YNLJVdH2f0+00+0034000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 454.56, 'y1': 121.2000012, 'y2': 344.399994}], 'imageset': 'test'}
# index is 9432
#  867/1000 [=========================>....] - ETA: 6:45 - rpn_cls: 1.0851 - rpn_regr: 0.1125 - detector_cls: 0.2070 - detector_regr: 0.1502X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2EU0pbb9rNE+02+0074000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 3.2, 'x2': 634.24, 'y1': 0.0, 'y2': 316.1999988}], 'imageset': 'test'}
# index is 9433
#  868/1000 [=========================>....] - ETA: 6:42 - rpn_cls: 1.0858 - rpn_regr: 0.1124 - detector_cls: 0.2070 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0WFLndoovjY+01+0079000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 5.76, 'x2': 433.44, 'y1': 113.9999976, 'y2': 217.79999999999998}], 'imageset': 'test'}
# index is 9434
#  869/1000 [=========================>....] - ETA: 6:39 - rpn_cls: 1.0846 - rpn_regr: 0.1124 - detector_cls: 0.2069 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2yQ7ehuGTRI+00+0021000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 412.32, 'y1': 60.00000119999999, 'y2': 239.4}], 'imageset': 'test'}
# index is 9435
#  870/1000 [=========================>....] - ETA: 6:36 - rpn_cls: 1.0896 - rpn_regr: 0.1123 - detector_cls: 0.2069 - detector_regr: 0.1504X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1gXCV_X8Hw8+00+0008000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 85.1999976, 'y2': 261.600012}], 'imageset': 'test'}
# index is 9436
#  871/1000 [=========================>....] - ETA: 6:33 - rpn_cls: 1.0884 - rpn_regr: 0.1123 - detector_cls: 0.2068 - detector_regr: 0.1503X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-025GNtJ0oI+01+0121000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9437
#  872/1000 [=========================>....] - ETA: 6:30 - rpn_cls: 1.0934 - rpn_regr: 0.1122 - detector_cls: 0.2068 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3eMI4LQcnwc+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 36.160000000000004, 'x2': 310.4, 'y1': 19.5999984, 'y2': 235.2}], 'imageset': 'test'}
# index is 9438
#  873/1000 [=========================>....] - ETA: 6:27 - rpn_cls: 1.0921 - rpn_regr: 0.1121 - detector_cls: 0.2067 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2i-EkPpOcgI+01+0054000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 108.60000480000001, 'y2': 331.2}], 'imageset': 'test'}
# index is 9439
#  874/1000 [=========================>....] - ETA: 6:24 - rpn_cls: 1.0909 - rpn_regr: 0.1122 - detector_cls: 0.2066 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0hxGNJtSd80+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 304.96, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9440
#  875/1000 [=========================>....] - ETA: 6:20 - rpn_cls: 1.0896 - rpn_regr: 0.1121 - detector_cls: 0.2065 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1n-UGX-YDhQ+00+0019000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9441
#  876/1000 [=========================>....] - ETA: 6:17 - rpn_cls: 1.0884 - rpn_regr: 0.1121 - detector_cls: 0.2064 - detector_regr: 0.1501X is (1, 416, 508, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ES52c2xLAc+00+0028000+1.jpg', 'width': 352, 'height': 288, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 302.016, 'y1': 0.0, 'y2': 271.6799904}], 'imageset': 'test'}
# index is 9442
#  877/1000 [=========================>....] - ETA: 6:14 - rpn_cls: 1.0872 - rpn_regr: 0.1120 - detector_cls: 0.2064 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6dnETcotmM+00+0014000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 464.64, 'x2': 480.0, 'y1': 16.80000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 9443
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3X68YQk3WpE+02+0102000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 7.68, 'x2': 478.08, 'y1': 72.0, 'y2': 320.4}], 'imageset': 'test'}
# index is 9444
#  878/1000 [=========================>....] - ETA: 6:11 - rpn_cls: 1.0859 - rpn_regr: 0.1119 - detector_cls: 0.2066 - detector_regr: 0.1500X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2StaMMCS-_o+00+0058000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 361.44, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9445
#  879/1000 [=========================>....] - ETA: 6:08 - rpn_cls: 1.0847 - rpn_regr: 0.1118 - detector_cls: 0.2067 - detector_regr: 0.1499X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0oGiHVOz6iY+01+0059000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 142.72, 'x2': 636.16, 'y1': 76.8000024, 'y2': 271.8}], 'imageset': 'test'}
# index is 9446
#  880/1000 [=========================>....] - ETA: 6:05 - rpn_cls: 1.0835 - rpn_regr: 0.1117 - detector_cls: 0.2067 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2_m7hmhS_24+00+0003000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 277.12, 'y1': 0.0, 'y2': 234.400008}], 'imageset': 'test'}
# index is 9447
#  881/1000 [=========================>....] - ETA: 6:02 - rpn_cls: 1.0822 - rpn_regr: 0.1116 - detector_cls: 0.2066 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+20oU8hAH-nI+00+0058000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 147.20000000000002, 'x2': 265.28, 'y1': 83.1999984, 'y2': 180.0}], 'imageset': 'test'}
# index is 9448
#  882/1000 [=========================>....] - ETA: 5:59 - rpn_cls: 1.0810 - rpn_regr: 0.1119 - detector_cls: 0.2068 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1xCOs0GXXpE+00+0018000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 106.24000000000001, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9449
#  883/1000 [=========================>....] - ETA: 5:56 - rpn_cls: 1.0798 - rpn_regr: 0.1119 - detector_cls: 0.2067 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0wKnBd4z0XA+00+0301000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 9450
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1J0QWMbFz5c+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 72.0, 'x2': 351.36, 'y1': 82.8, 'y2': 336.6}], 'imageset': 'test'}
# index is 9451
#  884/1000 [=========================>....] - ETA: 5:53 - rpn_cls: 1.0785 - rpn_regr: 0.1118 - detector_cls: 0.2067 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2XFyqFBGT3I+00+0002000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 30.7999992, 'y2': 168.399996}], 'imageset': 'test'}
# index is 9452
#  885/1000 [=========================>....] - ETA: 5:50 - rpn_cls: 1.0773 - rpn_regr: 0.1118 - detector_cls: 0.2067 - detector_regr: 0.1500X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+070CuYCc2Xw+01+0120000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 137.92, 'x2': 162.24, 'y1': 113.1999984, 'y2': 140.39999999999998}], 'imageset': 'test'}
# index is 9453
#  886/1000 [=========================>....] - ETA: 5:47 - rpn_cls: 1.0761 - rpn_regr: 0.1122 - detector_cls: 0.2066 - detector_regr: 0.1502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3XM9XQ5aH7g+00+0023000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 267.84, 'y1': 26.79999936, 'y2': 240.0}], 'imageset': 'test'}
# index is 9454
#  887/1000 [=========================>....] - ETA: 5:44 - rpn_cls: 1.0749 - rpn_regr: 0.1121 - detector_cls: 0.2064 - detector_regr: 0.1501X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2yjE_MQbSxk+00+0112000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9455
#  888/1000 [=========================>....] - ETA: 5:41 - rpn_cls: 1.0737 - rpn_regr: 0.1123 - detector_cls: 0.2064 - detector_regr: 0.1500X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3MKBLFFsqHw+01+0095000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9456
#  889/1000 [=========================>....] - ETA: 5:38 - rpn_cls: 1.0725 - rpn_regr: 0.1122 - detector_cls: 0.2063 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1tvjAf_uoiQ+00+0014000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 391.67999999999995, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9457
#  890/1000 [=========================>....] - ETA: 5:35 - rpn_cls: 1.0713 - rpn_regr: 0.1121 - detector_cls: 0.2062 - detector_regr: 0.1498X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3n21aKPvJ34+00+0059000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 99.83999999999999, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9458
#  891/1000 [=========================>....] - ETA: 5:32 - rpn_cls: 1.0701 - rpn_regr: 0.1120 - detector_cls: 0.2061 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-yMI3k70zIU+00+0017000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 267.84000000000003, 'x2': 344.15999999999997, 'y1': 106.19999999999999, 'y2': 146.9999988}], 'imageset': 'test'}
# index is 9459
#  892/1000 [=========================>....] - ETA: 5:29 - rpn_cls: 1.0689 - rpn_regr: 0.1122 - detector_cls: 0.2059 - detector_regr: 0.1498X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-pxMo4EHSYY+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.48, 'x2': 480.0, 'y1': 25.7999994, 'y2': 273.6}], 'imageset': 'test'}
# index is 9460
#  893/1000 [=========================>....] - ETA: 5:26 - rpn_cls: 1.0677 - rpn_regr: 0.1122 - detector_cls: 0.2060 - detector_regr: 0.1498X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2wT-x0YyivY+02+0591000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 175.36, 'y1': 78.5999988, 'y2': 177.00000119999999}], 'imageset': 'test'}
# index is 9461
#  894/1000 [=========================>....] - ETA: 5:23 - rpn_cls: 1.0665 - rpn_regr: 0.1122 - detector_cls: 0.2062 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+235NI9CNNYs+02+0090000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 269.12, 'y1': 71.600004, 'y2': 191.600004}], 'imageset': 'test'}
# index is 9462
#  895/1000 [=========================>....] - ETA: 5:20 - rpn_cls: 1.0653 - rpn_regr: 0.1121 - detector_cls: 0.2062 - detector_regr: 0.1499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-KHjb74Z5MY+00+0156000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 288.96, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9463
#  896/1000 [=========================>....] - ETA: 5:17 - rpn_cls: 1.0641 - rpn_regr: 0.1120 - detector_cls: 0.2061 - detector_regr: 0.1498X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+003f2isklHU+02+0065000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 170.24, 'x2': 1280.0, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 9464
#  897/1000 [=========================>....] - ETA: 5:14 - rpn_cls: 1.0667 - rpn_regr: 0.1119 - detector_cls: 0.2062 - detector_regr: 0.1498X is (1, 416, 747, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+081HkwJAjTc+00+0015000+1.jpg', 'width': 640, 'height': 356, 'bboxes': [{'class': 'train', 'x1': 263.03999999999996, 'x2': 567.04, 'y1': 93.15333096, 'y2': 356.0}], 'imageset': 'test'}
# index is 9465
#  898/1000 [=========================>....] - ETA: 5:11 - rpn_cls: 1.0656 - rpn_regr: 0.1118 - detector_cls: 0.2061 - detector_regr: 0.1497X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0POyH7D2a_U+00+0028000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 1280.0, 'y1': 373.199976, 'y2': 509.99997600000006}], 'imageset': 'test'}
# index is 9466
#  899/1000 [=========================>....] - ETA: 5:08 - rpn_cls: 1.0644 - rpn_regr: 0.1125 - detector_cls: 0.2060 - detector_regr: 0.1496X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1Vq6Nf47BoM+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 115.19999999999999, 'x2': 480.0, 'y1': 92.39999759999999, 'y2': 292.79999879999997}], 'imageset': 'test'}
# index is 9467
#  900/1000 [==========================>...] - ETA: 5:05 - rpn_cls: 1.0632 - rpn_regr: 0.1124 - detector_cls: 0.2060 - detector_regr: 0.1496X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3bIcostmWR0+01+0042000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 276.47999999999996, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9468
#  901/1000 [==========================>...] - ETA: 5:02 - rpn_cls: 1.0621 - rpn_regr: 0.1123 - detector_cls: 0.2059 - detector_regr: 0.1495X is (1, 416, 558, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-bOySjRdVIw+01+0286000+1.jpg', 'width': 352, 'height': 262, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 238.30400000000003, 'y1': 76.85332984, 'y2': 168.99}], 'imageset': 'test'}
# index is 9469
#  902/1000 [==========================>...] - ETA: 4:58 - rpn_cls: 1.0629 - rpn_regr: 0.1123 - detector_cls: 0.2058 - detector_regr: 0.1494X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2i2R4fS-jQ4+00+0065000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 413.44, 'x2': 1280.0, 'y1': 242.4000024, 'y2': 720.0}], 'imageset': 'test'}
# index is 9470
#  903/1000 [==========================>...] - ETA: 4:55 - rpn_cls: 1.0618 - rpn_regr: 0.1122 - detector_cls: 0.2061 - detector_regr: 0.1494X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1oPpuE7-y70+00+0217000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 124.32000000000001, 'x2': 207.84, 'y1': 174.6, 'y2': 242.40000600000002}], 'imageset': 'test'}
# index is 9471
#  904/1000 [==========================>...] - ETA: 4:52 - rpn_cls: 1.0606 - rpn_regr: 0.1121 - detector_cls: 0.2060 - detector_regr: 0.1494X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+16EEcm5Ra_w+00+0142000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 64.1999988, 'y2': 290.400012}], 'imageset': 'test'}
# index is 9472
#  905/1000 [==========================>...] - ETA: 4:49 - rpn_cls: 1.0594 - rpn_regr: 0.1120 - detector_cls: 0.2060 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0G9gcbaLaHo+00+0015000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 337.91999999999996, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9473
#  906/1000 [==========================>...] - ETA: 4:46 - rpn_cls: 1.0582 - rpn_regr: 0.1119 - detector_cls: 0.2059 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1_VPW-l4DIg+00+0023000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 7.599999840000001, 'y2': 105.19999920000001}], 'imageset': 'test'}
# index is 9474
#  907/1000 [==========================>...] - ETA: 4:43 - rpn_cls: 1.0571 - rpn_regr: 0.1119 - detector_cls: 0.2058 - detector_regr: 0.1492X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3jLlEtkqh7k+00+0030000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 76.8, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9475
#  908/1000 [==========================>...] - ETA: 4:40 - rpn_cls: 1.0619 - rpn_regr: 0.1118 - detector_cls: 0.2057 - detector_regr: 0.1491X is (1, 416, 558, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-bOySjRdVIw+03+0063000+1.jpg', 'width': 352, 'height': 262, 'bboxes': [{'class': 'train', 'x1': 44.352000000000004, 'x2': 326.30400000000003, 'y1': 1.31, 'y2': 262.0}], 'imageset': 'test'}
# index is 9476
#  909/1000 [==========================>...] - ETA: 4:37 - rpn_cls: 1.0608 - rpn_regr: 0.1117 - detector_cls: 0.2061 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3lF47TszHME+00+0006000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 24.32, 'y1': 34.3999992, 'y2': 240.0}], 'imageset': 'test'}
# index is 9477
#  910/1000 [==========================>...] - ETA: 4:34 - rpn_cls: 1.0656 - rpn_regr: 0.1119 - detector_cls: 0.2060 - detector_regr: 0.1490X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+16Vqpbyic-Q+00+0054000+1.jpg', 'width': 636, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 636.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9478
#  911/1000 [==========================>...] - ETA: 4:31 - rpn_cls: 1.0644 - rpn_regr: 0.1119 - detector_cls: 0.2060 - detector_regr: 0.1492X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2v46KrrrTyw+00+0118000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 130.56, 'x2': 480.0, 'y1': 0.0, 'y2': 264.6}], 'imageset': 'test'}
# index is 9479
#  912/1000 [==========================>...] - ETA: 4:28 - rpn_cls: 1.0632 - rpn_regr: 0.1119 - detector_cls: 0.2060 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-TUi3G1xzOA+00+0005000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 41.92, 'x2': 272.0, 'y1': 28.0000008, 'y2': 240.0}], 'imageset': 'test'}
# index is 9480
#  913/1000 [==========================>...] - ETA: 4:25 - rpn_cls: 1.0621 - rpn_regr: 0.1118 - detector_cls: 0.2061 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2Oau4Ai7QJc+00+0006000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 56.64, 'x2': 139.2, 'y1': 103.7999988, 'y2': 145.8}], 'imageset': 'test'}
# index is 9481
#  914/1000 [==========================>...] - ETA: 4:22 - rpn_cls: 1.0609 - rpn_regr: 0.1119 - detector_cls: 0.2062 - detector_regr: 0.1492X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2xyQ0CVtHoY+00+0006000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 447.36, 'y1': 109.8, 'y2': 360.0}], 'imageset': 'test'}
# index is 9482
#  915/1000 [==========================>...] - ETA: 4:19 - rpn_cls: 1.0598 - rpn_regr: 0.1118 - detector_cls: 0.2061 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2BtG8h1du8g+00+0108000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 101.4000012, 'y2': 255.6}], 'imageset': 'test'}
# index is 9483
#  916/1000 [==========================>...] - ETA: 4:16 - rpn_cls: 1.0646 - rpn_regr: 0.1118 - detector_cls: 0.2060 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0gnxsCO6CQc+00+0010000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9484
#  917/1000 [==========================>...] - ETA: 4:13 - rpn_cls: 1.0634 - rpn_regr: 0.1117 - detector_cls: 0.2059 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+06zKJASmKOU+00+0113000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9485
#  918/1000 [==========================>...] - ETA: 4:10 - rpn_cls: 1.0623 - rpn_regr: 0.1116 - detector_cls: 0.2060 - detector_regr: 0.1492X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0H0KOZqKZUI+00+0012000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 199.2, 'x2': 480.0, 'y1': 127.8, 'y2': 305.40000960000003}], 'imageset': 'test'}
# index is 9486
#  919/1000 [==========================>...] - ETA: 4:06 - rpn_cls: 1.0611 - rpn_regr: 0.1116 - detector_cls: 0.2061 - detector_regr: 0.1491X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0z0foP92nsA+00+0014000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 130.56, 'x2': 228.16, 'y1': 48.4000008, 'y2': 85.59999599999999}], 'imageset': 'test'}
# index is 9487
#  920/1000 [==========================>...] - ETA: 4:03 - rpn_cls: 1.0600 - rpn_regr: 0.1115 - detector_cls: 0.2063 - detector_regr: 0.1494X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+34vwg15erxM+04+0736000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 19.68, 'x2': 480.0, 'y1': 132.6000024, 'y2': 293.9999976}], 'imageset': 'test'}
# index is 9488
#  921/1000 [==========================>...] - ETA: 4:00 - rpn_cls: 1.0588 - rpn_regr: 0.1115 - detector_cls: 0.2061 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+05X3-EAJ99s+00+0013000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 297.28000000000003, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9489
#  922/1000 [==========================>...] - ETA: 3:57 - rpn_cls: 1.0577 - rpn_regr: 0.1114 - detector_cls: 0.2061 - detector_regr: 0.1494X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2UkWpZ_mzk4+00+0288000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 96.8000016, 'y2': 188.4}], 'imageset': 'test'}
# index is 9490
#  923/1000 [==========================>...] - ETA: 3:54 - rpn_cls: 1.0566 - rpn_regr: 0.1114 - detector_cls: 0.2061 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3KAYuc9_2Vc+01+0081000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 345.59999999999997, 'y1': 79.2, 'y2': 355.200012}], 'imageset': 'test'}
# index is 9491
#  924/1000 [==========================>...] - ETA: 3:51 - rpn_cls: 1.0554 - rpn_regr: 0.1114 - detector_cls: 0.2061 - detector_regr: 0.1492X is (1, 416, 558, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-bOySjRdVIw+03+0067000+1.jpg', 'width': 352, 'height': 262, 'bboxes': [{'class': 'train', 'x1': 28.512, 'x2': 272.096, 'y1': 1.746666754, 'y2': 262.0}], 'imageset': 'test'}
# index is 9492
#  925/1000 [==========================>...] - ETA: 3:48 - rpn_cls: 1.0543 - rpn_regr: 0.1115 - detector_cls: 0.2062 - detector_regr: 0.1492X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3oFYQY3IG-0+00+0008000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 84.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9493
#  926/1000 [==========================>...] - ETA: 3:45 - rpn_cls: 1.0531 - rpn_regr: 0.1114 - detector_cls: 0.2062 - detector_regr: 0.1491X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+28Dnk8Xy8qs+00+0004000+1.jpg', 'width': 480, 'height': 270, 'bboxes': [{'class': 'train', 'x1': 68.16, 'x2': 480.0, 'y1': 58.9499991, 'y2': 258.749991}], 'imageset': 'test'}
# index is 9494
#  927/1000 [==========================>...] - ETA: 3:42 - rpn_cls: 1.0520 - rpn_regr: 0.1113 - detector_cls: 0.2065 - detector_regr: 0.1492X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZY4b_yyA1c+01+0214000+0.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 9495
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-Yydiyn2DAs+00+0005000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 306.24, 'x2': 480.0, 'y1': 24.0000012, 'y2': 319.1999976}], 'imageset': 'test'}
# index is 9496
#  928/1000 [==========================>...] - ETA: 3:39 - rpn_cls: 1.0520 - rpn_regr: 0.1112 - detector_cls: 0.2066 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2RPLt0vxnvc+00+0013000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 33.120000000000005, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9497
#  929/1000 [==========================>...] - ETA: 3:36 - rpn_cls: 1.0626 - rpn_regr: 0.1112 - detector_cls: 0.2065 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3jk0m-KbEr4+00+0012000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 9498
#  930/1000 [==========================>...] - ETA: 3:33 - rpn_cls: 1.0673 - rpn_regr: 0.1111 - detector_cls: 0.2064 - detector_regr: 0.1493X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1Lav8PRNiYA+00+0007000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 121.6, 'x2': 543.36, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9499
#  931/1000 [==========================>...] - ETA: 3:30 - rpn_cls: 1.0662 - rpn_regr: 0.1110 - detector_cls: 0.2066 - detector_regr: 0.1493X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3FmiqUY3PSU+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 419.52, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 9500
#  932/1000 [==========================>...] - ETA: 3:27 - rpn_cls: 1.0708 - rpn_regr: 0.1112 - detector_cls: 0.2068 - detector_regr: 0.1495X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+01Qc5zMoY5A+01+0094000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 11.399999760000002, 'y2': 360.0}], 'imageset': 'test'}
# index is 9501
#  933/1000 [==========================>...] - ETA: 3:24 - rpn_cls: 1.0697 - rpn_regr: 0.1110 - detector_cls: 0.2068 - detector_regr: 0.1495X is (1, 416, 554, 3)
# Y is 2
# ...
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+32-nD1xY1ks+00+0120000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 235.2, 'y1': 19.2, 'y2': 240.0}], 'imageset': 'test'}
# index is 10594
#  966/1000 [===========================>..] - ETA: 1:45 - rpn_cls: 1.0377 - rpn_regr: 0.0982 - detector_cls: 0.1888 - detector_regr: 0.1300X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2OiJ6tnxOf0+00+0013000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 17.1999996, 'y2': 231.19999199999998}], 'imageset': 'test'}
# index is 10595
#  967/1000 [============================>.] - ETA: 1:42 - rpn_cls: 1.0366 - rpn_regr: 0.0981 - detector_cls: 0.1887 - detector_regr: 0.1299X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2VAR9oLR218+00+0004000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 79.36, 'x2': 89.28, 'y1': 127.2, 'y2': 138.799992}], 'imageset': 'test'}
# index is 10596
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1ANYxlugrLU+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10597
#  968/1000 [============================>.] - ETA: 1:39 - rpn_cls: 1.0355 - rpn_regr: 0.0981 - detector_cls: 0.1887 - detector_regr: 0.1298X is (1, 416, 747, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+081HkwJAjTc+01+0055000+1.jpg', 'width': 640, 'height': 356, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 356.0}], 'imageset': 'test'}
# index is 10598
#  969/1000 [============================>.] - ETA: 1:36 - rpn_cls: 1.0380 - rpn_regr: 0.0980 - detector_cls: 0.1886 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2HaRwvJEOYA+02+0099000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 470.4, 'y1': 130.20000480000002, 'y2': 285.600006}], 'imageset': 'test'}
# index is 10599
#  970/1000 [============================>.] - ETA: 1:32 - rpn_cls: 1.0369 - rpn_regr: 0.0980 - detector_cls: 0.1886 - detector_regr: 0.1299X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2icEF4LKH1o+00+0006000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 10600
#  971/1000 [============================>.] - ETA: 1:29 - rpn_cls: 1.0358 - rpn_regr: 0.0979 - detector_cls: 0.1885 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+32-nD1xY1ks+02+0076000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 264.96, 'y1': 57.599999999999994, 'y2': 240.0}], 'imageset': 'test'}
# index is 10601
#  972/1000 [============================>.] - ETA: 1:26 - rpn_cls: 1.0348 - rpn_regr: 0.0979 - detector_cls: 0.1886 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0u64PwU7VzY+00+0008000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 225.6, 'x2': 395.52, 'y1': 141.600006, 'y2': 348.599988}], 'imageset': 'test'}
# index is 10602
#  973/1000 [============================>.] - ETA: 1:23 - rpn_cls: 1.0337 - rpn_regr: 0.0979 - detector_cls: 0.1887 - detector_regr: 0.1298X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+12u-BhwpX_0+00+0028000+1.jpg', 'width': 640, 'height': 352, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 624.0, 'y1': 21.706666784, 'y2': 301.5466784}], 'imageset': 'test'}
# index is 10603
#  974/1000 [============================>.] - ETA: 1:20 - rpn_cls: 1.0382 - rpn_regr: 0.0978 - detector_cls: 0.1887 - detector_regr: 0.1300X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3rs8aRi_WHE+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 4.20000012, 'y2': 314.3999988}], 'imageset': 'test'}
# index is 10604
#  975/1000 [============================>.] - ETA: 1:17 - rpn_cls: 1.0371 - rpn_regr: 0.0977 - detector_cls: 0.1887 - detector_regr: 0.1299X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1wXL_g0Nl8Q+01+0051000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 19.2000006, 'y2': 360.0}], 'imageset': 'test'}
# index is 10605
#  976/1000 [============================>.] - ETA: 1:14 - rpn_cls: 1.0361 - rpn_regr: 0.0977 - detector_cls: 0.1886 - detector_regr: 0.1299X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+14EJ1ii-2qk+00+0026000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 38.4000012, 'y2': 276.599988}], 'imageset': 'test'}
# index is 10606
#  977/1000 [============================>.] - ETA: 1:11 - rpn_cls: 1.0350 - rpn_regr: 0.0976 - detector_cls: 0.1887 - detector_regr: 0.1299X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-MN3QfQfVX8+00+0129000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 37.120000000000005, 'x2': 1280.0, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 10607
#  978/1000 [============================>.] - ETA: 1:08 - rpn_cls: 1.0374 - rpn_regr: 0.0975 - detector_cls: 0.1889 - detector_regr: 0.1300X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZWE-igmdLU+01+0053000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 338.9999976}], 'imageset': 'test'}
# index is 10608
#  979/1000 [============================>.] - ETA: 1:05 - rpn_cls: 1.0364 - rpn_regr: 0.0974 - detector_cls: 0.1888 - detector_regr: 0.1299X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2vpjj5R3Y9k+00+0029000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 1.60000008, 'y2': 182.79999840000002}], 'imageset': 'test'}
# index is 10609
#  980/1000 [============================>.] - ETA: 1:01 - rpn_cls: 1.0409 - rpn_regr: 0.0974 - detector_cls: 0.1887 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+34vwg15erxM+03+0701000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 54.72, 'x2': 68.64, 'y1': 186.599988, 'y2': 199.8}], 'imageset': 'test'}
# index is 10610
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1ESx0R0rlms+01+0218000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 74.9999988, 'y2': 359.3999988}], 'imageset': 'test'}
# index is 10611
#  981/1000 [============================>.] - ETA: 58s - rpn_cls: 1.0398 - rpn_regr: 0.0974 - detector_cls: 0.1887 - detector_regr: 0.1299 X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0W3yCw7SDJE+00+0045000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 104.64, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 10612
#  982/1000 [============================>.] - ETA: 55s - rpn_cls: 1.0405 - rpn_regr: 0.0973 - detector_cls: 0.1889 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0T75sYwrYa4+00+0032000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 106.56, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10613
#  983/1000 [============================>.] - ETA: 52s - rpn_cls: 1.0395 - rpn_regr: 0.0972 - detector_cls: 0.1889 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2GI4jRIGCuA+02+0094000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 271.2, 'x2': 480.0, 'y1': 142.8000048, 'y2': 297.599994}], 'imageset': 'test'}
# index is 10614
#  984/1000 [============================>.] - ETA: 49s - rpn_cls: 1.0384 - rpn_regr: 0.0973 - detector_cls: 0.1888 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3BQFmqge0Ic+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 229.44, 'y1': 130.8000024, 'y2': 343.8}], 'imageset': 'test'}
# index is 10615
#  985/1000 [============================>.] - ETA: 46s - rpn_cls: 1.0392 - rpn_regr: 0.0973 - detector_cls: 0.1888 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3Z5KPD7ReQM+01+0044000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 29.28, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10616
#  986/1000 [============================>.] - ETA: 43s - rpn_cls: 1.0382 - rpn_regr: 0.0972 - detector_cls: 0.1888 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+09+0496000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 161.28, 'x2': 480.0, 'y1': 173.9999952, 'y2': 360.0}], 'imageset': 'test'}
# index is 10617
#  987/1000 [============================>.] - ETA: 40s - rpn_cls: 1.0386 - rpn_regr: 0.0974 - detector_cls: 0.1887 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3Z5KPD7ReQM+01+0045000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 96.96000000000001, 'x2': 480.0, 'y1': 2.40000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 10618
#  988/1000 [============================>.] - ETA: 37s - rpn_cls: 1.0375 - rpn_regr: 0.0973 - detector_cls: 0.1890 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3ZlrVZIuh5c+01+0157000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 10619
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3KAYuc9_2Vc+00+0042000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 251.52, 'y1': 38.4000012, 'y2': 275.999994}], 'imageset': 'test'}
# index is 10620
#  989/1000 [============================>.] - ETA: 34s - rpn_cls: 1.0377 - rpn_regr: 0.0973 - detector_cls: 0.1889 - detector_regr: 0.1298X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0BSfrXvRmLk+00+0071000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 851.2, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 10621
#  990/1000 [============================>.] - ETA: 30s - rpn_cls: 1.0367 - rpn_regr: 0.0972 - detector_cls: 0.1890 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-nnAdGpBxqk+01+0045000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 76.8, 'x2': 152.95999999999998, 'y1': 84.0, 'y2': 156.799992}], 'imageset': 'test'}
# index is 10622
#  991/1000 [============================>.] - ETA: 27s - rpn_cls: 1.0374 - rpn_regr: 0.0971 - detector_cls: 0.1890 - detector_regr: 0.1297X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0LSgxm0ecSU+00+0010000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 75.36, 'x2': 361.92, 'y1': 78.0000012, 'y2': 272.999988}], 'imageset': 'test'}
# index is 10623
#  992/1000 [============================>.] - ETA: 24s - rpn_cls: 1.0364 - rpn_regr: 0.0972 - detector_cls: 0.1889 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+34vwg15erxM+04+0736000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 19.68, 'x2': 480.0, 'y1': 132.6000024, 'y2': 293.9999976}], 'imageset': 'test'}
# index is 10624
#  993/1000 [============================>.] - ETA: 21s - rpn_cls: 1.0353 - rpn_regr: 0.0971 - detector_cls: 0.1888 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2y3UQqt6elU+01+0047000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 30.0, 'y2': 190.40000400000002}], 'imageset': 'test'}
# index is 10625
#  994/1000 [============================>.] - ETA: 18s - rpn_cls: 1.0343 - rpn_regr: 0.0971 - detector_cls: 0.1889 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+01Qc5zMoY5A+01+0094000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 11.399999760000002, 'y2': 360.0}], 'imageset': 'test'}
# index is 10626
#  995/1000 [============================>.] - ETA: 15s - rpn_cls: 1.0332 - rpn_regr: 0.0970 - detector_cls: 0.1890 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2HY22-cb4-I+01+0029000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 19.68, 'x2': 480.0, 'y1': 62.399998800000006, 'y2': 313.8000012}], 'imageset': 'test'}
# index is 10627
#  996/1000 [============================>.] - ETA: 12s - rpn_cls: 1.0322 - rpn_regr: 0.0969 - detector_cls: 0.1890 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1n-UGX-YDhQ+00+0018000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 34.08, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10628
#  997/1000 [============================>.] - ETA: 9s - rpn_cls: 1.0312 - rpn_regr: 0.0968 - detector_cls: 0.1890 - detector_regr: 0.1299 X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3T1_hat2TUg+00+0125000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10629
#  998/1000 [============================>.] - ETA: 6s - rpn_cls: 1.0301 - rpn_regr: 0.0968 - detector_cls: 0.1888 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3onrqgPuvlk+00+0012000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 96.64, 'x2': 305.28, 'y1': 22.40000016, 'y2': 203.200008}], 'imageset': 'test'}
# index is 10630
#  999/1000 [============================>.] - ETA: 3s - rpn_cls: 1.0291 - rpn_regr: 0.0968 - detector_cls: 0.1888 - detector_regr: 0.1298X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3Sx2QvjLSbk+03+0262000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 310.08, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 10631
# 1000/1000 [==============================] - 3097s 3s/step - rpn_cls: 1.0281 - rpn_regr: 0.0969 - detector_cls: 0.1888 - detector_regr: 0.1297
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.572237960339944
# Classifier accuracy for bounding boxes from RPN: 0.9206875
# Loss RPN classifier: 1.0280753977221126
# Loss RPN regression: 0.09688786999043077
# Loss Detector classifier: 0.18881310466216883
# Loss Detector regression: 0.1297336869193241
# Elapsed time: 3097.23264503479
# Total loss decreased from 1.4988594258741197 to 1.4435100592940364, saving weights
# Training complete, exiting.
