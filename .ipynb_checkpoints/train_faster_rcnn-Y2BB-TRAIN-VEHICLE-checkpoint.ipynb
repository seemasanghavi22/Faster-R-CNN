# %% [markdown]
# ## Faster R-CNN Training for YTBB Train Class - using Pretrained ResNet50

# %%
from __future__ import division
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import re

# %%
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input
from keras.models import Model
from keras_frcnn import config, data_generators
from keras_frcnn import losses as losses
import keras_frcnn.roi_helpers as roi_helpers
from keras.utils import generic_utils
sys.setrecursionlimit(40000)

# %%
from keras_frcnn.simple_parser import get_data
from keras_frcnn import resnet as nn

# %% [markdown]
# #### Specify the config

# %%
# Create a config object and set the values
C = config.Config()
firstTraining = True

C.use_horizontal_flips = bool(False)
C.use_vertical_flips = bool(False)
C.rot_90 = bool(False)
C.model_path = './y2bb_model_frcnn_train_vehicle_v1.hdf5'
C.verbose = True
model_path_regex = re.match("^(.+)(\.hdf5)$", C.model_path)
if model_path_regex.group(2) != '.hdf5':
	print('Output weights must have .hdf5 filetype')
	exit(1)
C.num_rois = int(32)
C.network = 'resnet50'
if firstTraining is True:
    C.base_net_weights = nn.get_weight_path()
    firstTraining = False
else:
    C.base_net_weights = options.input_weight_path
config_output_filename = "y2bb_config_train.pickle"
#train_path = './annotate.txt'
#train_path = 'COCO_extracted_dataset/airplane_for_train/coco_airplane_annotate.txt'
train_path = 'y2bb_training_Train_annotate.txt'
val_path = 'y2bb_validation_Train_annotate.txt'

# %% [markdown]
# #### Load the training images using annotation file (created post data preprocessing)

# %%
train_imgs, classes_count, class_mapping = get_data(train_path)
val_imgs, _, _ = get_data(val_path)

if 'bg' not in classes_count:
	classes_count['bg'] = 0
	class_mapping['bg'] = len(class_mapping)

C.class_mapping = class_mapping
inv_map = {v: k for k, v in class_mapping.items()}

print('Training images per class:')
pprint.pprint(classes_count)
print(f'Num classes (including bg) = {len(classes_count)}')
# Out:
# Parsing annotation files
# Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).
# Parsing annotation files
# Training images per class:
# {'bg': 50, 'train': 950}
# Num classes (including bg) = 2

# %%
train_imgs
# Out:
# [{'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+01+0043000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 260.64000000000004,
#     'x2': 319.20000000000005,
#     'y1': 143.4000024,
#     'y2': 190.199988}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+10X4sACw0Bk+01+0081000+1.jpg',
#   'width': 384,
#   'height': 288,
#   'bboxes': [{'class': 'train',
#     'x1': 38.400000000000006,
#     'x2': 350.592,
#     'y1': 79.68000096,
#     'y2': 153.1200096}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1gXCV_X8Hw8+00+0008000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 85.1999976,
#     'y2': 261.600012}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3I5-oJDuyj8+00+0009000+1.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 1280.0,
#     'y1': 0.0,
#     'y2': 440.40002400000003}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0qh9LTeOGY8+00+0046000+1.jpg',
#   'width': 192,
#   'height': 144,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 192.0,
#     'y1': 0.0,
#     'y2': 85.19999616}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2iqay12cCJc+01+0110000+1.jpg',
#   'width': 320,
#   'height': 240,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 320.0,
#     'y1': 2.8000000800000002,
#     'y2': 153.999996}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3T1_hat2TUg+04+0265000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 360.0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0vfg9ZKYA2s+00+0005000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 429.12,
#     'y1': 120.00000239999999,
#     'y2': 289.2000024}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3j3YyvV_OZU+00+0026000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 437.76,
#     'y1': 106.799994,
#     'y2': 310.8000024}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1ThJWSUSbKs+00+0027000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 21.599999999999998,
#     'y2': 232.799994}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0Z2XnkJAIQ8+00+0047000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 121.92,
#     'x2': 395.03999999999996,
#     'y1': 54.6000012,
#     'y2': 252.59999399999998}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3bO_hDgvZBc+00+0005000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 310.200012}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+22NHRnlFer4+00+0150000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2':
+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 398.88,
#     'y1': 43.800001200000004,
#     'y2': 295.2}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+2ooNGOwH-U4+02+0075000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 448.8,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 360.0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+1SalFhLi2Jo+00+0141000+1.jpg',
#   'width': 320,
#   'height': 240,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 153.28,
#     'y1': 113.1999984,
#     'y2': 176.4}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+0SJj_mTwfvo+00+0057000+1.jpg',
#   'width': 320,
#   'height': 240,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 320.0,
#     'y1': 50.8000008,
#     'y2': 183.19999200000004}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+0Tumh38aqJA+01+0037000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 338.9999976}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+-025GNtJ0oI+00+0010000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 77.4,
#     'y2': 210.6}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+2MnbKb4krcY+00+0016000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 67.67999999999999,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 360.0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+1Fmwh4rPvrA+01+0046000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 479.52000000000004,
#     'y1': 2.4000001199999996,
#     'y2': 298.8}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/train_for_validation/15+1vjyqdBS6yY+00+0044000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 320.16,
#     'y1': 0.0,
#     'y2': 282.0000096}],
#   'imageset': 'test'}]

# %%
class_mapping
# Out:
# {'train': 0, 'bg': 1}

# %% [markdown]
# #### Save model weights path and config

# %%
with open(config_output_filename, 'wb') as config_f:
	pickle.dump(C,config_f)
	print(f'Config has been written to {config_output_filename}, and can be loaded when testing to ensure correct results')

#random.shuffle(train_imgs)

num_imgs = len(train_imgs)
print(f'Num train samples {len(train_imgs)}')
print(f'Num val samples {len(val_imgs)}')
# Out:
# Config has been written to y2bb_config_train.pickle, and can be loaded when testing to ensure correct results
# Num train samples 1000
# Num val samples 200

# %% [markdown]
# #### Training Setup - Faster R-CNN model initialization

# %%
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, C, nn.get_img_output_length, K.common.image_dim_ordering(), mode='train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn.get_img_output_length,K.common.image_dim_ordering(), mode='val')

# %%
data_gen_train
# Out:
# <generator object get_anchor_gt at 0x000001AF0C156E08>

# %%
data_gen_val
# Out:
# <generator object get_anchor_gt at 0x000001AF0C156DB0>

# %%
if K.common.image_dim_ordering() == 'th':
	input_shape_img = (3, None, None)
else:
	input_shape_img = (None, None, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))

# %%
img_input
# Out:
# <tf.Tensor 'input_1:0' shape=(None, None, None, 3) dtype=float32>

# %%
roi_input
# Out:
# <tf.Tensor 'input_2:0' shape=(None, None, 4) dtype=float32>

# %%
# define the base network (resnet here, can be VGG, Inception, etc)
shared_layers = nn.nn_base(img_input, trainable=True)
shared_layers
# Out:
# <tf.Tensor 'activation_40/Relu:0' shape=(None, None, None, 1024) dtype=float32>

# %%
C.anchor_box_scales
# Out:
# [128, 256, 512]

# %%
C.anchor_box_ratios
# Out:
# [[1, 1],
#  [0.7071067811865475, 1.414213562373095],
#  [1.414213562373095, 0.7071067811865475]]

# %%
# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
num_anchors
# Out:
# 9

# %%
rpn = nn.rpn(shared_layers, num_anchors)
rpn
# Out:
# [<tf.Tensor 'rpn_out_class/Sigmoid:0' shape=(None, None, None, 9) dtype=float32>,
#  <tf.Tensor 'rpn_out_regress/BiasAdd:0' shape=(None, None, None, 36) dtype=float32>,
#  <tf.Tensor 'activation_40/Relu:0' shape=(None, None, None, 1024) dtype=float32>]

# %%
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)
classifier
# Out:
# [<tf.Tensor 'dense_class_2/Reshape_1:0' shape=(1, 32, 2) dtype=float32>,
#  <tf.Tensor 'dense_regress_2/Reshape_1:0' shape=(1, 32, 4) dtype=float32>]

# %%
model_rpn = Model(img_input, rpn[:2])
model_rpn.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier = Model([img_input, roi_input], classifier)
model_classifier.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)
model_all.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
try:
	print('loading weights from {C.base_net_weights}')
	model_rpn.load_weights(C.base_net_weights, by_name=True)
	model_classifier.load_weights(C.base_net_weights, by_name=True)    
	#model_rpn.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
	#model_classifier.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
except:
	print('Could not load pretrained model weights. Weights can be found in the keras application folder \
		https://github.com/fchollet/keras/tree/master/keras/applications')
# Out:
# loading weights from {C.base_net_weights}

# %%
optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={f'dense_class_{len(classes_count)}': 'accuracy'})
model_all.compile(optimizer='sgd', loss='mae')

# %%
model_rpn.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
model_all.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %% [markdown]
# #### Faster R-CNN model Training - 5 Epochs

# %%
#number of images in the dataset
epoch_length = 1000 
num_epochs = int(5)
iter_num = 0

# %%
losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
start_time = time.time()

best_loss = np.Inf

# %%
class_mapping_inv = {v: k for k, v in class_mapping.items()}
print('Starting training')

vis = True
index = 0
# Out:
# Starting training

# %%
for epoch_num in range(num_epochs):

	progbar = generic_utils.Progbar(epoch_length)
	print(f'Epoch {epoch_num + 1}/{num_epochs}')

	while True:
		try:

			if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
				mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
				rpn_accuracy_rpn_monitor = []
				print(f'Average number of overlapping bounding boxes from RPN = {mean_overlapping_bboxes} for {epoch_length} previous iterations')
				if mean_overlapping_bboxes == 0:
					print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

			X, Y, img_data = next(data_gen_train)
			print(f'X is {X.shape}')
			print(f'Y is {len(Y)}')
			print(f'img_data is {img_data}')
			print(f'index is {index}')
			index = index + 1

			loss_rpn = model_rpn.train_on_batch(X, Y)

			P_rpn = model_rpn.predict_on_batch(X)

			R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.common.image_dim_ordering(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
			# note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
			X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

			if X2 is None:
				rpn_accuracy_rpn_monitor.append(0)
				rpn_accuracy_for_epoch.append(0)
				continue

			neg_samples = np.where(Y1[0, :, -1] == 1)
			pos_samples = np.where(Y1[0, :, -1] == 0)

			if len(neg_samples) > 0:
				neg_samples = neg_samples[0]
			else:
				neg_samples = []

			if len(pos_samples) > 0:
				pos_samples = pos_samples[0]
			else:
				pos_samples = []
			
			rpn_accuracy_rpn_monitor.append(len(pos_samples))
			rpn_accuracy_for_epoch.append((len(pos_samples)))

			if C.num_rois > 1:
				if len(pos_samples) < C.num_rois//2:
					selected_pos_samples = pos_samples.tolist()
				else:
					selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
				try:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
				except:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

				sel_samples = selected_pos_samples + selected_neg_samples
			else:
				# in the extreme case where num_rois = 1, we pick a random pos or neg sample
				selected_pos_samples = pos_samples.tolist()
				selected_neg_samples = neg_samples.tolist()
				if np.random.randint(0, 2):
					sel_samples = random.choice(neg_samples)
				else:
					sel_samples = random.choice(pos_samples)

			loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

			losses[iter_num, 0] = loss_rpn[1]
			losses[iter_num, 1] = loss_rpn[2]

			losses[iter_num, 2] = loss_class[1]
			losses[iter_num, 3] = loss_class[2]
			losses[iter_num, 4] = loss_class[3]

			progbar.update(iter_num+1, [('rpn_cls', losses[iter_num, 0]), ('rpn_regr', losses[iter_num, 1]),
									  ('detector_cls', losses[iter_num, 2]), ('detector_regr', losses[iter_num, 3])])

			iter_num += 1
			
			if iter_num == epoch_length:
				loss_rpn_cls = np.mean(losses[:, 0])
				loss_rpn_regr = np.mean(losses[:, 1])
				loss_class_cls = np.mean(losses[:, 2])
				loss_class_regr = np.mean(losses[:, 3])
				class_acc = np.mean(losses[:, 4])

				mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
				rpn_accuracy_for_epoch = []

				if C.verbose:
					print(f'Mean number of bounding boxes from RPN overlapping ground truth boxes: {mean_overlapping_bboxes}')
					print(f'Classifier accuracy for bounding boxes from RPN: {class_acc}')
					print(f'Loss RPN classifier: {loss_rpn_cls}')
					print(f'Loss RPN regression: {loss_rpn_regr}')
					print(f'Loss Detector classifier: {loss_class_cls}')
					print(f'Loss Detector regression: {loss_class_regr}')
					print(f'Elapsed time: {time.time() - start_time}')

				curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
				iter_num = 0
				start_time = time.time()

				if curr_loss < best_loss:
					if C.verbose:
						print(f'Total loss decreased from {best_loss} to {curr_loss}, saving weights')
					best_loss = curr_loss
				model_all.save_weights(model_path_regex.group(1) + "_" + '{:04d}'.format(epoch_num) + model_path_regex.group(2))

				break

		except Exception as e:
			print(f'Exception: {e}')
			continue

print('Training complete, exiting.')
# Out:
# Epoch 1/5
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0dEiFgGYfQ4+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 199.67999999999998, 'x2': 284.15999999999997, 'y1': 120.60000000000001, 'y2': 216.0}], 'imageset': 'test'}
# index is 0
#    1/1000 [..............................] - ETA: 8:09:36 - rpn_cls: 5.4738 - rpn_regr: 0.1075 - detector_cls: 0.6931 - detector_regr: 0.2916X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3M9zJQVwlRY+00+0008000+1.jpg', 'width': 636, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 58.512, 'x2': 506.89200000000005, 'y1': 130.8000024, 'y2': 300.59999999999997}], 'imageset': 'test'}
# index is 1
#    2/1000 [..............................] - ETA: 4:44:53 - rpn_cls: 5.5354 - rpn_regr: 0.1271 - detector_cls: 0.6910 - detector_regr: 0.3686X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2nvsroM7uZ0+00+0031000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 209.28, 'x2': 287.52, 'y1': 129.6, 'y2': 221.4}], 'imageset': 'test'}
# index is 2
#    3/1000 [..............................] - ETA: 3:32:27 - rpn_cls: 5.1803 - rpn_regr: 0.1391 - detector_cls: 0.6876 - detector_regr: 0.4113X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2xyQ0CVtHoY+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 195.35999999999999, 'x2': 411.36, 'y1': 111.0000024, 'y2': 215.4000096}], 'imageset': 'test'}
# index is 3
#    4/1000 [..............................] - ETA: 2:56:31 - rpn_cls: 5.1799 - rpn_regr: 0.1634 - detector_cls: 0.6859 - detector_regr: 0.4849X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+17PEdLBoSQg+01+0067000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 560.0, 'y1': 50.400000000000006, 'y2': 360.0}], 'imageset': 'test'}
# index is 4
#    5/1000 [..............................] - ETA: 2:37:58 - rpn_cls: 6.2284 - rpn_regr: 0.1375 - detector_cls: 0.6831 - detector_regr: 0.4588X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+22NHRnlFer4+02+0059000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 117.599994, 'y2': 206.99999999999997}], 'imageset': 'test'}
# index is 5
#    6/1000 [..............................] - ETA: 2:22:53 - rpn_cls: 5.7167 - rpn_regr: 0.2004 - detector_cls: 0.6778 - detector_regr: 0.3823X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-SivrdE-gMM+00+0044000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 27.839999999999996, 'x2': 320.0, 'y1': 34.3999992, 'y2': 142.399992}], 'imageset': 'test'}
# index is 6
#    7/1000 [..............................] - ETA: 2:11:57 - rpn_cls: 6.0486 - rpn_regr: 0.1924 - detector_cls: 0.6743 - detector_regr: 0.3824X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+08krZG0GN_8+01+0032000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 16.80000012, 'y2': 288.600012}], 'imageset': 'test'}
# index is 7
#    8/1000 [..............................] - ETA: 2:05:59 - rpn_cls: 6.1167 - rpn_regr: 0.2491 - detector_cls: 0.6714 - detector_regr: 0.3907X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0uTMbkgszdU+00+0064000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 204.8, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 8
#    9/1000 [..............................] - ETA: 2:01:06 - rpn_cls: 6.4521 - rpn_regr: 0.2682 - detector_cls: 0.6686 - detector_regr: 0.3974X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+04ZKB63bfSg+03+0102000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 398.08, 'x2': 618.24, 'y1': 45.6000012, 'y2': 243.00000000000003}], 'imageset': 'test'}
# index is 9
#   10/1000 [..............................] - ETA: 1:58:51 - rpn_cls: 7.0290 - rpn_regr: 0.2454 - detector_cls: 0.6625 - detector_regr: 0.4252X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+00iw45dQOBA+00+0016000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 124.80000000000001, 'x2': 169.60000000000002, 'y1': 91.2, 'y2': 129.2000064}], 'imageset': 'test'}
# index is 10
#   11/1000 [..............................] - ETA: 1:56:39 - rpn_cls: 6.8614 - rpn_regr: 0.2743 - detector_cls: 0.6522 - detector_regr: 0.3866X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3rs8aRi_WHE+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 4.20000012, 'y2': 314.3999988}], 'imageset': 'test'}
# index is 11
#   12/1000 [..............................] - ETA: 1:54:45 - rpn_cls: 7.0109 - rpn_regr: 0.3102 - detector_cls: 0.6477 - detector_regr: 0.3916X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2v0dCPbPYbo+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 245.76, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 12
#   13/1000 [..............................] - ETA: 1:53:07 - rpn_cls: 6.8951 - rpn_regr: 0.3005 - detector_cls: 0.6389 - detector_regr: 0.4114X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2tBVc0YwKZg+01+0035000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 1280.0, 'y1': 33.60000024, 'y2': 720.0}], 'imageset': 'test'}
# index is 13
#   14/1000 [..............................] - ETA: 1:53:06 - rpn_cls: 7.0006 - rpn_regr: 0.2805 - detector_cls: 0.6307 - detector_regr: 0.4116X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+07yqmNxwcYQ+02+0101000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 8.639999999999999, 'x2': 479.52, 'y1': 15.000000479999999, 'y2': 356.4}], 'imageset': 'test'}
# index is 14
#   15/1000 [..............................] - ETA: 1:51:29 - rpn_cls: 6.6534 - rpn_regr: 0.3145 - detector_cls: 0.6237 - detector_regr: 0.4221X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1IcLjcXfZfI+09+0477000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 77.44, 'x2': 634.24, 'y1': 64.8, 'y2': 310.8000024}], 'imageset': 'test'}
# index is 15
#   16/1000 [..............................] - ETA: 1:51:37 - rpn_cls: 6.6609 - rpn_regr: 0.2993 - detector_cls: 0.6131 - detector_regr: 0.4265X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3M9zJQVwlRY+00+0011000+1.jpg', 'width': 636, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 89.04, 'x2': 345.98400000000004, 'y1': 130.20000480000002, 'y2': 289.2000024}], 'imageset': 'test'}
# index is 16
#   17/1000 [..............................] - ETA: 1:51:10 - rpn_cls: 6.5408 - rpn_regr: 0.2875 - detector_cls: 0.6064 - detector_regr: 0.4222X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-yMI3k70zIU+00+0017000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 267.84000000000003, 'x2': 344.15999999999997, 'y1': 106.19999999999999, 'y2': 146.9999988}], 'imageset': 'test'}
# index is 17
#   18/1000 [..............................] - ETA: 1:49:57 - rpn_cls: 6.3455 - rpn_regr: 0.3091 - detector_cls: 0.5934 - detector_regr: 0.3987X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-771AUMRGi0+01+0036000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 192.8000016}], 'imageset': 'test'}
# index is 18
#   19/1000 [..............................] - ETA: 1:49:01 - rpn_cls: 6.2395 - rpn_regr: 0.3250 - detector_cls: 0.5878 - detector_regr: 0.4074X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2X4c-0Ctmmw+03+0074000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 31.200000000000003, 'x2': 306.24, 'y1': 92.39999759999999, 'y2': 306.600012}], 'imageset': 'test'}
# index is 19
#   20/1000 [..............................] - ETA: 1:47:54 - rpn_cls: 6.5050 - rpn_regr: 0.3139 - detector_cls: 0.5816 - detector_regr: 0.4101X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-wk7J5aKLB4+01+0044000+1.jpg', 'width': 480, 'height': 272, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 354.24, 'y1': 58.93333424, 'y2': 200.3733424}], 'imageset': 'test'}
# index is 20
#   21/1000 [..............................] - ETA: 1:48:04 - rpn_cls: 6.4322 - rpn_regr: 0.3090 - detector_cls: 0.5732 - detector_regr: 0.4163X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-agMZAokxnU+00+0005000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 420.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 21
#   22/1000 [..............................] - ETA: 1:47:16 - rpn_cls: 6.2954 - rpn_regr: 0.3285 - detector_cls: 0.5692 - detector_regr: 0.4201X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-rOnmbSTcI8+00+0013000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 255.36, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 22
#   23/1000 [..............................] - ETA: 1:46:17 - rpn_cls: 6.3571 - rpn_regr: 0.3435 - detector_cls: 0.5681 - detector_regr: 0.4229X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+21yEIRuPNlo+00+0001000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.400000008, 'y2': 149.5999992}], 'imageset': 'test'}
# index is 23
#   24/1000 [..............................] - ETA: 1:46:17 - rpn_cls: 6.2147 - rpn_regr: 0.3449 - detector_cls: 0.5622 - detector_regr: 0.4341X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3FmiqUY3PSU+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 419.52, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 24
#   25/1000 [..............................] - ETA: 1:45:51 - rpn_cls: 6.1338 - rpn_regr: 0.3607 - detector_cls: 0.5468 - detector_regr: 0.4168X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3HRw4jH7bSo+00+0008000+1.jpg', 'width': 640, 'height': 352, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 582.4, 'y1': 0.0, 'y2': 338.50665728}], 'imageset': 'test'}
# index is 25
#   26/1000 [..............................] - ETA: 1:46:12 - rpn_cls: 6.2459 - rpn_regr: 0.3481 - detector_cls: 0.5488 - detector_regr: 0.4186X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1cy9A4oGWJU+00+0010000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 369.6, 'y1': 0.0, 'y2': 320.4}], 'imageset': 'test'}
# index is 26
#   27/1000 [..............................] - ETA: 1:45:42 - rpn_cls: 6.2197 - rpn_regr: 0.3540 - detector_cls: 0.5555 - detector_regr: 0.4212X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2M1vWgwLuio+00+0006000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 60.0, 'y2': 141.6}], 'imageset': 'test'}
# index is 27
#   28/1000 [..............................] - ETA: 1:45:12 - rpn_cls: 6.2113 - rpn_regr: 0.3523 - detector_cls: 0.5479 - detector_regr: 0.4287X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3KAYuc9_2Vc+01+0089000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 284.15999999999997, 'y1': 56.400001200000005, 'y2': 360.0}], 'imageset': 'test'}
# index is 28
#   29/1000 [..............................] - ETA: 1:45:00 - rpn_cls: 6.1837 - rpn_regr: 0.3469 - detector_cls: 0.5526 - detector_regr: 0.4355X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2X4c-0Ctmmw+01+0118000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 35.519999999999996, 'x2': 355.2, 'y1': 83.9999988, 'y2': 327.6}], 'imageset': 'test'}
# index is 29
#   30/1000 [..............................] - ETA: 1:44:26 - rpn_cls: 6.2551 - rpn_regr: 0.3406 - detector_cls: 0.5587 - detector_regr: 0.4395X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1KK7XtwPCoo+01+0026000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 56.64, 'x2': 431.52, 'y1': 24.0000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 30
#   31/1000 [..............................] - ETA: 1:43:50 - rpn_cls: 6.0551 - rpn_regr: 0.3479 - detector_cls: 0.5509 - detector_regr: 0.4327X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1Lav8PRNiYA+00+0007000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 121.6, 'x2': 543.36, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 31
#   32/1000 [..............................] - ETA: 1:44:04 - rpn_cls: 6.1235 - rpn_regr: 0.3417 - detector_cls: 0.5530 - detector_regr: 0.4333X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 145.92, 'x2': 282.24, 'y1': 118.80000000000001, 'y2': 256.799988}], 'imageset': 'test'}
# index is 32
#   33/1000 [..............................] - ETA: 1:43:33 - rpn_cls: 6.1190 - rpn_regr: 0.3355 - detector_cls: 0.5499 - detector_regr: 0.4452X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2KL8RWSy1_g+01+0255000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 415.2, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 33
#   34/1000 [>.............................] - ETA: 1:43:23 - rpn_cls: 6.1732 - rpn_regr: 0.3458 - detector_cls: 0.5469 - detector_regr: 0.4512X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2icEF4LKH1o+00+0008000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 34
#   35/1000 [>.............................] - ETA: 1:42:45 - rpn_cls: 6.0627 - rpn_regr: 0.3594 - detector_cls: 0.5463 - detector_regr: 0.4522X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3lF47TszHME+01+0160000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 42.24, 'y1': 0.0, 'y2': 239.5999992}], 'imageset': 'test'}
# index is 35
#   36/1000 [>.............................] - ETA: 1:41:56 - rpn_cls: 5.9804 - rpn_regr: 0.3699 - detector_cls: 0.5401 - detector_regr: 0.4441X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3onrqgPuvlk+01+0042000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 107.84, 'x2': 320.0, 'y1': 0.400000008, 'y2': 240.0}], 'imageset': 'test'}
# index is 36
#   37/1000 [>.............................] - ETA: 1:41:21 - rpn_cls: 6.0330 - rpn_regr: 0.3710 - detector_cls: 0.5394 - detector_regr: 0.4452X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3birqWg1fMw+00+0021000+1.jpg', 'width': 640, 'height': 352, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 403.84000000000003, 'y1': 0.0, 'y2': 312.6933216}], 'imageset': 'test'}
# index is 37
#   38/1000 [>.............................] - ETA: 1:41:02 - rpn_cls: 6.0813 - rpn_regr: 0.3654 - detector_cls: 0.5382 - detector_regr: 0.4463X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2FMue4ul6oc+03+0093000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 81.12, 'x2': 250.56, 'y1': 46.800000000000004, 'y2': 173.9999952}], 'imageset': 'test'}
# index is 38
#   39/1000 [>.............................] - ETA: 1:40:15 - rpn_cls: 6.0545 - rpn_regr: 0.3621 - detector_cls: 0.5345 - detector_regr: 0.4485X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1lchW68PF2I+01+0021000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 308.48, 'y1': 0.0, 'y2': 209.2000008}], 'imageset': 'test'}
# index is 39
#   40/1000 [>.............................] - ETA: 1:39:44 - rpn_cls: 6.1713 - rpn_regr: 0.3696 - detector_cls: 0.5333 - detector_regr: 0.4482X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0SkIi3YGKPI+01+0070000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 374.88, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 40
#   41/1000 [>.............................] - ETA: 1:39:23 - rpn_cls: 6.2705 - rpn_regr: 0.3741 - detector_cls: 0.5325 - detector_regr: 0.4479X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3T1_hat2TUg+00+0130000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 431.52, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 41
#   42/1000 [>.............................] - ETA: 1:38:57 - rpn_cls: 6.3403 - rpn_regr: 0.3821 - detector_cls: 0.5310 - detector_regr: 0.4499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-KHjb74Z5MY+02+0101000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 289.44, 'y1': 0.0, 'y2': 303.599988}], 'imageset': 'test'}
# index is 42
#   43/1000 [>.............................] - ETA: 1:38:46 - rpn_cls: 6.3397 - rpn_regr: 0.3783 - detector_cls: 0.5300 - detector_regr: 0.4499X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0vfg9ZKYA2s+00+0012000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 52.32, 'x2': 480.0, 'y1': 103.1999976, 'y2': 245.40001199999998}], 'imageset': 'test'}
# index is 43
#   44/1000 [>.............................] - ETA: 1:38:26 - rpn_cls: 6.3176 - rpn_regr: 0.3728 - detector_cls: 0.5306 - detector_regr: 0.4523X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+16c_9Bc6XUQ+00+0031000+0.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 44
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2d0iQVxhQ_g+00+0081000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 45
# X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZY4b_yyA1c+01+0214000+0.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 46
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0qih7ASxWdM+00+0003000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 15.36, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 47
#   45/1000 [>.............................] - ETA: 1:40:32 - rpn_cls: 6.1841 - rpn_regr: 0.3819 - detector_cls: 0.5298 - detector_regr: 0.4506X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3lF47TszHME+01+0150000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 44.160000000000004, 'y1': 0.0, 'y2': 238.8}], 'imageset': 'test'}
# index is 48
#   46/1000 [>.............................] - ETA: 1:40:06 - rpn_cls: 6.1259 - rpn_regr: 0.3885 - detector_cls: 0.5258 - detector_regr: 0.4509X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1gXCV_X8Hw8+00+0008000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 85.1999976, 'y2': 261.600012}], 'imageset': 'test'}
# index is 49
#   47/1000 [>.............................] - ETA: 1:39:42 - rpn_cls: 6.0828 - rpn_regr: 0.3852 - detector_cls: 0.5256 - detector_regr: 0.4518X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0IzMjNd2srQ+00+0005000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 45.6000012, 'y2': 301.799988}], 'imageset': 'test'}
# index is 50
#   48/1000 [>.............................] - ETA: 1:39:27 - rpn_cls: 6.1697 - rpn_regr: 0.3888 - detector_cls: 0.5252 - detector_regr: 0.4523X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2yQ7ehuGTRI+00+0030000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 355.68, 'y1': 0.0, 'y2': 262.8}], 'imageset': 'test'}
# index is 51
#   49/1000 [>.............................] - ETA: 1:39:03 - rpn_cls: 6.1320 - rpn_regr: 0.3859 - detector_cls: 0.5275 - detector_regr: 0.4536X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-gBu_WXFnx8+01+0090000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 86.9999976, 'y2': 236.400012}], 'imageset': 'test'}
# index is 52
#   50/1000 [>.............................] - ETA: 1:38:46 - rpn_cls: 6.1020 - rpn_regr: 0.3828 - detector_cls: 0.5277 - detector_regr: 0.4559X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+07DiN3UALd0+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 120.96000000000001, 'x2': 441.6, 'y1': 33.0000012, 'y2': 328.200012}], 'imageset': 'test'}
# index is 53
#   51/1000 [>.............................] - ETA: 1:38:32 - rpn_cls: 6.0907 - rpn_regr: 0.3830 - detector_cls: 0.5284 - detector_regr: 0.4561X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6dnETcotmM+00+0014000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 464.64, 'x2': 480.0, 'y1': 16.80000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 54
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-t1yQ1H51Lo+00+0054000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 310.71999999999997, 'y1': 62.400000000000006, 'y2': 189.60000000000002}], 'imageset': 'test'}
# index is 55
#   52/1000 [>.............................] - ETA: 1:38:48 - rpn_cls: 6.0111 - rpn_regr: 0.3793 - detector_cls: 0.5318 - detector_regr: 0.4582X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2X4c-0Ctmmw+01+0116000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 31.68, 'x2': 294.71999999999997, 'y1': 86.9999976, 'y2': 306.0}], 'imageset': 'test'}
# index is 56
#   53/1000 [>.............................] - ETA: 1:38:36 - rpn_cls: 6.0734 - rpn_regr: 0.3734 - detector_cls: 0.5335 - detector_regr: 0.4587X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3BQFmqge0Ic+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 229.44, 'y1': 130.8000024, 'y2': 343.8}], 'imageset': 'test'}
# index is 57
#   54/1000 [>.............................] - ETA: 1:38:15 - rpn_cls: 6.1485 - rpn_regr: 0.3672 - detector_cls: 0.5321 - detector_regr: 0.4592X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-iwd4lSUk4w+00+0012000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 58
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-9Kf0njIktU+00+0001000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 12.479999999999999, 'x2': 422.88, 'y1': 26.399998800000002, 'y2': 271.1999988}], 'imageset': 'test'}
# index is 59
#   55/1000 [>.............................] - ETA: 1:38:31 - rpn_cls: 6.0487 - rpn_regr: 0.3655 - detector_cls: 0.5354 - detector_regr: 0.4596X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0u64PwU7VzY+00+0004000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 202.07999999999998, 'x2': 315.84000000000003, 'y1': 151.799994, 'y2': 292.79999879999997}], 'imageset': 'test'}
# index is 60
#   56/1000 [>.............................] - ETA: 1:38:15 - rpn_cls: 6.0963 - rpn_regr: 0.3607 - detector_cls: 0.5304 - detector_regr: 0.4514X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2E4Fp_kREe8+00+0134000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 98.40000239999999, 'y2': 216.600012}], 'imageset': 'test'}
# index is 61
#   57/1000 [>.............................] - ETA: 1:37:55 - rpn_cls: 6.0717 - rpn_regr: 0.3603 - detector_cls: 0.5281 - detector_regr: 0.4555X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2X4c-0Ctmmw+02+0045000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 33.120000000000005, 'x2': 305.76, 'y1': 91.8, 'y2': 306.600012}], 'imageset': 'test'}
# index is 62
#   58/1000 [>.............................] - ETA: 1:37:40 - rpn_cls: 6.1078 - rpn_regr: 0.3554 - detector_cls: 0.5287 - detector_regr: 0.4547X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1KaJH3b51VM+00+0001000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 7.359999999999999, 'x2': 275.2, 'y1': 0.0, 'y2': 204.400008}], 'imageset': 'test'}
# index is 63
#   59/1000 [>.............................] - ETA: 1:37:27 - rpn_cls: 6.1225 - rpn_regr: 0.3569 - detector_cls: 0.5288 - detector_regr: 0.4529X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2_m7hmhS_24+00+0003000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 277.12, 'y1': 0.0, 'y2': 234.400008}], 'imageset': 'test'}
# index is 64
#   60/1000 [>.............................] - ETA: 1:37:08 - rpn_cls: 6.1086 - rpn_regr: 0.3610 - detector_cls: 0.5277 - detector_regr: 0.4506X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2qs-ClwgZjY+00+0011000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 4.8, 'x2': 297.28000000000003, 'y1': 20.79999984, 'y2': 240.0}], 'imageset': 'test'}
# index is 65
#   61/1000 [>.............................] - ETA: 1:36:56 - rpn_cls: 6.0386 - rpn_regr: 0.3653 - detector_cls: 0.5254 - detector_regr: 0.4467X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0IGlkRhZ3N0+01+0043000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 66
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-pqpwRfppjA+01+0519000+0.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 67
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3X68YQk3WpE+02+0102000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 7.68, 'x2': 478.08, 'y1': 72.0, 'y2': 320.4}], 'imageset': 'test'}
# index is 68
#   62/1000 [>.............................] - ETA: 1:37:44 - rpn_cls: 6.0211 - rpn_regr: 0.3675 - detector_cls: 0.5272 - detector_regr: 0.4469X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+30m9vqvgMvM+00+0010000+1.jpg', 'width': 160, 'height': 120, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 160.0, 'y1': 0.0, 'y2': 120.0}], 'imageset': 'test'}
# index is 69
#   63/1000 [>.............................] - ETA: 1:37:30 - rpn_cls: 5.9876 - rpn_regr: 0.3742 - detector_cls: 0.5267 - detector_regr: 0.4464X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2-Xaynl3qbQ+00+0003000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 31.04, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 70
#   64/1000 [>.............................] - ETA: 1:37:18 - rpn_cls: 5.9217 - rpn_regr: 0.3794 - detector_cls: 0.5275 - detector_regr: 0.4473X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-Pc9x6O0ptA+00+0099000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 2.56, 'x2': 315.2, 'y1': 5.19999984, 'y2': 240.0}], 'imageset': 'test'}
# index is 71
#   65/1000 [>.............................] - ETA: 1:37:02 - rpn_cls: 5.8857 - rpn_regr: 0.3847 - detector_cls: 0.5267 - detector_regr: 0.4477X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2KGKvT2Ag_w+00+0005000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 384.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 72
#   66/1000 [>.............................] - ETA: 1:36:51 - rpn_cls: 5.8839 - rpn_regr: 0.3872 - detector_cls: 0.5256 - detector_regr: 0.4482X is (1, 416, 508, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0n-lMeS_2fw+01+0119000+1.jpg', 'width': 352, 'height': 288, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 220.0, 'y1': 64.8, 'y2': 253.44}], 'imageset': 'test'}
# index is 73
#   67/1000 [=>............................] - ETA: 1:36:32 - rpn_cls: 5.8893 - rpn_regr: 0.3825 - detector_cls: 0.5291 - detector_regr: 0.4480X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-8ksJIqOgcA+00+0010000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 56.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 74
#   68/1000 [=>............................] - ETA: 1:36:15 - rpn_cls: 5.8958 - rpn_regr: 0.3849 - detector_cls: 0.5285 - detector_regr: 0.4488X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0j6RR7_Y8Ow+00+0029000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 143.36, 'x2': 1130.24, 'y1': 54.0, 'y2': 657.6000192}], 'imageset': 'test'}
# index is 75
#   69/1000 [=>............................] - ETA: 1:36:18 - rpn_cls: 5.8616 - rpn_regr: 0.3803 - detector_cls: 0.5301 - detector_regr: 0.4485X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-LkSgDlGI2w+00+0328000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 223.68, 'y1': 0.0, 'y2': 272.999988}], 'imageset': 'test'}
# index is 76
#   70/1000 [=>............................] - ETA: 1:36:05 - rpn_cls: 5.8841 - rpn_regr: 0.3762 - detector_cls: 0.5337 - detector_regr: 0.4505X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1USRwMcH0Fc+01+0099000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 315.84000000000003, 'y1': 36.6000012, 'y2': 244.20000240000002}], 'imageset': 'test'}
# index is 77
#   71/1000 [=>............................] - ETA: 1:35:50 - rpn_cls: 5.8379 - rpn_regr: 0.3725 - detector_cls: 0.5360 - detector_regr: 0.4502X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2j-S5Ez5O6k+01+0036000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 123.0000012, 'y2': 291.0000024}], 'imageset': 'test'}
# index is 78
#   72/1000 [=>............................] - ETA: 1:35:43 - rpn_cls: 5.7594 - rpn_regr: 0.3699 - detector_cls: 0.5368 - detector_regr: 0.4520X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2ksdt48YU-g+00+0018000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 743.68, 'x2': 879.3600000000001, 'y1': 369.59997599999997, 'y2': 496.79999999999995}], 'imageset': 'test'}
# index is 79
#   73/1000 [=>............................] - ETA: 1:35:42 - rpn_cls: 5.7025 - rpn_regr: 0.3706 - detector_cls: 0.5322 - detector_regr: 0.4458X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1kbtdQCFaiI+01+0046000+1.jpg', 'width': 480, 'height': 270, 'bboxes': [{'class': 'train', 'x1': 143.51999999999998, 'x2': 372.48, 'y1': 66.15, 'y2': 191.24999100000002}], 'imageset': 'test'}
# index is 80
#   74/1000 [=>............................] - ETA: 1:35:47 - rpn_cls: 5.6639 - rpn_regr: 0.3662 - detector_cls: 0.5323 - detector_regr: 0.4449X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZcY7wUzysg+01+0057000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 188.64000000000001, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 81
#   75/1000 [=>............................] - ETA: 1:35:31 - rpn_cls: 5.6611 - rpn_regr: 0.3627 - detector_cls: 0.5324 - detector_regr: 0.4446X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+01+0035000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 176.64, 'x2': 254.88000000000002, 'y1': 123.0000012, 'y2': 208.79999999999998}], 'imageset': 'test'}
# index is 82
#   76/1000 [=>............................] - ETA: 1:35:14 - rpn_cls: 5.6768 - rpn_regr: 0.3607 - detector_cls: 0.5287 - detector_regr: 0.4387X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2BtG8h1du8g+00+0120000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 20.400001200000002, 'y2': 283.8000096}], 'imageset': 'test'}
# index is 83
#   77/1000 [=>............................] - ETA: 1:35:05 - rpn_cls: 5.7172 - rpn_regr: 0.3626 - detector_cls: 0.5288 - detector_regr: 0.4392X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZWE-igmdLU+01+0045000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 345.59999999999997}], 'imageset': 'test'}
# index is 84
#   78/1000 [=>............................] - ETA: 1:34:50 - rpn_cls: 5.6517 - rpn_regr: 0.3674 - detector_cls: 0.5282 - detector_regr: 0.4383X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1vjyqdBS6yY+00+0038000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 270.6000012}], 'imageset': 'test'}
# index is 85
#   79/1000 [=>............................] - ETA: 1:34:34 - rpn_cls: 5.7101 - rpn_regr: 0.3696 - detector_cls: 0.5286 - detector_regr: 0.4399X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-025GNtJ0oI+01+0104000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 86
#   80/1000 [=>............................] - ETA: 1:34:25 - rpn_cls: 5.6707 - rpn_regr: 0.3745 - detector_cls: 0.5286 - detector_regr: 0.4393X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2EOq90VkCBc+00+0168000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 87
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1SalFhLi2Jo+01+0072000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 34.3999992, 'y2': 236.000004}], 'imageset': 'test'}
# index is 88
#   81/1000 [=>............................] - ETA: 1:34:33 - rpn_cls: 5.6634 - rpn_regr: 0.3767 - detector_cls: 0.5282 - detector_regr: 0.4381X is (1, 416, 558, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-bOySjRdVIw+01+0286000+1.jpg', 'width': 352, 'height': 262, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 238.30400000000003, 'y1': 76.85332984, 'y2': 168.99}], 'imageset': 'test'}
# index is 89
#   82/1000 [=>............................] - ETA: 1:34:23 - rpn_cls: 5.6482 - rpn_regr: 0.3740 - detector_cls: 0.5267 - detector_regr: 0.4388X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1Zb3Pb7vCyQ+00+0054000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 90
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+00+0010000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 177.12, 'x2': 318.72, 'y1': 96.60000600000001, 'y2': 249.59998800000002}], 'imageset': 'test'}
# index is 91
#   83/1000 [=>............................] - ETA: 1:34:33 - rpn_cls: 5.6658 - rpn_regr: 0.3719 - detector_cls: 0.5252 - detector_regr: 0.4436X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-fesObi6HC8+00+0014000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 120.32, 'x2': 169.28, 'y1': 87.20000160000001, 'y2': 135.19999919999998}], 'imageset': 'test'}
# index is 92
#   84/1000 [=>............................] - ETA: 1:34:19 - rpn_cls: 5.6840 - rpn_regr: 0.3714 - detector_cls: 0.5210 - detector_regr: 0.4383X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1qyw9LyVhC0+00+0599000+0.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 93
# X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3GQO3bJ_klg+00+0013000+1.jpg', 'width': 480, 'height': 264, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 274.08, 'y1': 6.159999912, 'y2': 264.0}], 'imageset': 'test'}
# index is 94
#   85/1000 [=>............................] - ETA: 1:34:45 - rpn_cls: 5.6822 - rpn_regr: 0.3696 - detector_cls: 0.5209 - detector_regr: 0.4396X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2FMue4ul6oc+03+0094000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 312.96000000000004, 'x2': 480.0, 'y1': 47.3999976, 'y2': 173.399994}], 'imageset': 'test'}
# index is 95
#   86/1000 [=>............................] - ETA: 1:34:28 - rpn_cls: 5.6370 - rpn_regr: 0.3686 - detector_cls: 0.5215 - detector_regr: 0.4418X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3Ey93zKcFqQ+00+0046000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 96
# X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZY4b_yyA1c+00+0153000+0.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 97
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2y3UQqt6elU+01+0047000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 30.0, 'y2': 190.40000400000002}], 'imageset': 'test'}
# index is 98
#   87/1000 [=>............................] - ETA: 1:35:04 - rpn_cls: 5.6207 - rpn_regr: 0.3682 - detector_cls: 0.5204 - detector_regr: 0.4414X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0Tumh38aqJA+00+0003000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 218.4, 'x2': 463.68, 'y1': 97.2, 'y2': 216.0}], 'imageset': 'test'}
# index is 99
#   88/1000 [=>............................] - ETA: 1:34:48 - rpn_cls: 5.5577 - rpn_regr: 0.3670 - detector_cls: 0.5187 - detector_regr: 0.4447X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0T75sYwrYa4+00+0032000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 106.56, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 100
#   89/1000 [=>............................] - ETA: 1:34:37 - rpn_cls: 5.5359 - rpn_regr: 0.3696 - detector_cls: 0.5180 - detector_regr: 0.4431X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3T1_hat2TUg+03+0231000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 101
#   90/1000 [=>............................] - ETA: 1:34:22 - rpn_cls: 5.5289 - rpn_regr: 0.3739 - detector_cls: 0.5192 - detector_regr: 0.4436X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3TnNb5Oc--8+11+0047000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 273.59999999999997, 'y1': 24.600000599999998, 'y2': 269.3999988}], 'imageset': 'test'}
# index is 102
#   91/1000 [=>............................] - ETA: 1:34:07 - rpn_cls: 5.5158 - rpn_regr: 0.3704 - detector_cls: 0.5225 - detector_regr: 0.4434X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0oGiHVOz6iY+00+0030000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 89.60000000000001, 'x2': 581.12, 'y1': 122.4, 'y2': 243.600012}], 'imageset': 'test'}
# index is 103
#   92/1000 [=>............................] - ETA: 1:34:09 - rpn_cls: 5.4697 - rpn_regr: 0.3693 - detector_cls: 0.5218 - detector_regr: 0.4460X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-XuZyQLZLGc+00+0023000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 102.24, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 104
#   93/1000 [=>............................] - ETA: 1:33:55 - rpn_cls: 5.4692 - rpn_regr: 0.3717 - detector_cls: 0.5208 - detector_regr: 0.4448X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0SJj_mTwfvo+00+0050000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 182.79999840000002}], 'imageset': 'test'}
# index is 105
#   94/1000 [=>............................] - ETA: 1:33:42 - rpn_cls: 5.4121 - rpn_regr: 0.3724 - detector_cls: 0.5218 - detector_regr: 0.4462X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3Ey93zKcFqQ+00+0031000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 170.88, 'x2': 480.0, 'y1': 96.0000048, 'y2': 310.8000024}], 'imageset': 'test'}
# index is 106
#   95/1000 [=>............................] - ETA: 1:33:33 - rpn_cls: 5.3919 - rpn_regr: 0.3701 - detector_cls: 0.5260 - detector_regr: 0.4453X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-inbWsZ-4Ok+00+0106000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 185.92, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 107
#   96/1000 [=>............................] - ETA: 1:33:20 - rpn_cls: 5.3896 - rpn_regr: 0.3700 - detector_cls: 0.5258 - detector_regr: 0.4463X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1_VPW-l4DIg+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 18.4000008, 'y2': 119.2000008}], 'imageset': 'test'}
# index is 108
#   97/1000 [=>............................] - ETA: 1:33:08 - rpn_cls: 5.3479 - rpn_regr: 0.3680 - detector_cls: 0.5259 - detector_regr: 0.4461X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1S1nZhZU0Ok+01+0083000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 55.999999200000005, 'y2': 195.19999919999998}], 'imageset': 'test'}
# index is 109
#   98/1000 [=>............................] - ETA: 1:32:57 - rpn_cls: 5.3204 - rpn_regr: 0.3671 - detector_cls: 0.5265 - detector_regr: 0.4465X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3P_b80TKV_0+01+0040000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.48, 'x2': 480.0, 'y1': 93.60000000000001, 'y2': 236.400012}], 'imageset': 'test'}
# index is 110
#   99/1000 [=>............................] - ETA: 1:32:46 - rpn_cls: 5.2787 - rpn_regr: 0.3658 - detector_cls: 0.5263 - detector_regr: 0.4468X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0q0TdcPK9gg+00+0300000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 111
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-yMI3k70zIU+02+0092000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 112
#  100/1000 [==>...........................] - ETA: 1:32:56 - rpn_cls: 5.2647 - rpn_regr: 0.3696 - detector_cls: 0.5264 - detector_regr: 0.4469X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2yQ7ehuGTRI+00+0021000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 412.32, 'y1': 60.00000119999999, 'y2': 239.4}], 'imageset': 'test'}
# index is 113
#  101/1000 [==>...........................] - ETA: 1:32:44 - rpn_cls: 5.2309 - rpn_regr: 0.3664 - detector_cls: 0.5276 - detector_regr: 0.4465X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-ZcY7wUzysg+01+0047000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 147.35999999999999, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 114
#  102/1000 [==>...........................] - ETA: 1:32:30 - rpn_cls: 5.2077 - rpn_regr: 0.3632 - detector_cls: 0.5285 - detector_regr: 0.4470X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+02+0208000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 48.0, 'x2': 168.48, 'y1': 184.79998799999998, 'y2': 258.599988}], 'imageset': 'test'}
# index is 115
#  103/1000 [==>...........................] - ETA: 1:32:21 - rpn_cls: 5.2414 - rpn_regr: 0.3605 - detector_cls: 0.5270 - detector_regr: 0.4465X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+07+0431000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 191.04000000000002, 'y1': 111.6, 'y2': 359.3999988}], 'imageset': 'test'}
# index is 116
#  104/1000 [==>...........................] - ETA: 1:32:07 - rpn_cls: 5.2303 - rpn_regr: 0.3585 - detector_cls: 0.5290 - detector_regr: 0.4471X is (1, 416, 554, 3)
# Y is 2
# ...
# index is 5288
#  966/1000 [===========================>..] - ETA: 3:28 - rpn_cls: 1.3153 - rpn_regr: 0.1670 - detector_cls: 0.2574 - detector_regr: 0.2064X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0HtmeOUMaGA+02+0087000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 5289
#  967/1000 [============================>.] - ETA: 3:22 - rpn_cls: 1.3196 - rpn_regr: 0.1669 - detector_cls: 0.2574 - detector_regr: 0.2064X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-9Kf0njIktU+02+0064000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 371.52, 'y1': 0.0, 'y2': 320.4}], 'imageset': 'test'}
# index is 5290
#  968/1000 [============================>.] - ETA: 3:16 - rpn_cls: 1.3183 - rpn_regr: 0.1668 - detector_cls: 0.2575 - detector_regr: 0.2064X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2v0dCPbPYbo+00+0022000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 297.6, 'x2': 320.0, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 5291
#  969/1000 [============================>.] - ETA: 3:10 - rpn_cls: 1.3225 - rpn_regr: 0.1672 - detector_cls: 0.2573 - detector_regr: 0.2062X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2iqay12cCJc+01+0110000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 2.8000000800000002, 'y2': 153.999996}], 'imageset': 'test'}
# index is 5292
#  970/1000 [============================>.] - ETA: 3:04 - rpn_cls: 1.3213 - rpn_regr: 0.1672 - detector_cls: 0.2573 - detector_regr: 0.2062X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+26lbSYsxRc4+00+0015000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 73.92, 'x2': 480.0, 'y1': 77.4, 'y2': 360.0}], 'imageset': 'test'}
# index is 5293
#  971/1000 [============================>.] - ETA: 2:58 - rpn_cls: 1.3199 - rpn_regr: 0.1672 - detector_cls: 0.2573 - detector_regr: 0.2062X is (1, 416, 756, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3HRw4jH7bSo+00+0015000+1.jpg', 'width': 640, 'height': 352, 'bboxes': [{'class': 'train', 'x1': 190.72, 'x2': 512.64, 'y1': 0.0, 'y2': 184.8}], 'imageset': 'test'}
# index is 5294
#  972/1000 [============================>.] - ETA: 2:52 - rpn_cls: 1.3185 - rpn_regr: 0.1673 - detector_cls: 0.2577 - detector_regr: 0.2067X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1e8KB4IqkpA+05+0338000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 61.44, 'x2': 443.52000000000004, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 5295
#  973/1000 [============================>.] - ETA: 2:45 - rpn_cls: 1.3172 - rpn_regr: 0.1675 - detector_cls: 0.2577 - detector_regr: 0.2067X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3BQFmqge0Ic+01+0076000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 196.32, 'y1': 118.200006, 'y2': 360.0}], 'imageset': 'test'}
# index is 5296
#  974/1000 [============================>.] - ETA: 2:39 - rpn_cls: 1.3158 - rpn_regr: 0.1676 - detector_cls: 0.2577 - detector_regr: 0.2068X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3kGGyKkX91Q+00+0006000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 256.8, 'x2': 335.52, 'y1': 166.80000239999998, 'y2': 211.79998799999998}], 'imageset': 'test'}
# index is 5297
#  975/1000 [============================>.] - ETA: 2:33 - rpn_cls: 1.3248 - rpn_regr: 0.1676 - detector_cls: 0.2577 - detector_regr: 0.2072X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2HaRwvJEOYA+02+0099000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 470.4, 'y1': 130.20000480000002, 'y2': 285.600006}], 'imageset': 'test'}
# index is 5298
#  976/1000 [============================>.] - ETA: 2:27 - rpn_cls: 1.3234 - rpn_regr: 0.1676 - detector_cls: 0.2578 - detector_regr: 0.2072X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1yhbvw1c9tk+00+0016000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 403.68, 'y1': 0.0, 'y2': 249.59998800000002}], 'imageset': 'test'}
# index is 5299
#  977/1000 [============================>.] - ETA: 2:21 - rpn_cls: 1.3276 - rpn_regr: 0.1675 - detector_cls: 0.2578 - detector_regr: 0.2073X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3BQFmqge0Ic+01+0086000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 174.72, 'y1': 102.6, 'y2': 360.0}], 'imageset': 'test'}
# index is 5300
#  978/1000 [============================>.] - ETA: 2:15 - rpn_cls: 1.3263 - rpn_regr: 0.1674 - detector_cls: 0.2577 - detector_regr: 0.2071X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0IGlkRhZ3N0+00+0011000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 403.2, 'y1': 106.799994, 'y2': 231.599988}], 'imageset': 'test'}
# index is 5301
#  979/1000 [============================>.] - ETA: 2:08 - rpn_cls: 1.3249 - rpn_regr: 0.1673 - detector_cls: 0.2576 - detector_regr: 0.2071X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2X4c-0Ctmmw+03+0074000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 31.200000000000003, 'x2': 306.24, 'y1': 92.39999759999999, 'y2': 306.600012}], 'imageset': 'test'}
# index is 5302
#  980/1000 [============================>.] - ETA: 2:02 - rpn_cls: 1.3247 - rpn_regr: 0.1672 - detector_cls: 0.2576 - detector_regr: 0.2071X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1YNLJVdH2f0+00+0039000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 433.92, 'y1': 127.1999952, 'y2': 342.599994}], 'imageset': 'test'}
# index is 5303
#  981/1000 [============================>.] - ETA: 1:56 - rpn_cls: 1.3242 - rpn_regr: 0.1674 - detector_cls: 0.2577 - detector_regr: 0.2071X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1yhbvw1c9tk+00+0027000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 473.28, 'y1': 0.0, 'y2': 221.4}], 'imageset': 'test'}
# index is 5304
#  982/1000 [============================>.] - ETA: 1:50 - rpn_cls: 1.3228 - rpn_regr: 0.1672 - detector_cls: 0.2580 - detector_regr: 0.2071X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3n21aKPvJ34+00+0059000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 99.83999999999999, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 5305
#  983/1000 [============================>.] - ETA: 1:44 - rpn_cls: 1.3216 - rpn_regr: 0.1671 - detector_cls: 0.2580 - detector_regr: 0.2072X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0oGiHVOz6iY+01+0055000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 83.2, 'x2': 497.92, 'y1': 147.6, 'y2': 257.9999904}], 'imageset': 'test'}
# index is 5306
#  984/1000 [============================>.] - ETA: 1:38 - rpn_cls: 1.3203 - rpn_regr: 0.1672 - detector_cls: 0.2580 - detector_regr: 0.2073X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3bO_hDgvZBc+00+0005000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 310.200012}], 'imageset': 'test'}
# index is 5307
#  985/1000 [============================>.] - ETA: 1:32 - rpn_cls: 1.3189 - rpn_regr: 0.1671 - detector_cls: 0.2580 - detector_regr: 0.2073X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+18Tmu8TY6CM+00+0003000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 848.6400000000001, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 5308
#  986/1000 [============================>.] - ETA: 1:25 - rpn_cls: 1.3176 - rpn_regr: 0.1670 - detector_cls: 0.2581 - detector_regr: 0.2073X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+1IcLjcXfZfI+06+0317000+0.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5309
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0e9fUBlGgu4+00+0120000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5310
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+28DJ1IafNdA+04+0416000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 288.96, 'x2': 469.44, 'y1': 79.2, 'y2': 331.2}], 'imageset': 'test'}
# index is 5311
#  987/1000 [============================>.] - ETA: 1:19 - rpn_cls: 1.3163 - rpn_regr: 0.1671 - detector_cls: 0.2580 - detector_regr: 0.2074X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6dnETcotmM+00+0014000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 464.64, 'x2': 480.0, 'y1': 16.80000012, 'y2': 360.0}], 'imageset': 'test'}
# index is 5312
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6-4soyVvC4+00+0009000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 145.92, 'x2': 282.24, 'y1': 118.80000000000001, 'y2': 256.799988}], 'imageset': 'test'}
# index is 5313
#  988/1000 [============================>.] - ETA: 1:13 - rpn_cls: 1.3150 - rpn_regr: 0.1670 - detector_cls: 0.2580 - detector_regr: 0.2074X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2zRN1VZhBqU+02+0078000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 639.36, 'y1': 0.0, 'y2': 280.8}], 'imageset': 'test'}
# index is 5314
#  989/1000 [============================>.] - ETA: 1:07 - rpn_cls: 1.3137 - rpn_regr: 0.1669 - detector_cls: 0.2579 - detector_regr: 0.2074X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3bO_hDgvZBc+00+0003000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 313.2}], 'imageset': 'test'}
# index is 5315
#  990/1000 [============================>.] - ETA: 1:01 - rpn_cls: 1.3124 - rpn_regr: 0.1668 - detector_cls: 0.2578 - detector_regr: 0.2074X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-wk7J5aKLB4+01+0044000+1.jpg', 'width': 480, 'height': 272, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 354.24, 'y1': 58.93333424, 'y2': 200.3733424}], 'imageset': 'test'}
# index is 5316
#  991/1000 [============================>.] - ETA: 55s - rpn_cls: 1.3161 - rpn_regr: 0.1667 - detector_cls: 0.2578 - detector_regr: 0.2075 X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-6rWDGEKj1g+00+0008000+1.jpg', 'width': 192, 'height': 144, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 192.0, 'y1': 0.0, 'y2': 144.0}], 'imageset': 'test'}
# index is 5317
#  992/1000 [============================>.] - ETA: 49s - rpn_cls: 1.3154 - rpn_regr: 0.1667 - detector_cls: 0.2578 - detector_regr: 0.2075X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+2qs-ClwgZjY+00+0011000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 4.8, 'x2': 297.28000000000003, 'y1': 20.79999984, 'y2': 240.0}], 'imageset': 'test'}
# index is 5318
#  993/1000 [============================>.] - ETA: 43s - rpn_cls: 1.3141 - rpn_regr: 0.1666 - detector_cls: 0.2576 - detector_regr: 0.2074X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0Z2XnkJAIQ8+00+0044000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 144.0, 'x2': 396.47999999999996, 'y1': 61.8000012, 'y2': 220.20001200000002}], 'imageset': 'test'}
# index is 5319
#  994/1000 [============================>.] - ETA: 36s - rpn_cls: 1.3139 - rpn_regr: 0.1668 - detector_cls: 0.2579 - detector_regr: 0.2078X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+3X3-ZoE3yHI+01+0037000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 247.36, 'y1': 64.40000400000001, 'y2': 240.0}], 'imageset': 'test'}
# index is 5320
#  995/1000 [============================>.] - ETA: 30s - rpn_cls: 1.3126 - rpn_regr: 0.1667 - detector_cls: 0.2578 - detector_regr: 0.2077X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0Z2XnkJAIQ8+00+0048000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 116.64, 'x2': 392.15999999999997, 'y1': 37.1999988, 'y2': 253.79999999999998}], 'imageset': 'test'}
# index is 5321
#  996/1000 [============================>.] - ETA: 24s - rpn_cls: 1.3126 - rpn_regr: 0.1668 - detector_cls: 0.2578 - detector_regr: 0.2078X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+0hxGNJtSd80+00+0019000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 304.96, 'y1': 0.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 5322
#  997/1000 [============================>.] - ETA: 18s - rpn_cls: 1.3113 - rpn_regr: 0.1666 - detector_cls: 0.2579 - detector_regr: 0.2078X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+27aLyuHW_Rc+00+0026000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 320.0, 'y1': 24.4000008, 'y2': 239.5999992}], 'imageset': 'test'}
# index is 5323
#  998/1000 [============================>.] - ETA: 12s - rpn_cls: 1.3102 - rpn_regr: 0.1667 - detector_cls: 0.2579 - detector_regr: 0.2078X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+-zrRVj9puac+00+0346000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'train', 'x1': 117.12, 'x2': 238.07999999999998, 'y1': 85.59999599999999, 'y2': 137.1999984}], 'imageset': 'test'}
# index is 5324
#  999/1000 [============================>.] - ETA: 6s - rpn_cls: 1.3174 - rpn_regr: 0.1667 - detector_cls: 0.2578 - detector_regr: 0.2081 X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/train_for_train/15+34vwg15erxM+03+0705000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'train', 'x1': 133.92000000000002, 'x2': 212.64000000000001, 'y1': 162.0, 'y2': 191.400012}], 'imageset': 'test'}
# index is 5325
# 1000/1000 [==============================] - 6139s 6s/step - rpn_cls: 1.3215 - rpn_regr: 0.1668 - detector_cls: 0.2576 - detector_regr: 0.2079
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.486866791744841
# Classifier accuracy for bounding boxes from RPN: 0.88815625
# Loss RPN classifier: 1.3215227761290678
# Loss RPN regression: 0.16684195591742174
# Loss Detector classifier: 0.2575979078246746
# Loss Detector regression: 0.20790954407677054
# Elapsed time: 6140.018355846405
# Total loss decreased from 2.0248867403037094 to 1.9538721839479347, saving weights
# Training complete, exiting.
