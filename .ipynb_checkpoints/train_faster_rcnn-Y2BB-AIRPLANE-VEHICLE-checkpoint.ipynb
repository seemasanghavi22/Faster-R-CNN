# %% [markdown]
# ## Faster R-CNN Training for YTBB AirPlane Class - using Pretrained ResNet50

# %%
from __future__ import division
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import re
import pandas as pd

# %%
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input
from keras.models import Model
from keras_frcnn import config, data_generators
from keras_frcnn import losses as losses
import keras_frcnn.roi_helpers as roi_helpers
from keras.utils import generic_utils
sys.setrecursionlimit(40000)
# Out:
# Using TensorFlow backend.

# %%
from keras_frcnn.simple_parser import get_data
from keras_frcnn import resnet as nn

# %% [markdown]
# #### Specify the config

# %%
# Create a config object and set the values
C = config.Config()
firstTraining = True

C.use_horizontal_flips = bool(False)
C.use_vertical_flips = bool(False)
C.rot_90 = bool(False)
C.model_path = './y2bb_model_frcnn_airplane_vehicle_v1.hdf5'
C.verbose = True
model_path_regex = re.match("^(.+)(\.hdf5)$", C.model_path)
if model_path_regex.group(2) != '.hdf5':
	print('Output weights must have .hdf5 filetype')
	exit(1)
C.num_rois = int(32)
C.network = 'resnet50'
if firstTraining is True:
    C.base_net_weights = nn.get_weight_path()
    firstTraining = False
else:
    C.base_net_weights = options.input_weight_path
config_output_filename = "y2bb_config_airplane.pickle"
#train_path = './annotate.txt'
#train_path = 'COCO_extracted_dataset/airplane_for_train/coco_airplane_annotate.txt'
train_path = 'y2bb_training_airplane_annotate.txt'
val_path = 'y2bb_validation_airplane_annotate.txt'

# %% [markdown]
# #### Load the training images using annotation file (created post data preprocessing)

# %%
train_imgs, classes_count, class_mapping = get_data(train_path)
val_imgs, _, _ = get_data(val_path)

if 'bg' not in classes_count:
	classes_count['bg'] = 0
	class_mapping['bg'] = len(class_mapping)

C.class_mapping = class_mapping
inv_map = {v: k for k, v in class_mapping.items()}

print('Training images per class:')
pprint.pprint(classes_count)
print(f'Num classes (including bg) = {len(classes_count)}')
# Out:
# Parsing annotation files
# Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).
# Parsing annotation files
# Training images per class:
# {'airplane': 950, 'bg': 50}
# Num classes (including bg) = 2

# %%
train_imgs
# Out:
# [{'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1RvBx5Yo1Q4+01+0063000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 132.95999999999998,
#     'x2': 303.84000000000003,
#     'y1': 160.79999759999998,
#     'y2': 211.19999040000002}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2qK8HB73HhY+04+0079000+1.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2': 1280.0,
#     'y1': 159.5999952,
#     'y2': 649.1999807999999}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+243BzpfsPpo+00+0028000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 253.44,
#     'x2': 398.4,
#     'y1': 141.0000048,
#     'y2': 187.20000000000002}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-6UiTYUvEiA+00+0029000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 16.2,
#     'y2': 228.6}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3ITHoJbfmaI+01+0261000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 334.08,
#     'x2': 412.32000000000005,
#     'y1': 97.8000048,
#     'y2': 138.6}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2uP2LM9Xu7U+00+0014000+1.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 244.48000000000002,
#     'x2': 478.08,
#     'y1': 90.6000012,
#     'y2': 195.600006}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3XmgCmmT3q4+02+0081000+1.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'airplane',
#     'x1': 122.88,
#     'x2': 1162.2399999999998,
#     'y1': 100.80000000000001,
#     'y2': 461.99998800000003}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-59Rg6_4eVo+01+0108000+1.jpg',
#   'width': 320,
#   'height': 240,
#   'bboxes': [{'class': 'airplane',
#     'x1': 62.07999999999999,
#     'x2': 284.16,
#     'y1': 80.4,
#     'y2': 149.5999992}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2GhhyUtXbjA+00+0210000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 0.0,
#     'y2': 288.600012}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-_kdoJRFXO0+00+0001000+1.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2':
0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_validation/13+0YTXqyJMq8Q+02+0033000+1.jpg',
#   'width': 1280,
#   'height': 720,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2': 1280.0,
#     'y1': 36.0,
#     'y2': 720.0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_validation/13+2LzlaZoD1xE+00+0125000+1.jpg',
#   'width': 320,
#   'height': 240,
#   'bboxes': [{'class': 'airplane',
#     'x1': 25.6,
#     'x2': 299.52,
#     'y1': 78.800004,
#     'y2': 160.00000799999998}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_validation/13+-BjkgIoZjWg+00+0018000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 108.96,
#     'x2': 458.4,
#     'y1': 101.4000012,
#     'y2': 229.79998800000004}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_validation/13+2BS1xf5tnfI+01+0059000+1.jpg',
#   'width': 480,
#   'height': 360,
#   'bboxes': [{'class': 'airplane',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 32.4,
#     'y2': 360.0}],
#   'imageset': 'test'},
#  {'filepath': 'Y2BB_extracted_dataset/airplane_for_validation/13+2u7Fjf6OFRQ+00+0177000+1.jpg',
#   'width': 480,
#   'height': 320,
#   'bboxes': [{'class': 'airplane',
#     'x1': 90.71999999999998,
#     'x2': 474.24,
#     'y1': 105.60000000000001,
#     'y2': 224.0}],
#   'imageset': 'test'}]

# %%
class_mapping
# Out:
# {'airplane': 0, 'bg': 1}

# %% [markdown]
# #### Save model weights path and config

# %%
with open(config_output_filename, 'wb') as config_f:
	pickle.dump(C,config_f)
	print(f'Config has been written to {config_output_filename}, and can be loaded when testing to ensure correct results')

#random.shuffle(train_imgs)

num_imgs = len(train_imgs)
print(f'Num train samples {len(train_imgs)}')
print(f'Num val samples {len(val_imgs)}')
# Out:
# Config has been written to y2bb_config_airplane.pickle, and can be loaded when testing to ensure correct results
# Num train samples 1000
# Num val samples 200

# %% [markdown]
# #### Training Setup - Faster R-CNN model initialization

# %%
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, C, nn.get_img_output_length, K.common.image_dim_ordering(), mode='train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn.get_img_output_length,K.common.image_dim_ordering(), mode='val')

# %%
data_gen_train
# Out:
# <generator object get_anchor_gt at 0x0000023EE4D24410>

# %%
data_gen_val
# Out:
# <generator object get_anchor_gt at 0x0000023EE4D244C0>

# %%
if K.common.image_dim_ordering() == 'th':
	input_shape_img = (3, None, None)
else:
	input_shape_img = (None, None, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))

# %%
img_input
# Out:
# <tf.Tensor 'input_1:0' shape=(None, None, None, 3) dtype=float32>

# %%
roi_input
# Out:
# <tf.Tensor 'input_2:0' shape=(None, None, 4) dtype=float32>

# %%
# define the base network (resnet here, can be VGG, Inception, etc)
shared_layers = nn.nn_base(img_input, trainable=True)
shared_layers
# Out:
# <tf.Tensor 'activation_40/Relu:0' shape=(None, None, None, 1024) dtype=float32>

# %%
C.anchor_box_scales
# Out:
# [128, 256, 512]

# %%
C.anchor_box_ratios
# Out:
# [[1, 1],
#  [0.7071067811865475, 1.414213562373095],
#  [1.414213562373095, 0.7071067811865475]]

# %%
# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
num_anchors
# Out:
# 9

# %%
rpn = nn.rpn(shared_layers, num_anchors)
rpn
# Out:
# [<tf.Tensor 'rpn_out_class/Sigmoid:0' shape=(None, None, None, 9) dtype=float32>,
#  <tf.Tensor 'rpn_out_regress/BiasAdd:0' shape=(None, None, None, 36) dtype=float32>,
#  <tf.Tensor 'activation_40/Relu:0' shape=(None, None, None, 1024) dtype=float32>]

# %%
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)
classifier
# Out:
# [<tf.Tensor 'dense_class_2/Reshape_1:0' shape=(1, 32, 2) dtype=float32>,
#  <tf.Tensor 'dense_regress_2/Reshape_1:0' shape=(1, 32, 4) dtype=float32>]

# %%
model_rpn = Model(img_input, rpn[:2])
model_rpn.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier = Model([img_input, roi_input], classifier)
model_classifier.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)
model_all.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
try:
	print('loading weights from {C.base_net_weights}')
	model_rpn.load_weights(C.base_net_weights, by_name=True)
	model_classifier.load_weights(C.base_net_weights, by_name=True)    
	#model_rpn.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
	#model_classifier.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
except:
	print('Could not load pretrained model weights. Weights can be found in the keras application folder \
		https://github.com/fchollet/keras/tree/master/keras/applications')
# Out:
# loading weights from {C.base_net_weights}

# %%
optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={f'dense_class_{len(classes_count)}': 'accuracy'})
model_all.compile(optimizer='sgd', loss='mae')

# %%
model_rpn.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
model_all.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 2 0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 2 0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 5 0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 5 0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 5 0           add_7[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 1 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, None, None, 1 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, None, None, 1 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, None, None, 1 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, None, None, 1 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, None, None, 1 0           add_13[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_1 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_40[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 7, 7, 204 0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 7, 7, 204 0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 7, 7, 204 0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_49[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_1[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %% [markdown]
# #### Faster R-CNN model Training - 5 Epochs

# %%
#number of images in the dataset
epoch_length = 1000 
num_epochs = int(5)
iter_num = 0

# %%
losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
start_time = time.time()

best_loss = np.Inf

# %%
class_mapping_inv = {v: k for k, v in class_mapping.items()}
print('Starting training')

vis = True
index = 0
# Out:
# Starting training

# %%
for epoch_num in range(num_epochs):

	progbar = generic_utils.Progbar(epoch_length)
	print(f'Epoch {epoch_num + 1}/{num_epochs}')

	while True:
		try:

			if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
				mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
				rpn_accuracy_rpn_monitor = []
				print(f'Average number of overlapping bounding boxes from RPN = {mean_overlapping_bboxes} for {epoch_length} previous iterations')
				if mean_overlapping_bboxes == 0:
					print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

			X, Y, img_data = next(data_gen_train)
			print(f'X is {X.shape}')
			print(f'Y is {len(Y)}')
			print(f'img_data is {img_data}')
			print(f'index is {index}')
			index = index + 1

			loss_rpn = model_rpn.train_on_batch(X, Y)

			P_rpn = model_rpn.predict_on_batch(X)

			R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.common.image_dim_ordering(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
			# note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
			X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

			if X2 is None:
				rpn_accuracy_rpn_monitor.append(0)
				rpn_accuracy_for_epoch.append(0)
				continue

			neg_samples = np.where(Y1[0, :, -1] == 1)
			pos_samples = np.where(Y1[0, :, -1] == 0)

			if len(neg_samples) > 0:
				neg_samples = neg_samples[0]
			else:
				neg_samples = []

			if len(pos_samples) > 0:
				pos_samples = pos_samples[0]
			else:
				pos_samples = []
			
			rpn_accuracy_rpn_monitor.append(len(pos_samples))
			rpn_accuracy_for_epoch.append((len(pos_samples)))

			if C.num_rois > 1:
				if len(pos_samples) < C.num_rois//2:
					selected_pos_samples = pos_samples.tolist()
				else:
					selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
				try:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
				except:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

				sel_samples = selected_pos_samples + selected_neg_samples
			else:
				# in the extreme case where num_rois = 1, we pick a random pos or neg sample
				selected_pos_samples = pos_samples.tolist()
				selected_neg_samples = neg_samples.tolist()
				if np.random.randint(0, 2):
					sel_samples = random.choice(neg_samples)
				else:
					sel_samples = random.choice(pos_samples)

			loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

			losses[iter_num, 0] = loss_rpn[1]
			losses[iter_num, 1] = loss_rpn[2]

			losses[iter_num, 2] = loss_class[1]
			losses[iter_num, 3] = loss_class[2]
			losses[iter_num, 4] = loss_class[3]

			progbar.update(iter_num+1, [('rpn_cls', losses[iter_num, 0]), ('rpn_regr', losses[iter_num, 1]),
									  ('detector_cls', losses[iter_num, 2]), ('detector_regr', losses[iter_num, 3])])

			iter_num += 1
			
			if iter_num == epoch_length:
				loss_rpn_cls = np.mean(losses[:, 0])
				loss_rpn_regr = np.mean(losses[:, 1])
				loss_class_cls = np.mean(losses[:, 2])
				loss_class_regr = np.mean(losses[:, 3])
				class_acc = np.mean(losses[:, 4])

				mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
				rpn_accuracy_for_epoch = []

				if C.verbose:
					print(f'Mean number of bounding boxes from RPN overlapping ground truth boxes: {mean_overlapping_bboxes}')
					print(f'Classifier accuracy for bounding boxes from RPN: {class_acc}')
					print(f'Loss RPN classifier: {loss_rpn_cls}')
					print(f'Loss RPN regression: {loss_rpn_regr}')
					print(f'Loss Detector classifier: {loss_class_cls}')
					print(f'Loss Detector regression: {loss_class_regr}')
					print(f'Elapsed time: {time.time() - start_time}')

				curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
				iter_num = 0
				start_time = time.time()

				if curr_loss < best_loss:
					if C.verbose:
						print(f'Total loss decreased from {best_loss} to {curr_loss}, saving weights')
					best_loss = curr_loss
				model_all.save_weights(model_path_regex.group(1) + "_" + '{:04d}'.format(epoch_num) + model_path_regex.group(2))

				break

		except Exception as e:
			print(f'Exception: {e}')
			continue

print('Training complete, exiting.')
# Out:
# Epoch 1/5
# X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1xLDkTOw4SU+00+0012000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 152.95999999999998, 'x2': 515.2, 'y1': 115.2, 'y2': 264.000006}], 'imageset': 'test'}
# index is 0
#    1/1000 [..............................] - ETA: 10:56:26 - rpn_cls: 6.4551 - rpn_regr: 0.0657 - detector_cls: 0.6931 - detector_regr: 0.2754X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2yH3VzXWIZ8+02+0034000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 37.92, 'x2': 480.0, 'y1': 71.4000024, 'y2': 307.8}], 'imageset': 'test'}
# index is 1
#    2/1000 [..............................] - ETA: 6:02:25 - rpn_cls: 5.2732 - rpn_regr: 0.2795 - detector_cls: 0.6900 - detector_regr: 0.3498 X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0tNY3s9iemE+00+0007000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 2
#    3/1000 [..............................] - ETA: 4:26:40 - rpn_cls: 4.9631 - rpn_regr: 0.1980 - detector_cls: 0.6871 - detector_regr: 0.4310X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2lFrVWGxDws+00+0012000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 203.51999999999998, 'x2': 288.48, 'y1': 201.0000024, 'y2': 237.60000000000002}], 'imageset': 'test'}
# index is 3
#    4/1000 [..............................] - ETA: 3:35:50 - rpn_cls: 4.8049 - rpn_regr: 0.3133 - detector_cls: 0.6813 - detector_regr: 0.3233X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0NTjZPBvH_8+04+0824000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 640.0, 'y1': 100.20000239999999, 'y2': 360.0}], 'imageset': 'test'}
# index is 4
#    5/1000 [..............................] - ETA: 3:10:14 - rpn_cls: 5.1375 - rpn_regr: 0.2637 - detector_cls: 0.6775 - detector_regr: 0.3312X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3C-L6xGSJAc+03+0196000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 29.119999999999997, 'x2': 303.68, 'y1': 76.39999920000001, 'y2': 151.2}], 'imageset': 'test'}
# index is 5
#    6/1000 [..............................] - ETA: 2:52:06 - rpn_cls: 5.2699 - rpn_regr: 0.2575 - detector_cls: 0.6748 - detector_regr: 0.3737X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0YTXqyJMq8Q+02+0037000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 21.599999999999998, 'y2': 720.0}], 'imageset': 'test'}
# index is 6
#    7/1000 [..............................] - ETA: 2:40:48 - rpn_cls: 5.8611 - rpn_regr: 0.2239 - detector_cls: 0.6692 - detector_regr: 0.3689X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1BdIJqoJ5Kw+01+0044000+1.jpg', 'width': 384, 'height': 216, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 237.312, 'y1': 88.19999928, 'y2': 144.3600036}], 'imageset': 'test'}
# index is 7
#    8/1000 [..............................] - ETA: 2:34:19 - rpn_cls: 5.6621 - rpn_regr: 0.2278 - detector_cls: 0.6630 - detector_regr: 0.3228X is (1, 416, 605, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0bcMjuRPvb0+00+0146000+1.jpg', 'width': 524, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 524.0, 'y1': 57.6, 'y2': 360.0}], 'imageset': 'test'}
# index is 8
#    9/1000 [..............................] - ETA: 2:28:55 - rpn_cls: 5.4525 - rpn_regr: 0.2820 - detector_cls: 0.6624 - detector_regr: 0.3496X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-FOKM9iC1Io+00+0226000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 9
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3C-L6xGSJAc+00+0002000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 50.24, 'x2': 261.76, 'y1': 64.0000032, 'y2': 149.5999992}], 'imageset': 'test'}
# index is 10
#   10/1000 [..............................] - ETA: 2:26:27 - rpn_cls: 5.3080 - rpn_regr: 0.2618 - detector_cls: 0.6602 - detector_regr: 0.3536X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+00sYiYGq1NE+01+0462000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 231.04, 'y1': 137.59999200000001, 'y2': 240.0}], 'imageset': 'test'}
# index is 11
#   11/1000 [..............................] - ETA: 2:21:44 - rpn_cls: 5.4296 - rpn_regr: 0.2406 - detector_cls: 0.6591 - detector_regr: 0.3701X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3aXicex8wfQ+01+0205000+0.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 12
# X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1S0VogIg4xo+00+0041000+1.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'airplane', 'x1': 144.48, 'x2': 332.64, 'y1': 115.19999999999999, 'y2': 203.7333312}], 'imageset': 'test'}
# index is 13
#   12/1000 [..............................] - ETA: 2:21:12 - rpn_cls: 5.3799 - rpn_regr: 0.2353 - detector_cls: 0.6508 - detector_regr: 0.3900X is (1, 416, 743, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3d_asaW0ugw+00+0032000+1.jpg', 'width': 640, 'height': 358, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 243.2, 'y1': 152.15, 'y2': 265.5166786}], 'imageset': 'test'}
# index is 14
#   13/1000 [..............................] - ETA: 2:18:41 - rpn_cls: 5.2666 - rpn_regr: 0.2301 - detector_cls: 0.6443 - detector_regr: 0.3984X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+03+0230000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 384.0, 'y1': 76.80000384, 'y2': 185.76}], 'imageset': 'test'}
# index is 15
#   14/1000 [..............................] - ETA: 2:14:55 - rpn_cls: 5.2403 - rpn_regr: 0.2296 - detector_cls: 0.6380 - detector_regr: 0.4100X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-lxhXRXXvzc+00+1064000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 227.51999999999998, 'x2': 475.2, 'y1': 193.80000959999998, 'y2': 262.8}], 'imageset': 'test'}
# index is 16
#   15/1000 [..............................] - ETA: 2:11:57 - rpn_cls: 4.9994 - rpn_regr: 0.2331 - detector_cls: 0.6286 - detector_regr: 0.4244X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3HKYAxj4igw+00+0161000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 139.5, 'x2': 395.1, 'y1': 131.4, 'y2': 217.200006}], 'imageset': 'test'}
# index is 17
#   16/1000 [..............................] - ETA: 2:09:11 - rpn_cls: 4.9774 - rpn_regr: 0.2368 - detector_cls: 0.6208 - detector_regr: 0.4370X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3XmgCmmT3q4+00+0204000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 176.4, 'y2': 481.200012}], 'imageset': 'test'}
# index is 18
#   17/1000 [..............................] - ETA: 2:07:40 - rpn_cls: 4.7773 - rpn_regr: 0.2408 - detector_cls: 0.6062 - detector_regr: 0.4439X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2Io7AhRN7IE+03+0353000+1.jpg', 'width': 320, 'height': 180, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 298.88, 'y1': 35.7000012, 'y2': 173.9999952}], 'imageset': 'test'}
# index is 19
#   18/1000 [..............................] - ETA: 2:06:55 - rpn_cls: 4.7567 - rpn_regr: 0.2297 - detector_cls: 0.6050 - detector_regr: 0.4479X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3XmgCmmT3q4+00+0196000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 148.7999952, 'y2': 488.40000480000003}], 'imageset': 'test'}
# index is 20
#   19/1000 [..............................] - ETA: 2:05:38 - rpn_cls: 4.6957 - rpn_regr: 0.2311 - detector_cls: 0.5956 - detector_regr: 0.4495X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+26Zcpo240Do+00+0028000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 75.648, 'x2': 339.84000000000003, 'y1': 32.159999232, 'y2': 115.68000096}], 'imageset': 'test'}
# index is 21
#   20/1000 [..............................] - ETA: 2:03:38 - rpn_cls: 4.7122 - rpn_regr: 0.2266 - detector_cls: 0.5910 - detector_regr: 0.4535X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-UmHNz8mlbk+08+0091000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 2.4, 'x2': 473.76, 'y1': 78.5999988, 'y2': 238.80000959999998}], 'imageset': 'test'}
# index is 22
#   21/1000 [..............................] - ETA: 2:01:44 - rpn_cls: 4.7671 - rpn_regr: 0.2252 - detector_cls: 0.5852 - detector_regr: 0.4552X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1mncUKMFWmk+00+0009000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 43.776, 'x2': 307.58399999999995, 'y1': 126.23999904, 'y2': 195.36000192}], 'imageset': 'test'}
# index is 23
#   22/1000 [..............................] - ETA: 1:59:36 - rpn_cls: 4.7186 - rpn_regr: 0.2278 - detector_cls: 0.5804 - detector_regr: 0.4551X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+29GvhbXmKqA+00+0151000+1.jpg', 'width': 240, 'height': 180, 'bboxes': [{'class': 'airplane', 'x1': 21.599999999999998, 'x2': 41.76, 'y1': 60.6000006, 'y2': 66.6}], 'imageset': 'test'}
# index is 24
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-59Rg6_4eVo+01+0117000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 16.96, 'x2': 273.92, 'y1': 69.1999992, 'y2': 156.3999936}], 'imageset': 'test'}
# index is 25
#   23/1000 [..............................] - ETA: 1:59:06 - rpn_cls: 4.6687 - rpn_regr: 0.2228 - detector_cls: 0.5855 - detector_regr: 0.4486X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2hPqjpdQqv0+00+0003000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 155.03999999999996, 'x2': 234.72, 'y1': 73.8, 'y2': 124.19999999999999}], 'imageset': 'test'}
# index is 26
#   24/1000 [..............................] - ETA: 1:57:41 - rpn_cls: 4.5692 - rpn_regr: 0.2355 - detector_cls: 0.5664 - detector_regr: 0.4299X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+387cy_uwVUk+00+0127000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 188.16, 'x2': 1280.0, 'y1': 2.400000048, 'y2': 720.0}], 'imageset': 'test'}
# index is 27
#   25/1000 [..............................] - ETA: 1:57:06 - rpn_cls: 4.5838 - rpn_regr: 0.2293 - detector_cls: 0.5738 - detector_regr: 0.4343X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0O-YR5X6xm4+00+0064000+1.jpg', 'width': 192, 'height': 144, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 148.224, 'y1': 46.800000000000004, 'y2': 97.68000096}], 'imageset': 'test'}
# index is 28
#   26/1000 [..............................] - ETA: 1:55:53 - rpn_cls: 4.5056 - rpn_regr: 0.2243 - detector_cls: 0.5815 - detector_regr: 0.4313X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+27VSNN9fnvs+01+0042000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 94.08, 'x2': 432.96000000000004, 'y1': 27.0, 'y2': 179.39999880000002}], 'imageset': 'test'}
# index is 29
#   27/1000 [..............................] - ETA: 1:54:55 - rpn_cls: 4.4348 - rpn_regr: 0.2169 - detector_cls: 0.6045 - detector_regr: 0.4308X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3rdS6OiSgDQ+01+0053000+1.jpg', 'width': 480, 'height': 270, 'bboxes': [{'class': 'airplane', 'x1': 108.96, 'x2': 342.72, 'y1': 176.399991, 'y2': 235.7999991}], 'imageset': 'test'}
# index is 30
#   28/1000 [..............................] - ETA: 1:54:23 - rpn_cls: 4.2873 - rpn_regr: 0.2182 - detector_cls: 0.5998 - detector_regr: 0.4347X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2fADgRcGugQ+05+0402000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 293.12, 'x2': 1048.3200000000002, 'y1': 390.00002399999994, 'y2': 622.8}], 'imageset': 'test'}
# index is 31
#   29/1000 [..............................] - ETA: 1:54:14 - rpn_cls: 4.2820 - rpn_regr: 0.2140 - detector_cls: 0.6001 - detector_regr: 0.4314X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3V_tgGdzXbc+00+0179000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 442.88000000000005, 'x2': 1241.6, 'y1': 244.8, 'y2': 422.39998080000004}], 'imageset': 'test'}
# index is 32
#   30/1000 [..............................] - ETA: 1:53:46 - rpn_cls: 4.1674 - rpn_regr: 0.2159 - detector_cls: 0.5857 - detector_regr: 0.4170X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2fADgRcGugQ+00+0003000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 815.36, 'x2': 1218.5600000000002, 'y1': 340.7999976, 'y2': 477.60001919999996}], 'imageset': 'test'}
# index is 33
#   31/1000 [..............................] - ETA: 1:53:29 - rpn_cls: 4.1002 - rpn_regr: 0.2120 - detector_cls: 0.5755 - detector_regr: 0.4115X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+31HB-qD50C0+02+0098000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 3.3599999999999994, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 34
#   32/1000 [..............................] - ETA: 1:52:49 - rpn_cls: 3.9900 - rpn_regr: 0.2317 - detector_cls: 0.5764 - detector_regr: 0.4149X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+01MT_gjQLlY+01+0130000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 480.0, 'y1': 57.6, 'y2': 283.20001199999996}], 'imageset': 'test'}
# index is 35
#   33/1000 [..............................] - ETA: 1:52:06 - rpn_cls: 4.0034 - rpn_regr: 0.2364 - detector_cls: 0.5707 - detector_regr: 0.4137X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+15alnxl-7HY+00+0217000+1.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'airplane', 'x1': 24.479999999999997, 'x2': 480.0, 'y1': 119.4666656, 'y2': 320.0}], 'imageset': 'test'}
# index is 36
#   34/1000 [>.............................] - ETA: 1:51:46 - rpn_cls: 3.9282 - rpn_regr: 0.2432 - detector_cls: 0.5667 - detector_regr: 0.4135X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3KN2LOgN9kU+00+0186000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 478.72, 'x2': 1120.0, 'y1': 254.3999904, 'y2': 444.00002399999994}], 'imageset': 'test'}
# index is 37
#   35/1000 [>.............................] - ETA: 1:51:23 - rpn_cls: 3.9561 - rpn_regr: 0.2418 - detector_cls: 0.5597 - detector_regr: 0.4140X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2IAmlmIl82A+00+0012000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 96.0000048, 'y2': 572.4}], 'imageset': 'test'}
# index is 38
#   36/1000 [>.............................] - ETA: 1:51:11 - rpn_cls: 3.9550 - rpn_regr: 0.2385 - detector_cls: 0.5583 - detector_regr: 0.4124X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3EnEuf4BleM+00+0009000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 15.36, 'x2': 1280.0, 'y1': 240.00000479999997, 'y2': 511.2}], 'imageset': 'test'}
# index is 39
#   37/1000 [>.............................] - ETA: 1:51:01 - rpn_cls: 3.8501 - rpn_regr: 0.2441 - detector_cls: 0.5489 - detector_regr: 0.4012X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0NTjZPBvH_8+03+0805000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 40
#   38/1000 [>.............................] - ETA: 1:50:41 - rpn_cls: 3.8359 - rpn_regr: 0.2386 - detector_cls: 0.5481 - detector_regr: 0.4061X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0ZFstBk2zS0+00+0021000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 72.96000000000001, 'x2': 1280.0, 'y1': 111.6, 'y2': 624.0000239999999}], 'imageset': 'test'}
# index is 41
#   39/1000 [>.............................] - ETA: 1:50:36 - rpn_cls: 3.8074 - rpn_regr: 0.2343 - detector_cls: 0.5489 - detector_regr: 0.4054X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1SSDgFOhVkE+00+0031000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 46.080000000000005, 'x2': 1246.72, 'y1': 234.0, 'y2': 490.80002399999995}], 'imageset': 'test'}
# index is 42
#   40/1000 [>.............................] - ETA: 1:50:17 - rpn_cls: 3.7516 - rpn_regr: 0.2386 - detector_cls: 0.5458 - detector_regr: 0.4131X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+24DG7rPMmlQ+01+0035000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 84.48, 'x2': 480.0, 'y1': 31.7999988, 'y2': 170.3999988}], 'imageset': 'test'}
# index is 43
#   41/1000 [>.............................] - ETA: 1:49:41 - rpn_cls: 3.7213 - rpn_regr: 0.2348 - detector_cls: 0.5482 - detector_regr: 0.4107X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0h_pwJXQsc0+00+0190000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 222.23999999999998, 'x2': 480.0, 'y1': 76.8000024, 'y2': 192.0000096}], 'imageset': 'test'}
# index is 44
#   42/1000 [>.............................] - ETA: 1:49:09 - rpn_cls: 3.6356 - rpn_regr: 0.2334 - detector_cls: 0.5475 - detector_regr: 0.4100X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2DlJt40pLx4+00+0064000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 304.96, 'y1': 108.0, 'y2': 240.0}], 'imageset': 'test'}
# index is 45
#   43/1000 [>.............................] - ETA: 1:48:31 - rpn_cls: 3.5582 - rpn_regr: 0.2336 - detector_cls: 0.5485 - detector_regr: 0.4098X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+01MT_gjQLlY+00+0008000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 28.799999999999997, 'x2': 406.08, 'y1': 94.7999952, 'y2': 215.4000096}], 'imageset': 'test'}
# index is 46
#   44/1000 [>.............................] - ETA: 1:48:04 - rpn_cls: 3.5695 - rpn_regr: 0.2301 - detector_cls: 0.5469 - detector_regr: 0.4054X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-0oOCh2swmU+00+0023000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 480.0, 'y1': 77.4, 'y2': 271.1999988}], 'imageset': 'test'}
# index is 47
#   45/1000 [>.............................] - ETA: 1:47:29 - rpn_cls: 3.5039 - rpn_regr: 0.2316 - detector_cls: 0.5496 - detector_regr: 0.4080X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2Io7AhRN7IE+02+0301000+1.jpg', 'width': 320, 'height': 180, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 315.84, 'y1': 40.8000006, 'y2': 180.0}], 'imageset': 'test'}
# index is 48
#   46/1000 [>.............................] - ETA: 1:47:16 - rpn_cls: 3.5043 - rpn_regr: 0.2274 - detector_cls: 0.5487 - detector_regr: 0.4085X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-ZRXNJQXEM4+00+0350000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 128.16, 'x2': 207.36, 'y1': 149.9999976, 'y2': 173.9999952}], 'imageset': 'test'}
# index is 49
#   47/1000 [>.............................] - ETA: 1:46:50 - rpn_cls: 3.6057 - rpn_regr: 0.2429 - detector_cls: 0.5406 - detector_regr: 0.3998X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1oqDzceXOOM+02+0100000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 431.04, 'y1': 0.0, 'y2': 264.6}], 'imageset': 'test'}
# index is 50
#   48/1000 [>.............................] - ETA: 1:46:20 - rpn_cls: 3.5392 - rpn_regr: 0.2467 - detector_cls: 0.5417 - detector_regr: 0.4009X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-Y0QOovFqIQ+00+0005000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 133.12, 'x2': 981.76, 'y1': 173.9999952, 'y2': 468.0}], 'imageset': 'test'}
# index is 51
#   49/1000 [>.............................] - ETA: 1:46:24 - rpn_cls: 3.5109 - rpn_regr: 0.2441 - detector_cls: 0.5421 - detector_regr: 0.3999X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3EtJwCepvxI+01+0079000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 88.96000000000001, 'x2': 640.0, 'y1': 40.19999904, 'y2': 253.79999999999998}], 'imageset': 'test'}
# index is 52
#   50/1000 [>.............................] - ETA: 1:46:26 - rpn_cls: 3.5428 - rpn_regr: 0.2424 - detector_cls: 0.5400 - detector_regr: 0.3997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2jUked788ts+01+0310000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 99.36, 'x2': 455.52000000000004, 'y1': 118.200006, 'y2': 283.8000096}], 'imageset': 'test'}
# index is 53
#   51/1000 [>.............................] - ETA: 1:46:09 - rpn_cls: 3.4913 - rpn_regr: 0.2385 - detector_cls: 0.5406 - detector_regr: 0.3986X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2e22m-Fnpos+00+0007000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 139.52, 'x2': 1047.04, 'y1': 181.2000024, 'y2': 507.59999999999997}], 'imageset': 'test'}
# index is 54
#   52/1000 [>.............................] - ETA: 1:46:13 - rpn_cls: 3.4723 - rpn_regr: 0.2367 - detector_cls: 0.5409 - detector_regr: 0.3983X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+22zkjrDUOt0+02+0040000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 124.80000000000001, 'x2': 381.12, 'y1': 128.399994, 'y2': 204.59998800000002}], 'imageset': 'test'}
# index is 55
#   53/1000 [>.............................] - ETA: 1:45:47 - rpn_cls: 3.5086 - rpn_regr: 0.2375 - detector_cls: 0.5338 - detector_regr: 0.3908X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+02+0204000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 27.263999999999996, 'x2': 383.61600000000004, 'y1': 72.95999904000001, 'y2': 151.20000000000002}], 'imageset': 'test'}
# index is 56
#   54/1000 [>.............................] - ETA: 1:45:25 - rpn_cls: 3.4600 - rpn_regr: 0.2387 - detector_cls: 0.5319 - detector_regr: 0.3919X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-trkGYFubZg+00+0027000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 134.4, 'x2': 1280.0, 'y1': 1.200000024, 'y2': 219.6}], 'imageset': 'test'}
# index is 57
#   55/1000 [>.............................] - ETA: 1:45:23 - rpn_cls: 3.4202 - rpn_regr: 0.2429 - detector_cls: 0.5318 - detector_regr: 0.3945X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2if5LkgSn1M+00+0024000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 1.28, 'x2': 1280.0, 'y1': 167.9999976, 'y2': 558.0}], 'imageset': 'test'}
# index is 58
#   56/1000 [>.............................] - ETA: 1:45:09 - rpn_cls: 3.3672 - rpn_regr: 0.2415 - detector_cls: 0.5314 - detector_regr: 0.3942X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+36ymO829OaU+02+0524000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 419.04, 'y1': 9.0, 'y2': 250.79999759999998}], 'imageset': 'test'}
# index is 59
#   57/1000 [>.............................] - ETA: 1:44:50 - rpn_cls: 3.3264 - rpn_regr: 0.2427 - detector_cls: 0.5376 - detector_regr: 0.3971X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-ShQJFe8sX8+00+0014000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 320.0, 'y1': 0.0, 'y2': 142.39999200000003}], 'imageset': 'test'}
# index is 60
#   58/1000 [>.............................] - ETA: 1:44:22 - rpn_cls: 3.2846 - rpn_regr: 0.2443 - detector_cls: 0.5388 - detector_regr: 0.3978X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3Bk1DMmrwKM+00+0120000+1.jpg', 'width': 540, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 55.08, 'x2': 490.86, 'y1': 120.00000239999999, 'y2': 246.60000000000002}], 'imageset': 'test'}
# index is 61
#   59/1000 [>.............................] - ETA: 1:44:02 - rpn_cls: 3.2367 - rpn_regr: 0.2420 - detector_cls: 0.5387 - detector_regr: 0.3956X is (1, 416, 693, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0ub04dbwo6w+00+0016000+1.jpg', 'width': 600, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 5.4, 'x2': 478.20000000000005, 'y1': 39.6, 'y2': 291.6}], 'imageset': 'test'}
# index is 62
#   60/1000 [>.............................] - ETA: 1:43:56 - rpn_cls: 3.2202 - rpn_regr: 0.2468 - detector_cls: 0.5396 - detector_regr: 0.3948X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0PTC_VWdxpE+00+0004000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 19.2, 'x2': 296.96, 'y1': 26.00000016, 'y2': 185.599992}], 'imageset': 'test'}
# index is 63
#   61/1000 [>.............................] - ETA: 1:43:28 - rpn_cls: 3.2256 - rpn_regr: 0.2498 - detector_cls: 0.5443 - detector_regr: 0.3987X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2dWblBkkccA+00+0020000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 297.0}], 'imageset': 'test'}
# index is 64
#   62/1000 [>.............................] - ETA: 1:43:23 - rpn_cls: 3.1811 - rpn_regr: 0.2460 - detector_cls: 0.5448 - detector_regr: 0.3983X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3C-L6xGSJAc+03+0194000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 17.919999999999998, 'x2': 293.12, 'y1': 84.3999984, 'y2': 158.0000064}], 'imageset': 'test'}
# index is 65
#   63/1000 [>.............................] - ETA: 1:43:02 - rpn_cls: 3.1311 - rpn_regr: 0.2445 - detector_cls: 0.5435 - detector_regr: 0.3965X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-nX6RRE92SY+00+0012000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 216.95999999999998, 'x2': 437.11999999999995, 'y1': 154.8, 'y2': 230.4}], 'imageset': 'test'}
# index is 66
#   64/1000 [>.............................] - ETA: 1:42:53 - rpn_cls: 3.1604 - rpn_regr: 0.2426 - detector_cls: 0.5380 - detector_regr: 0.3903X is (1, 416, 605, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0bcMjuRPvb0+01+0169000+1.jpg', 'width': 524, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 524.0, 'y1': 304.2, 'y2': 360.0}], 'imageset': 'test'}
# index is 67
#   65/1000 [>.............................] - ETA: 1:42:41 - rpn_cls: 3.1136 - rpn_regr: 0.2525 - detector_cls: 0.5330 - detector_regr: 0.3843X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+31HB-qD50C0+01+0069000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 64.80000000000001, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 68
#   66/1000 [>.............................] - ETA: 1:42:17 - rpn_cls: 3.0817 - rpn_regr: 0.2586 - detector_cls: 0.5336 - detector_regr: 0.3874X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+31HB-qD50C0+02+0104000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 35.52, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 69
#   67/1000 [=>............................] - ETA: 1:41:54 - rpn_cls: 3.0409 - rpn_regr: 0.2657 - detector_cls: 0.5326 - detector_regr: 0.3882X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3Bk1DMmrwKM+00+0126000+1.jpg', 'width': 540, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 5.94, 'x2': 535.14, 'y1': 1.8, 'y2': 331.2}], 'imageset': 'test'}
# index is 70
#   68/1000 [=>............................] - ETA: 1:41:43 - rpn_cls: 3.0296 - rpn_regr: 0.2734 - detector_cls: 0.5324 - detector_regr: 0.3890X is (1, 416, 508, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3UMcgMzFXd0+00+0029000+1.jpg', 'width': 352, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 185.856, 'x2': 329.12, 'y1': 127.19999808, 'y2': 180.0}], 'imageset': 'test'}
# index is 71
#   69/1000 [=>............................] - ETA: 1:41:16 - rpn_cls: 3.1263 - rpn_regr: 0.2707 - detector_cls: 0.5287 - detector_regr: 0.3878X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-lxhXRXXvzc+03+1424000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 108.96, 'x2': 385.92, 'y1': 151.799994, 'y2': 240.600006}], 'imageset': 'test'}
# index is 72
#   70/1000 [=>............................] - ETA: 1:40:57 - rpn_cls: 3.1432 - rpn_regr: 0.2714 - detector_cls: 0.5242 - detector_regr: 0.3949X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+387cy_uwVUk+00+0132000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 193.28, 'x2': 1280.0, 'y1': 37.19999951999999, 'y2': 720.0}], 'imageset': 'test'}
# index is 73
#   71/1000 [=>............................] - ETA: 1:40:54 - rpn_cls: 3.1240 - rpn_regr: 0.2684 - detector_cls: 0.5265 - detector_regr: 0.3974X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2qhSFMl5vmU+00+0011000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 188.16, 'x2': 1280.0, 'y1': 157.1999976, 'y2': 720.0}], 'imageset': 'test'}
# index is 74
#   72/1000 [=>............................] - ETA: 1:40:44 - rpn_cls: 3.1197 - rpn_regr: 0.2653 - detector_cls: 0.5254 - detector_regr: 0.3972X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3G591E3xlT8+03+0047000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 8.0, 'x2': 312.96, 'y1': 7.199999999999999, 'y2': 225.19999919999998}], 'imageset': 'test'}
# index is 75
#   73/1000 [=>............................] - ETA: 1:40:30 - rpn_cls: 3.0890 - rpn_regr: 0.2705 - detector_cls: 0.5258 - detector_regr: 0.3981X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1U4WhCF0ys0+03+0090000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 25.6, 'x2': 320.0, 'y1': 42.7999992, 'y2': 191.600004}], 'imageset': 'test'}
# index is 76
#   74/1000 [=>............................] - ETA: 1:40:11 - rpn_cls: 3.0510 - rpn_regr: 0.2706 - detector_cls: 0.5311 - detector_regr: 0.3987X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+08+0495000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 384.0, 'y1': 44.64, 'y2': 264.4800048}], 'imageset': 'test'}
# index is 77
#   75/1000 [=>............................] - ETA: 1:40:05 - rpn_cls: 3.0129 - rpn_regr: 0.2742 - detector_cls: 0.5310 - detector_regr: 0.3986X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1PpOP9vNhRk+00+0026000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 125.10000000000001, 'x2': 368.55, 'y1': 203.9999976, 'y2': 279.59999039999997}], 'imageset': 'test'}
# index is 78
#   76/1000 [=>............................] - ETA: 1:39:55 - rpn_cls: 3.0449 - rpn_regr: 0.2734 - detector_cls: 0.5261 - detector_regr: 0.3934X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2iMlyCdr6M4+02+0035000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 137.28000000000003, 'x2': 319.67999999999995, 'y1': 156.6, 'y2': 291.6}], 'imageset': 'test'}
# index is 79
#   77/1000 [=>............................] - ETA: 1:39:45 - rpn_cls: 3.0402 - rpn_regr: 0.2738 - detector_cls: 0.5247 - detector_regr: 0.3958X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3C-L6xGSJAc+01+0149000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 52.47999999999999, 'x2': 295.35999999999996, 'y1': 47.6000016, 'y2': 150.4000008}], 'imageset': 'test'}
# index is 80
#   78/1000 [=>............................] - ETA: 1:39:35 - rpn_cls: 3.0114 - rpn_regr: 0.2707 - detector_cls: 0.5244 - detector_regr: 0.3962X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3HKYAxj4igw+00+0158000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 161.54999999999998, 'x2': 414.45, 'y1': 128.399994, 'y2': 211.799988}], 'imageset': 'test'}
# index is 81
#   79/1000 [=>............................] - ETA: 1:39:23 - rpn_cls: 3.0451 - rpn_regr: 0.2703 - detector_cls: 0.5207 - detector_regr: 0.3912X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0ieIPos7Ibg+00+0026000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 428.64, 'y1': 63.5999976, 'y2': 336.0000024}], 'imageset': 'test'}
# index is 82
#   80/1000 [=>............................] - ETA: 1:39:13 - rpn_cls: 3.0119 - rpn_regr: 0.2726 - detector_cls: 0.5211 - detector_regr: 0.3917X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1L57LPMdXcs+02+0201000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 0.0, 'y2': 720.0}], 'imageset': 'test'}
# index is 83
#   81/1000 [=>............................] - ETA: 1:39:16 - rpn_cls: 2.9976 - rpn_regr: 0.2699 - detector_cls: 0.5219 - detector_regr: 0.3927X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-lxhXRXXvzc+06+0103000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 134.88000000000002, 'x2': 309.12, 'y1': 142.20000000000002, 'y2': 231.59998800000005}], 'imageset': 'test'}
# index is 84
#   82/1000 [=>............................] - ETA: 1:39:02 - rpn_cls: 3.0465 - rpn_regr: 0.2671 - detector_cls: 0.5190 - detector_regr: 0.3928X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2rlYRZwFyAk+06+0524000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1280.0, 'y1': 0.0, 'y2': 595.199988}], 'imageset': 'test'}
# index is 85
#   83/1000 [=>............................] - ETA: 1:39:05 - rpn_cls: 3.0410 - rpn_regr: 0.2641 - detector_cls: 0.5200 - detector_regr: 0.3940X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-TCD1d1E9Tc+00+0015000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 86
# X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1L57LPMdXcs+03+0251000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 53.760000000000005, 'x2': 1280.0, 'y1': 147.6, 'y2': 440.4000239999999}], 'imageset': 'test'}
# index is 87
#   84/1000 [=>............................] - ETA: 1:39:31 - rpn_cls: 3.0554 - rpn_regr: 0.2654 - detector_cls: 0.5191 - detector_regr: 0.3945X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-fYp8Dr3wR0+04+0060000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 60.16, 'x2': 219.51999999999998, 'y1': 97.9999992, 'y2': 179.5999992}], 'imageset': 'test'}
# index is 88
#   85/1000 [=>............................] - ETA: 1:39:18 - rpn_cls: 3.0199 - rpn_regr: 0.2647 - detector_cls: 0.5170 - detector_regr: 0.3987X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-59Rg6_4eVo+01+0110000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 65.28, 'x2': 256.96, 'y1': 81.2000016, 'y2': 152.4}], 'imageset': 'test'}
# index is 89
#   86/1000 [=>............................] - ETA: 1:39:05 - rpn_cls: 3.0086 - rpn_regr: 0.2635 - detector_cls: 0.5155 - detector_regr: 0.4009X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-fmv5H-yyoY+00+0010000+0.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 90
# X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3pA50Sm8efU+01+0024000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 131.04000000000002, 'x2': 418.56, 'y1': 139.1999976, 'y2': 231.59998800000005}], 'imageset': 'test'}
# index is 91
#   87/1000 [=>............................] - ETA: 1:39:23 - rpn_cls: 2.9759 - rpn_regr: 0.2637 - detector_cls: 0.5128 - detector_regr: 0.4045X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+04o6OCBkwwQ+00+0001000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 77.76, 'x2': 303.84000000000003, 'y1': 96.60000600000001, 'y2': 174.6}], 'imageset': 'test'}
# index is 92
#   88/1000 [=>............................] - ETA: 1:39:10 - rpn_cls: 3.0264 - rpn_regr: 0.2627 - detector_cls: 0.5111 - detector_regr: 0.4048X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+07+0420000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 384.0, 'y1': 10.080000000000002, 'y2': 288.0}], 'imageset': 'test'}
# index is 93
#   89/1000 [=>............................] - ETA: 1:38:57 - rpn_cls: 2.9928 - rpn_regr: 0.2683 - detector_cls: 0.5122 - detector_regr: 0.4063X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1tODnCBJmSE+02+0239000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 86.4, 'x2': 302.08000000000004, 'y1': 146.9999988, 'y2': 261.600012}], 'imageset': 'test'}
# index is 94
#   90/1000 [=>............................] - ETA: 1:38:59 - rpn_cls: 2.9596 - rpn_regr: 0.2683 - detector_cls: 0.5097 - detector_regr: 0.4113X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1QrYla5mhtg+00+0298000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 506.88, 'x2': 1017.6, 'y1': 270.0, 'y2': 429.600024}], 'imageset': 'test'}
# index is 95
#   91/1000 [=>............................] - ETA: 1:38:57 - rpn_cls: 3.0342 - rpn_regr: 0.2676 - detector_cls: 0.5056 - detector_regr: 0.4068X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3mbjn_RZJRU+00+0031000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 144.96, 'x2': 404.64, 'y1': 73.8, 'y2': 165.6}], 'imageset': 'test'}
# index is 96
#   92/1000 [=>............................] - ETA: 1:39:00 - rpn_cls: 3.0604 - rpn_regr: 0.2683 - detector_cls: 0.5015 - detector_regr: 0.4096X is (1, 416, 547, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2oPuLqoax18+00+0025000+1.jpg', 'width': 400, 'height': 304, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 400.0, 'y1': 0.0, 'y2': 227.49333232}], 'imageset': 'test'}
# index is 97
#   93/1000 [=>............................] - ETA: 1:38:47 - rpn_cls: 3.0320 - rpn_regr: 0.2713 - detector_cls: 0.5010 - detector_regr: 0.4094X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+31HB-qD50C0+02+0099000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 26.879999999999995, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 98
#   94/1000 [=>............................] - ETA: 1:38:30 - rpn_cls: 3.0330 - rpn_regr: 0.2758 - detector_cls: 0.5014 - detector_regr: 0.4102X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-11Xc3Caam0+00+0179000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.32, 'x2': 279.04, 'y1': 80.00000159999999, 'y2': 190.00000799999998}], 'imageset': 'test'}
# index is 99
#   95/1000 [=>............................] - ETA: 1:38:19 - rpn_cls: 3.0034 - rpn_regr: 0.2738 - detector_cls: 0.5057 - detector_regr: 0.4105X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-fmv5H-yyoY+00+0001000+0.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 100
# X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0KVW3yvNVH4+00+0129000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 318.72, 'x2': 1280.0, 'y1': 115.2, 'y2': 297.5999976}], 'imageset': 'test'}
# index is 101
#   96/1000 [=>............................] - ETA: 1:38:37 - rpn_cls: 2.9727 - rpn_regr: 0.2744 - detector_cls: 0.5052 - detector_regr: 0.4116X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2BS1xf5tnfI+00+0133000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 385.92, 'y1': 0.0, 'y2': 331.800012}], 'imageset': 'test'}
# index is 102
#   97/1000 [=>............................] - ETA: 1:38:24 - rpn_cls: 2.9822 - rpn_regr: 0.2761 - detector_cls: 0.5059 - detector_regr: 0.4128X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+06tyP-Jj834+00+0171000+1.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 480.0, 'y1': 28.2666656, 'y2': 301.86665600000003}], 'imageset': 'test'}
# index is 103
#   98/1000 [=>............................] - ETA: 1:38:15 - rpn_cls: 2.9868 - rpn_regr: 0.2808 - detector_cls: 0.5077 - detector_regr: 0.4141X is (1, 416, 547, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2xrFXftTvuA+00+0044000+1.jpg', 'width': 400, 'height': 304, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 400.0, 'y1': 0.0, 'y2': 163.65334144}], 'imageset': 'test'}
# index is 104
#   99/1000 [=>............................] - ETA: 1:38:00 - rpn_cls: 2.9659 - rpn_regr: 0.2806 - detector_cls: 0.5112 - detector_regr: 0.4147X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-XINplK9mOU+00+0480000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 194.56, 'x2': 640.0, 'y1': 125.39999879999999, 'y2': 360.0}], 'imageset': 'test'}
# index is 105
#  100/1000 [==>...........................] - ETA: 1:37:58 - rpn_cls: 2.9403 - rpn_regr: 0.2798 - detector_cls: 0.5120 - detector_regr: 0.4155X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-10DMgsYgmg+01+0034000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1189.1200000000001, 'y1': 176.4, 'y2': 570.0000239999999}], 'imageset': 'test'}
# index is 106
#  101/1000 [==>...........................] - ETA: 1:37:52 - rpn_cls: 2.9118 - rpn_regr: 0.2786 - detector_cls: 0.5115 - detector_regr: 0.4147X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2dWblBkkccA+00+0024000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 226.1999988}], 'imageset': 'test'}
# index is 107
#  102/1000 [==>...........................] - ETA: 1:37:50 - rpn_cls: 2.9114 - rpn_regr: 0.2769 - detector_cls: 0.5116 - detector_regr: 0.4146X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0nNVzuYeLCE+00+0090000+1.jpg', 'width': 540, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 100.44000000000001, 'x2': 423.90000000000003, 'y1': 136.8, 'y2': 258.599988}], 'imageset': 'test'}
# index is 108
#  103/1000 [==>...........................] - ETA: 1:37:39 - rpn_cls: 2.8954 - rpn_regr: 0.2751 - detector_cls: 0.5103 - detector_regr: 0.4140X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0dfy5p_JxFY+00+0023000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 320.0, 'y1': 2.00000016, 'y2': 186.799992}], 'imageset': 'test'}
# index is 109
#  104/1000 [==>...........................] - ETA: 1:37:23 - rpn_cls: 2.8724 - rpn_regr: 0.2776 - detector_cls: 0.5111 - detector_regr: 0.4151X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-TCD1d1E9Tc+00+0021000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 110
# X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3HKYAxj4igw+05+0339000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 44.1, 'x2': 211.5, 'y1': 175.20000480000002, 'y2': 228.6}], 'imageset': 'test'}
# index is 111
#  105/1000 [==>...........................] - ETA: 1:37:29 - rpn_cls: 2.8979 - rpn_regr: 0.2764 - detector_cls: 0.5093 - detector_regr: 0.4112X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-NvM1VvQOW0+00+0073000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 395.03999999999996, 'y1': 101.9999988, 'y2': 317.99998800000003}], 'imageset': 'test'}
# index is 112
# ...
# index is 5251
#  967/1000 [============================>.] - ETA: 3:23 - rpn_cls: 0.7705 - rpn_regr: 0.1495 - detector_cls: 0.2562 - detector_regr: 0.2008X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+26Zcpo240Do+00+0028000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 75.648, 'x2': 339.84000000000003, 'y1': 32.159999232, 'y2': 115.68000096}], 'imageset': 'test'}
# index is 5252
#  968/1000 [============================>.] - ETA: 3:17 - rpn_cls: 0.7697 - rpn_regr: 0.1495 - detector_cls: 0.2561 - detector_regr: 0.2007X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3b4cjY5DV7A+00+0002000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 406.08, 'y1': 0.0, 'y2': 359.3999988}], 'imageset': 'test'}
# index is 5253
#  969/1000 [============================>.] - ETA: 3:11 - rpn_cls: 0.7689 - rpn_regr: 0.1494 - detector_cls: 0.2561 - detector_regr: 0.2006X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3fGcFpnPmMA+00+0085000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 1237.7600000000002, 'y1': 104.39999999999999, 'y2': 529.2}], 'imageset': 'test'}
# index is 5254
#  970/1000 [============================>.] - ETA: 3:05 - rpn_cls: 0.7681 - rpn_regr: 0.1493 - detector_cls: 0.2560 - detector_regr: 0.2006X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-FOKM9iC1Io+00+0235000+0.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5255
# X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3HKYAxj4igw+05+0339000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 44.1, 'x2': 211.5, 'y1': 175.20000480000002, 'y2': 228.6}], 'imageset': 'test'}
# index is 5256
#  971/1000 [============================>.] - ETA: 2:59 - rpn_cls: 0.7673 - rpn_regr: 0.1492 - detector_cls: 0.2559 - detector_regr: 0.2006X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+24DG7rPMmlQ+00+0013000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 355.2, 'y1': 155.4000012, 'y2': 277.2}], 'imageset': 'test'}
# index is 5257
#  972/1000 [============================>.] - ETA: 2:52 - rpn_cls: 0.7670 - rpn_regr: 0.1491 - detector_cls: 0.2559 - detector_regr: 0.2005X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+350f3SOkF5c+00+0004000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 358.40000000000003, 'x2': 1200.6399999999999, 'y1': 170.3999952, 'y2': 373.199976}], 'imageset': 'test'}
# index is 5258
#  973/1000 [============================>.] - ETA: 2:46 - rpn_cls: 0.7662 - rpn_regr: 0.1490 - detector_cls: 0.2559 - detector_regr: 0.2004X is (1, 416, 520, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-GPXMqq2028+00+0005000+1.jpg', 'width': 450, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 71.55, 'x2': 391.05000000000007, 'y1': 39.00000024, 'y2': 183.6}], 'imageset': 'test'}
# index is 5259
#  974/1000 [============================>.] - ETA: 2:40 - rpn_cls: 0.7660 - rpn_regr: 0.1490 - detector_cls: 0.2558 - detector_regr: 0.2003X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2fADgRcGugQ+03+0328000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 289.28000000000003, 'x2': 1250.56, 'y1': 206.3999952, 'y2': 579.6}], 'imageset': 'test'}
# index is 5260
#  975/1000 [============================>.] - ETA: 2:34 - rpn_cls: 0.7652 - rpn_regr: 0.1489 - detector_cls: 0.2557 - detector_regr: 0.2002X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+23iCuMl00nA+00+0131000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 14.399999999999999, 'x2': 464.64, 'y1': 127.1999952, 'y2': 231.59998800000005}], 'imageset': 'test'}
# index is 5261
#  976/1000 [============================>.] - ETA: 2:28 - rpn_cls: 0.7645 - rpn_regr: 0.1488 - detector_cls: 0.2556 - detector_regr: 0.2001X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0_5Ydb5IBpk+00+0027000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 69.6, 'x2': 444.0, 'y1': 133.8000012, 'y2': 221.4}], 'imageset': 'test'}
# index is 5262
#  977/1000 [============================>.] - ETA: 2:21 - rpn_cls: 0.7637 - rpn_regr: 0.1489 - detector_cls: 0.2554 - detector_regr: 0.1999X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+0Oi63sISrFI+00+0010000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 480.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 5263
#  978/1000 [============================>.] - ETA: 2:15 - rpn_cls: 0.7644 - rpn_regr: 0.1493 - detector_cls: 0.2553 - detector_regr: 0.1998X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+010oXYICAwU+00+0213000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 227.84000000000003, 'x2': 1280.0, 'y1': 177.6000024, 'y2': 494.4000024}], 'imageset': 'test'}
# index is 5264
#  979/1000 [============================>.] - ETA: 2:09 - rpn_cls: 0.7686 - rpn_regr: 0.1493 - detector_cls: 0.2553 - detector_regr: 0.1997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-BjkgIoZjWg+00+0021000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 52.8, 'x2': 396.0, 'y1': 85.7999988, 'y2': 213.59998800000002}], 'imageset': 'test'}
# index is 5265
#  980/1000 [============================>.] - ETA: 2:03 - rpn_cls: 0.7678 - rpn_regr: 0.1493 - detector_cls: 0.2552 - detector_regr: 0.1997X is (1, 416, 726, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2G1ObcmTzS4+00+0013000+0.jpg', 'width': 426, 'height': 244, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5266
# X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-uIFiysZVgw+00+0015000+1.jpg', 'width': 540, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 513.0, 'y1': 0.0, 'y2': 279.0}], 'imageset': 'test'}
# index is 5267
#  981/1000 [============================>.] - ETA: 1:57 - rpn_cls: 0.7685 - rpn_regr: 0.1492 - detector_cls: 0.2554 - detector_regr: 0.1998X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3C-L6xGSJAc+05+0299000+1.jpg', 'width': 320, 'height': 240, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 320.0, 'y1': 40.400001599999996, 'y2': 166.79999999999998}], 'imageset': 'test'}
# index is 5268
#  982/1000 [============================>.] - ETA: 1:51 - rpn_cls: 0.7677 - rpn_regr: 0.1491 - detector_cls: 0.2554 - detector_regr: 0.1997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+04+0270000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 384.0, 'y1': 129.11999616, 'y2': 225.12000959999997}], 'imageset': 'test'}
# index is 5269
#  983/1000 [============================>.] - ETA: 1:44 - rpn_cls: 0.7669 - rpn_regr: 0.1491 - detector_cls: 0.2552 - detector_regr: 0.1996X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-_kdoJRFXO0+00+0001000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 261.12, 'y1': 251.99999999999997, 'y2': 392.40000000000003}], 'imageset': 'test'}
# index is 5270
#  984/1000 [============================>.] - ETA: 1:38 - rpn_cls: 0.7712 - rpn_regr: 0.1491 - detector_cls: 0.2551 - detector_regr: 0.1998X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2O7Ahxqr9rI+04+0283000+1.jpg', 'width': 384, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 384.0, 'y1': 91.67999904000001, 'y2': 234.23999904}], 'imageset': 'test'}
# index is 5271
#  985/1000 [============================>.] - ETA: 1:32 - rpn_cls: 0.7704 - rpn_regr: 0.1490 - detector_cls: 0.2552 - detector_regr: 0.1997X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3aXicex8wfQ+01+0195000+0.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5272
# X is (1, 416, 508, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2ifMPiPpxKo+03+0756000+1.jpg', 'width': 352, 'height': 288, 'bboxes': [{'class': 'airplane', 'x1': 169.66400000000002, 'x2': 241.12, 'y1': 101.75999616, 'y2': 160.80000192}], 'imageset': 'test'}
# index is 5273
#  986/1000 [============================>.] - ETA: 1:26 - rpn_cls: 0.7753 - rpn_regr: 0.1489 - detector_cls: 0.2552 - detector_regr: 0.1998X is (1, 416, 734, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3eJOcCwWSxQ+00+0035000+1.jpg', 'width': 636, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 197.796, 'y1': 154.8, 'y2': 302.4}], 'imageset': 'test'}
# index is 5274
#  987/1000 [============================>.] - ETA: 1:20 - rpn_cls: 0.7746 - rpn_regr: 0.1490 - detector_cls: 0.2552 - detector_regr: 0.1998X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2qK8HB73HhY+04+0076000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 153.6, 'x2': 1058.5600000000002, 'y1': 237.60000000000002, 'y2': 544.7999952}], 'imageset': 'test'}
# index is 5275
#  988/1000 [============================>.] - ETA: 1:14 - rpn_cls: 0.7738 - rpn_regr: 0.1489 - detector_cls: 0.2551 - detector_regr: 0.1997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2hRA-3OPQB4+02+0290000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 18.24, 'x2': 476.15999999999997, 'y1': 72.6000012, 'y2': 264.6}], 'imageset': 'test'}
# index is 5276
#  989/1000 [============================>.] - ETA: 1:07 - rpn_cls: 0.7730 - rpn_regr: 0.1488 - detector_cls: 0.2551 - detector_regr: 0.1996X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2Io7AhRN7IE+03+0353000+1.jpg', 'width': 320, 'height': 180, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 298.88, 'y1': 35.7000012, 'y2': 173.9999952}], 'imageset': 'test'}
# index is 5277
#  990/1000 [============================>.] - ETA: 1:01 - rpn_cls: 0.7722 - rpn_regr: 0.1487 - detector_cls: 0.2551 - detector_regr: 0.1997X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1ml7l5atuIE+01+0226000+1.jpg', 'width': 640, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 207.36, 'x2': 325.76, 'y1': 168.0000012, 'y2': 192.0000096}], 'imageset': 'test'}
# index is 5278
#  991/1000 [============================>.] - ETA: 55s - rpn_cls: 0.7723 - rpn_regr: 0.1490 - detector_cls: 0.2549 - detector_regr: 0.1995 X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3Bk1DMmrwKM+04+0090000+1.jpg', 'width': 540, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 3.78, 'x2': 417.42, 'y1': 74.3999976, 'y2': 335.400012}], 'imageset': 'test'}
# index is 5279
#  992/1000 [============================>.] - ETA: 49s - rpn_cls: 0.7716 - rpn_regr: 0.1488 - detector_cls: 0.2548 - detector_regr: 0.1995X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+3ITHoJbfmaI+01+0262000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 273.59999999999997, 'x2': 430.0799999999999, 'y1': 91.8, 'y2': 156.0000024}], 'imageset': 'test'}
# index is 5280
#  993/1000 [============================>.] - ETA: 43s - rpn_cls: 0.7731 - rpn_regr: 0.1488 - detector_cls: 0.2549 - detector_regr: 0.1998X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+06tyP-Jj834+01+0209000+1.jpg', 'width': 480, 'height': 320, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 480.0, 'y1': 18.133334400000003, 'y2': 302.4}], 'imageset': 'test'}
# index is 5281
#  994/1000 [============================>.] - ETA: 37s - rpn_cls: 0.7723 - rpn_regr: 0.1490 - detector_cls: 0.2548 - detector_regr: 0.1997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-Nosp5U2_Fs+00+0055000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 115.19999999999999, 'x2': 460.79999999999995, 'y1': 154.8, 'y2': 246.0000024}], 'imageset': 'test'}
# index is 5282
#  995/1000 [============================>.] - ETA: 30s - rpn_cls: 0.7716 - rpn_regr: 0.1490 - detector_cls: 0.2546 - detector_regr: 0.1997X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1QVNYiqyx2E+00+0016000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 325.12, 'x2': 1000.96, 'y1': 289.2000024, 'y2': 551.999988}], 'imageset': 'test'}
# index is 5283
#  996/1000 [============================>.] - ETA: 24s - rpn_cls: 0.7709 - rpn_regr: 0.1489 - detector_cls: 0.2545 - detector_regr: 0.1997X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+-7TE-zbf-UQ+00+1039000+1.jpg', 'width': 480, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 358.08, 'x2': 480.0, 'y1': 146.4000012, 'y2': 190.199988}], 'imageset': 'test'}
# index is 5284
#  997/1000 [============================>.] - ETA: 18s - rpn_cls: 0.7701 - rpn_regr: 0.1491 - detector_cls: 0.2546 - detector_regr: 0.2004X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+2qK8HB73HhY+03+0520000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 533.76, 'x2': 1280.0, 'y1': 298.8, 'y2': 531.6000048}], 'imageset': 'test'}
# index is 5285
#  998/1000 [============================>.] - ETA: 12s - rpn_cls: 0.7693 - rpn_regr: 0.1490 - detector_cls: 0.2546 - detector_regr: 0.2005X is (1, 416, 556, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1lWXMjTdFxI+01+0036000+1.jpg', 'width': 482, 'height': 360, 'bboxes': [{'class': 'airplane', 'x1': 0.0, 'x2': 482.0, 'y1': 0.0, 'y2': 360.0}], 'imageset': 'test'}
# index is 5286
#  999/1000 [============================>.] - ETA: 6s - rpn_cls: 0.7690 - rpn_regr: 0.1489 - detector_cls: 0.2546 - detector_regr: 0.2005 X is (1, 416, 739, 3)
# Y is 2
# img_data is {'filepath': 'Y2BB_extracted_dataset/airplane_for_train/13+1L57LPMdXcs+05+0307000+1.jpg', 'width': 1280, 'height': 720, 'bboxes': [{'class': 'airplane', 'x1': 293.12, 'x2': 1280.0, 'y1': 123.6000024, 'y2': 514.8}], 'imageset': 'test'}
# index is 5287
# 1000/1000 [==============================] - 6175s 6s/step - rpn_cls: 0.7682 - rpn_regr: 0.1489 - detector_cls: 0.2546 - detector_regr: 0.2004
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 8.837121212121213
# Classifier accuracy for bounding boxes from RPN: 0.89121875
# Loss RPN classifier: 0.7682427042853119
# Loss RPN regression: 0.1489175839824893
# Loss Detector classifier: 0.25455659452755935
# Loss Detector regression: 0.20043686739914118
# Elapsed time: 6175.291526317596
# Total loss decreased from 1.5539600750656672 to 1.3721537501945018, saving weights
# Training complete, exiting.
