# %% [markdown]
# ## Faster R-CNN Training for COCO Train Class - using Pretrained ResNet50

# %%
from __future__ import division
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import re

# %%
from keras import backend as K
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input
from keras.models import Model
from keras_frcnn import config, data_generators
from keras_frcnn import losses as losses
import keras_frcnn.roi_helpers as roi_helpers
from keras.utils import generic_utils
sys.setrecursionlimit(40000)
# Out:
# Using TensorFlow backend.

# %%
from keras_frcnn.simple_parser import get_data
from keras_frcnn import resnet as nn

# %% [markdown]
# #### Specify the config

# %%
# Create a config object and set the values
C = config.Config()
firstTraining = True

C.use_horizontal_flips = bool(False)
C.use_vertical_flips = bool(False)
C.rot_90 = bool(False)
C.model_path = './coco_model_frcnn_train_vehicle_v1.hdf5'
C.verbose = True
model_path_regex = re.match("^(.+)(\.hdf5)$", C.model_path)
if model_path_regex.group(2) != '.hdf5':
	print('Output weights must have .hdf5 filetype')
	exit(1)
C.num_rois = int(32)
C.network = 'resnet50'
if firstTraining is True:
    C.base_net_weights = nn.get_weight_path()
    firstTraining = False
else:
    C.base_net_weights = options.input_weight_path
config_output_filename = "coco_config_train.pickle"
#train_path = './annotate.txt'
#train_path = 'COCO_extracted_dataset/airplane_for_train/coco_airplane_annotate.txt'
train_path = 'coco_training_Train_annotate.txt'
val_path = 'coco_validation_Train_annotate.txt'

# %% [markdown]
# #### Load the training images using annotation file (created post data preprocessing)

# %%
train_imgs, classes_count, class_mapping = get_data(train_path)
val_imgs, _, _ = get_data(val_path)

if 'bg' not in classes_count:
	classes_count['bg'] = 0
	class_mapping['bg'] = len(class_mapping)

C.class_mapping = class_mapping
inv_map = {v: k for k, v in class_mapping.items()}

print('Training images per class:')
pprint.pprint(classes_count)
print(f'Num classes (including bg) = {len(classes_count)}')
# Out:
# Parsing annotation files
# Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).
# Parsing annotation files
# Training images per class:
# {'bg': 50, 'train': 950}
# Num classes (including bg) = 2

# %%
train_imgs
# Out:
# [{'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000032773.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 271.63,
#     'x2': 435.04,
#     'y1': 192.68,
#     'y2': 373.76}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000114698.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 355.24,
#     'y1': 240.28,
#     'y2': 605.58}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000548893.jpg',
#   'width': 640,
#   'height': 548,
#   'bboxes': [{'class': 'train',
#     'x1': 94.51,
#     'x2': 467.99,
#     'y1': 197.8,
#     'y2': 237.53}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000507936.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 0.95,
#     'x2': 319.91,
#     'y1': 133.22,
#     'y2': 336.62}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000278569.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 115.42,
#     'x2': 638.56,
#     'y1': 0.0,
#     'y2': 362.43}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000294954.jpg',
#   'width': 640,
#   'height': 551,
#   'bboxes': [{'class': 'train',
#     'x1': 67.16,
#     'x2': 574.53,
#     'y1': 6.29,
#     'y2': 548.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000237611.jpg',
#   'width': 640,
#   'height': 394,
#   'bboxes': [{'class': 'train',
#     'x1': 0.98,
#     'x2': 640.0,
#     'y1': 1.46,
#     'y2': 247.23}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000376882.jpg',
#   'width': 640,
#   'height': 468,
#   'bboxes': [{'class': 'train',
#     'x1': 50.84,
#     'x2': 561.6,
#     'y1': 0.0,
#     'y2': 250.76}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000032819.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 12.39,
#     'y2': 352.58}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000376888.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 482.16,
#     'y1': 63.1,
#     'y2': 351.1}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000352313.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 50.86,
#     'x2': 639.0600000000002,
#     'y1': 68.13,
#     'y2': 317.61}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172091.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 191.35,
#     'x2': 351.35,
#     'y1': 218.92,
#     'y2': 342.16}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000106562.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 58.94,
#     'x2': 443.01,
#     'y1': 0.0,
#     'y2': 417.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000000071.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 47.87,
#     'x2': 531.3,
#     'y1': 185.72,
#     'y2': 305.38}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000401482.jpg',
#   'width': 640,
#   'height': 489,
#   'bboxes': [{'class': 'train',
#     'x1': 24.18,
#     'x2': 314.2800000000001,
#     'y1': 28.57,
#     'y2': 286.81}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393294.jpg',
#   'width': 500,
#   'height': 320,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 293.48,
#     'y1': 163.28,
#     'y2': 185.71}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000139345.jpg',
#   'width': 500,
#   'height': 342,
#   'bboxes': [{'class': 'train',
#     'x1': 76.85,
#     'x2': 309.72,
#     'y1': 101.45,
#     'y2': 251.31}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393303.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 511.63,
#     'y1': 67.8,
#     'y2': 356.31}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000163933.jpg',
#   'width': 640,
#   'height': 430,
#   'bboxes': [{'class': 'train',
#     'x1': 41.27,
#     'x2': 524.21,
#     'y1': 219.0,
#     'y2': 283.86}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000114784.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 435.53,
#     'x2': 540.8199999999998,
#     'y1': 152.67,
#     'y2': 250.31}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000540769.jpg',
#   'width': 640,
#   'height': 509,
#   'bboxes': [{'class': 'train',
#     'x1': 75.49,
#     'x2': 633.6800000000002,
#     'y1': 134.97,
#     'y2': 438.08}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000401507.jpg',
#   'width': 640,
#   'height': 569,
#   'bboxes': [{'class': 'train',
#     'x1': 84.58,
#     'x2': 425.47,
#     'y1': 355.63,
#     'y2': 497.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024682.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 2.88,
#     'x2': 250.38,
#     'y1': 149.16,
#     'y2': 345.17}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000573546.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 69.56,
#     'x2': 509.75,
#     'y1': 104.65,
#     'y2': 291.4}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000073843.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 22.07,
#     'x2': 640.0,
#     'y1': 136.26,
#     'y2': 263.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172148.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 621.62,
#     'y1': 172.43,
#     'y2': 257.84000000000003}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000319609.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 382.96,
#     'y1': 215.52,
#     'y2': 356.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000147585.jpg',
#   'width': 640,
#   'height': 273,
#   'bboxes': [{'class': 'train',
#     'x1': 62.18,
#     'x2': 632.4599999999998,
#     'y1': 41.45,
#     'y2': 237.41000000000003}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000254081.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 310.91,
#     'y1': 140.3,
#     'y2': 395.85}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172173.jpg',
#   'width': 640,
#   'height': 494,
#   'bboxes': [{'class': 'train',
#     'x1': 113.23,
#     'x2': 548.4,
#     'y1': 104.35,
#     'y2': 407.41}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000114829.jpg',
#   'width': 500,
#   'height': 340,
#   'bboxes': [{'class': 'train',
#     'x1': 12.63,
#     'x2': 437.03,
#     'y1': 62.21,
#     'y2': 188.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000303252.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 246.88,
#     'x2': 640.0,
#     'y1': 156.09,
#     'y2': 404.58}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000532629.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 628.85,
#     'y1': 33.51,
#     'y2': 388.39}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000032918.jpg',
#   'width': 640,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 0.95,
#     'y2': 311.49}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000000151.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 210.76,
#     'x2': 480.0,
#     'y1': 4.6,
#     'y2': 640.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000016538.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 64.65,
#     'x2': 454.77,
#     'y1': 65.96,
#     'y2': 281.7}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041116.jpg',
#   'width': 640,
#   'height': 476,
#   'bboxes': [{'class': 'train',
#     'x1': 16.04,
#     'x2': 434.28,
#     'y1': 23.53,
#     'y2': 415.03}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000286877.jpg',
#   'width': 640,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 1.44,
#     'y2': 631.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000147616.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 1.62,
#     'x2': 425.11,
#     'y1': 390.55,
#     'y2': 599.65}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000540833.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 208.22,
#     'x2': 483.0,
#     'y1': 88.51,
#     'y2': 257.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000254130.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 29.75,
#     'x2': 591.08,
#     'y1': 200.25,
#     'y2': 302.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041138.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.64,
#     'x2': 266.47,
#     'y1': 107.48,
#     'y2': 376.66}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000573620.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 292.93,
#     'x2': 607.87,
#     'y1': 75.22,
#     'y2': 248.51}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172211.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 1.93,
#     'x2': 379.8,
#     'y1': 148.93,
#     'y2': 418.84}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000229559.jpg',
#   'width': 640,
#   'height': 433,
#   'bboxes': [{'class': 'train',
#     'x1': 211.15,
#     'x2': 574.09,
#     'y1': 186.82,
#     'y2': 344.45}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000491703.jpg',
#   'width': 375,
#   'height': 500,
#   'bboxes': [{'class': 'train',
#     'x1': 40.45,
#     'x2': 330.34,
#     'y1': 32.77,
#     'y2': 440.64}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000008385.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 640.0,
#     'y1': 0.67,
#     'y2': 419.03}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000434370.jpg',
#   'width': 640,
#   'height': 482,
#   'bboxes': [{'class': 'train',
#     'x1': 226.58,
#     'x2': 638.94,
#     'y1': 80.44,
#     'y2': 277.29}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000368845.jpg',
#   'width': 640,
#   'height': 387,
#   'bboxes': [{'class': 'train',
#     'x1': 233.94,
#     'x2': 483.53,
#     'y1': 193.07,
#     'y2': 293.95}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000458958.jpg',
#   'width': 640,
#   'height': 478,
#   'bboxes': [{'class': 'train',
#     'x1': 147.9,
#     'x2': 564.8100000000002,
#     'y1': 0.64,
#     'y2': 440.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000540882.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 128.28,
#     'x2': 476.74,
#     'y1': 216.59,
#     'y2': 406.14}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000483538.jpg',
#   'width': 640,
#   'height': 431,
#   'bboxes': [{'class': 'train',
#     'x1': 268.05,
#     'x2': 513.9200000000002,
#     'y1': 196.38,
#     'y2': 421.04}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213204.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 4.31,
#     'x2': 478.92,
#     'y1': 48.46,
#     'y2': 518.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024792.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 506.17,
#     'y1': 140.57,
#     'y2': 342.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000458970.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 33.44,
#     'x2': 408.81,
#     'y1': 148.85,
#     'y2': 347.33}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000409820.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 26.87,
#     'x2': 627.55,
#     'y1': 109.39,
#     'y2': 296.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000008422.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 68.76,
#     'x2': 399.99,
#     'y1': 192.61,
#     'y2': 313.36}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000532714.jpg',
#   'width': 640,
#   'height': 419,
#   'bboxes': [{'class': 'train',
#     'x1': 0.94,
#     'x2': 638.3900000000001,
#     'y1': 94.16,
#     'y2': 306.01}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000475370.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 70.04,
#     'x2': 374.28,
#     'y1': 186.55,
#     'y2': 216.16000000000003}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000409841.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 131.6,
#     'x2': 570.61,
#     'y1': 180.13,
#     'y2': 419.6}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000286961.jpg',
#   'width': 640,
#   'height': 394,
#   'bboxes': [{'class': 'train',
#     'x1': 76.39,
#     'x2': 399.94,
#     'y1': 184.16,
#     'y2': 284.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000352498.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 97.87,
#     'x2': 407.81,
#     'y1': 161.2,
#     'y2': 301.2999999999999}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000377074.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 0.95,
#     'x2': 375.41,
#     'y1': 163.95,
#     'y2': 240.17}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000139507.jpg',
#   'width': 640,
#   'height': 392,
#   'bboxes': [{'class': 'train',
#     'x1': 236.52,
#     'x2': 307.16,
#     'y1': 175.79,
#     'y2': 255.34}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000123127.jpg',
#   'width': 640,
#   'height': 373,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 105.43,
#     'y2': 244.05}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000073976.jpg',
#   'width': 500,
#   'height': 377,
#   'bboxes': [{'class': 'train',
#     'x1': 325.63,
#     'x2': 440.69,
#     'y1': 295.92,
#     'y2': 319.5200000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213242.jpg',
#   'width': 640,
#   'height': 268,
#   'bboxes': [{'class': 'train',
#     'x1': 163.04,
#     'x2': 606.17,
#     'y1': 117.38,
#     'y2': 174.20999999999995}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000311550.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 96.91,
#     'x2': 490.33,
#     'y1': 62.37,
#     'y2': 355.99}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000114943.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 640.0,
#     'y1': 47.6,
#     'y2': 386.35}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000426252.jpg',
#   'width': 640,
#   'height': 483,
#   'bboxes': [{'class': 'train',
#     'x1': 87.92,
#     'x2': 400.51,
#     'y1': 89.27,
#     'y2': 393.18}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000016653.jpg',
#   'width': 640,
#   'height': 407,
#   'bboxes': [{'class': 'train',
#     'x1': 13.72,
#     'x2': 561.57,
#     'y1': 172.92,
#     'y2': 321.09}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000459026.jpg',
#   'width': 640,
#   'height': 397,
#   'bboxes': [{'class': 'train',
#     'x1': 176.64,
#     'x2': 620.03,
#     'y1': 148.09,
#     'y2': 292.62}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000008469.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 216.23,
#     'x2': 361.5,
#     'y1': 223.62,
#     'y2': 323.41}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000188693.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 163.96,
#     'x2': 480.0,
#     'y1': 137.83,
#     'y2': 323.36}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000508195.jpg',
#   'width': 640,
#   'height': 379,
#   'bboxes': [{'class': 'train',
#     'x1': 30.66,
#     'x2': 597.88,
#     'y1': 63.88,
#     'y2': 315.12}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000262450.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.36,
#     'x2': 494.18,
#     'y1': 94.47,
#     'y2': 369.11}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000540987.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 49.26,
#     'y2': 621.66}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516417.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 129.44,
#     'x2': 640.0,
#     'y1': 153.17,
#     'y2': 334.38}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000065859.jpg',
#   'width': 640,
#   'height': 422,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 229.49,
#     'y1': 44.57,
#     'y2': 341.39}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024899.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 99.24,
#     'x2': 480.01,
#     'y1': 76.86,
#     'y2': 293.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000131400.jpg',
#   'width': 640,
#   'height': 481,
#   'bboxes': [{'class': 'train',
#     'x1': 28.78,
#     'x2': 567.87,
#     'y1': 176.17,
#     'y2': 297.52}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000155981.jpg',
#   'width': 640,
#   'height': 290,
#   'bboxes': [{'class': 'train',
#     'x1': 2.61,
#     'x2': 639.96,
#     'y1': 2.41,
#     'y2': 274.81}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024923.jpg',
#   'width': 500,
#   'height': 332,
#   'bboxes': [{'class': 'train',
#     'x1': 64.16,
#     'x2': 342.72,
#     'y1': 105.2,
#     'y2': 214.87}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000000349.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 539.33,
#     'y1': 130.52,
#     'y2': 388.31000000000006}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000188771.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 105.55,
#     'x2': 370.39,
#     'y1': 186.15,
#     'y2': 281.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000442723.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 162.73,
#     'x2': 479.9,
#     'y1': 265.6,
#     'y2': 640.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000483691.jpg',
#   'width': 637,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 57.27,
#     'x2': 535.48,
#     'y1': 121.84,
#     'y2': 413.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024947.jpg',
#   'width': 640,
#   'height': 430,
#   'bboxes': [{'class': 'train',
#     'x1': 112.42,
#     'x2': 446.7,
#     'y1': 212.7,
#     'y2': 294.57}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000074110.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 78.5,
#     'x2': 426.96,
#     'y1': 89.99,
#     'y2': 329.31}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393602.jpg',
#   'width': 640,
#   'height': 430,
#   'bboxes': [{'class': 'train',
#     'x1': 241.57,
#     'x2': 513.0999999999998,
#     'y1': 185.53,
#     'y2': 332.4}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000147843.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 193.96,
#     'x2': 331.75,
#     'y1': 168.41,
#     'y2': 278.76}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213382.jpg',
#   'width': 640,
#   'height': 398,
#   'bboxes': [{'class': 'train',
#     'x1': 425.66,
#     'x2': 638.94,
#     'y1': 1.89,
#     'y2': 398.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000344456.jpg',
#   'width': 640,
#   'height': 445,
#   'bboxes': [{'class': 'train',
#     'x1': 518.0,
#     'x2': 640.0,
#     'y1': 66.0,
#     'y2': 162.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000278921.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 364.85,
#     'x2': 594.69,
#     'y1': 0.0,
#     'y2': 178.73}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000401802.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 2.87,
#     'x2': 427.0,
#     'y1': 2.3,
#     'y2': 339.5200000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000475531.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 16.31,
#     'x2': 626.5899999999998,
#     'y1': 141.05,
#     'y2': 302.26}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393617.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 221.62,
#     'x2': 500.55,
#     'y1': 163.03,
#     'y2': 256.65}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000352658.jpg',
#   'width': 500,
#   'height': 336,
#   'bboxes': [{'class': 'train',
#     'x1': 294.57,
#     'x2': 373.67,
#     'y1': 114.51,
#     'y2': 218.48}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000049562.jpg',
#   'width': 640,
#   'height': 430,
#   'bboxes': [{'class': 'train',
#     'x1': 143.43,
#     'x2': 398.17,
#     'y1': 191.19,
#     'y2': 273.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000459166.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 252.43,
#     'x2': 471.9,
#     'y1': 99.03,
#     'y2': 287.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000385441.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 78.57,
#     'x2': 561.79,
#     'y1': 139.48,
#     'y2': 284.77}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000229794.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 68.29,
#     'x2': 640.0,
#     'y1': 162.54,
#     'y2': 353.94}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041377.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 35.5,
#     'x2': 290.52,
#     'y1': 137.01,
#     'y2': 258.35}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000082346.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 2.88,
#     'x2': 639.06,
#     'y1': 80.31,
#     'y2': 284.69}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000500147.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 4.31,
#     'x2': 640.0,
#     'y1': 40.99,
#     'y2': 96.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000270784.jpg',
#   'width': 640,
#   'height': 415,
#   'bboxes': [{'class': 'train',
#     'x1': 97.92,
#     'x2': 552.09,
#     'y1': 5.6,
#     'y2': 390.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000139712.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 467.3,
#     'x2': 640.0,
#     'y1': 0.9,
#     'y2': 289.28}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000049603.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 3.84,
#     'x2': 635.22,
#     'y1': 64.29,
#     'y2': 319.5300000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000016837.jpg',
#   'width': 431,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 225.29,
#     'x2': 431.0,
#     'y1': 170.76,
#     'y2': 519.46}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213448.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 43.83,
#     'x2': 567.87,
#     'y1': 147.69,
#     'y2': 266.79}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000057801.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 381.04,
#     'y1': 1.53,
#     'y2': 427.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000319952.jpg',
#   'width': 640,
#   'height': 431,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 38.34,
#     'y2': 301.41}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000106973.jpg',
#   'width': 640,
#   'height': 361,
#   'bboxes': [{'class': 'train',
#     'x1': 46.95,
#     'x2': 260.63,
#     'y1': 62.0,
#     'y2': 319.4}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000238051.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 75.47,
#     'x2': 612.0,
#     'y1': 1.37,
#     'y2': 605.14}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000246246.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 1.58,
#     'x2': 472.49,
#     'y1': 292.35,
#     'y2': 640.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000098800.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 3.24,
#     'x2': 640.0,
#     'y1': 158.23,
#     'y2': 445.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000459248.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 63.78,
#     'x2': 564.32,
#     'y1': 183.24,
#     'y2': 404.86}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000524788.jpg',
#   'width': 640,
#   'height': 380,
#   'bboxes': [{'class': 'train',
#     'x1': 18.52,
#     'x2': 573.28,
#     'y1': 253.33,
#     'y2': 330.3400000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000303617.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 109.23,
#     'x2': 374.39,
#     'y1': 80.75,
#     'y2': 382.9}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000385538.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 158.64,
#     'x2': 498.38,
#     'y1': 159.39,
#     'y2': 181.09}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000451074.jpg',
#   'width': 640,
#   'height': 482,
#   'bboxes': [{'class': 'train',
#     'x1': 230.62,
#     'x2': 306.01,
#     'y1': 185.06,
#     'y2': 224.47}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000229893.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 181.21,
#     'x2': 528.54,
#     'y1': 119.73,
#     'y2': 288.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000532998.jpg',
#   'width': 518,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 248.25,
#     'x2': 512.29,
#     'y1': 108.1,
#     'y2': 336.26}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213510.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 138.18,
#     'x2': 511.44,
#     'y1': 218.78,
#     'y2': 391.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516617.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 293.03,
#     'x2': 640.0,
#     'y1': 193.74,
#     'y2': 219.8}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000524816.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 82.52,
#     'x2': 554.62,
#     'y1': 95.96,
#     'y2': 352.16}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000573969.jpg',
#   'width': 640,
#   'height': 452,
#   'bboxes': [{'class': 'train',
#     'x1': 5.07,
#     'x2': 623.2700000000002,
#     'y1': 63.17,
#     'y2': 312.48}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000328216.jpg',
#   'width': 500,
#   'height': 385,
#   'bboxes': [{'class': 'train',
#     'x1': 177.83,
#     'x2': 355.65,
#     'y1': 143.55,
#     'y2': 289.44}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516633.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 41.17,
#     'x2': 536.14,
#     'y1': 145.84,
#     'y2': 316.26}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172574.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 7.55,
#     'x2': 600.81,
#     'y1': 226.52,
#     'y2': 391.55}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000164388.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 578.76,
#     'y1': 142.3,
#     'y2': 341.91}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000410152.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 409.81,
#     'y1': 217.89,
#     'y2': 417.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000500265.jpg',
#   'width': 640,
#   'height': 487,
#   'bboxes': [{'class': 'train',
#     'x1': 15.32,
#     'x2': 308.62,
#     'y1': 33.93,
#     'y2': 362.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000188972.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 217.35,
#     'x2': 511.63,
#     'y1': 84.15,
#     'y2': 421.71}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000369201.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 145.62,
#     'x2': 637.48,
#     'y1': 136.99,
#     'y2': 410.97}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221746.jpg',
#   'width': 640,
#   'height': 411,
#   'bboxes': [{'class': 'train',
#     'x1': 150.55,
#     'x2': 534.76,
#     'y1': 93.28,
#     'y2': 345.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213557.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 2.15,
#     'y2': 334.71}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000426556.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 404.01,
#     'y1': 111.89,
#     'y2': 330.69}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000229949.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 4.31,
#     'x2': 414.2,
#     'y1': 93.84,
#     'y2': 478.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000401980.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 2.11,
#     'x2': 637.86,
#     'y1': 0.0,
#     'y2': 423.84}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000541251.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 73.17,
#     'x2': 500.0,
#     'y1': 30.31,
#     'y2': 301.34}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172615.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 76.22,
#     'x2': 299.15,
#     'y1': 274.79,
#     'y2': 456.01}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000492104.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 208.22,
#     'x2': 601.64,
#     'y1': 120.9,
#     'y2': 288.82}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000066121.jpg',
#   'width': 640,
#   'height': 452,
#   'bboxes': [{'class': 'train',
#     'x1': 48.65,
#     'x2': 581.72,
#     'y1': 156.68,
#     'y2': 387.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000565834.jpg',
#   'width': 640,
#   'height': 430,
#   'bboxes': [{'class': 'train',
#     'x1': 257.57,
#     'x2': 462.16,
#     'y1': 205.01,
#     'y2': 333.49}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000287304.jpg',
#   'width': 424,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 1.05,
#     'x2': 424.0,
#     'y1': 0.0,
#     'y2': 639.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000459343.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 71.97,
#     'x2': 640.0,
#     'y1': 71.97,
#     'y2': 281.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000557648.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 24.95,
#     'x2': 586.2900000000002,
#     'y1': 145.85,
#     'y2': 354.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000508502.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 2.15,
#     'x2': 302.42,
#     'y1': 40.18,
#     'y2': 454.53}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221785.jpg',
#   'width': 500,
#   'height': 377,
#   'bboxes': [{'class': 'train',
#     'x1': 224.16,
#     'x2': 490.78,
#     'y1': 188.08,
#     'y2': 331.57000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000180827.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 3.24,
#     'x2': 640.0,
#     'y1': 21.57,
#     'y2': 473.53}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000541280.jpg',
#   'width': 640,
#   'height': 420,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 146.29,
#     'y2': 376.58}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000361059.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 72.25,
#     'x2': 478.19,
#     'y1': 206.87,
#     'y2': 336.16}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000320111.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 268.76,
#     'x2': 640.0,
#     'y1': 212.7,
#     'y2': 354.21}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000205432.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 351.33,
#     'x2': 411.37,
#     'y1': 238.61,
#     'y2': 283.5300000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000238203.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 0.95,
#     'x2': 512.61,
#     'y1': 178.18,
#     'y2': 228.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000246396.jpg',
#   'width': 640,
#   'height': 411,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 0.0,
#     'y2': 411.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000303743.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 1.08,
#     'x2': 538.25,
#     'y1': 151.01,
#     'y2': 371.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000311939.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 1.08,
#     'x2': 640.0,
#     'y1': 220.63,
#     'y2': 307.8}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516740.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 17.27,
#     'x2': 618.91,
#     'y1': 197.91,
#     'y2': 211.34}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000311941.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 636.07,
#     'y1': 53.48,
#     'y2': 378.2000000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000483976.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 295.54,
#     'x2': 510.48,
#     'y1': 148.73,
#     'y2': 344.48}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000295565.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 2.89,
#     'x2': 510.9,
#     'y1': 195.2,
#     'y2': 331.12}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000107150.jpg',
#   'width': 640,
#   'height': 370,
#   'bboxes': [{'class': 'train',
#     'x1': 229.8,
#     'x2': 398.21,
#     'y1': 162.27,
#     'y2': 271.78000000000003}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000238223.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 99.24,
#     'x2': 330.79,
#     'y1': 136.63,
#     'y2': 602.61}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000000659.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 108.41,
#     'x2': 463.37,
#     'y1': 66.92,
#     'y2': 404.61}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000410261.jpg',
#   'width': 500,
#   'height': 340,
#   'bboxes': [{'class': 'train',
#     'x1': 123.78,
#     'x2': 382.02,
#     'y1': 64.18,
#     'y2': 167.33}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000098965.jpg',
#   'width': 640,
#   'height': 381,
#   'bboxes': [{'class': 'train',
#     'x1': 226.35,
#     'x2': 483.81,
#     'y1': 123.83,
#     'y2': 316.49}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393887.jpg',
#   'width': 500,
#   'height': 358,
#   'bboxes': [{'class': 'train',
#     'x1': 398.45,
#     'x2': 499.65,
#     'y1': 170.64,
#     'y2': 201.45}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000320160.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 92.48,
#     'x2': 258.79,
#     'y1': 282.16,
#     'y2': 414.13}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221859.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 43.93,
#     'x2': 586.4,
#     'y1': 102.19,
#     'y2': 337.13}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000533158.jpg',
#   'width': 640,
#   'height': 327,
#   'bboxes': [{'class': 'train',
#     'x1': 109.98,
#     'x2': 574.8199999999998,
#     'y1': 151.77,
#     'y2': 295.47}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000082600.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 123.6,
#     'x2': 529.59,
#     'y1': 100.87,
#     'y2': 335.72}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000189101.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 143.46,
#     'x2': 506.97,
#     'y1': 163.63,
#     'y2': 373.96}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000271034.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 393.71,
#     'x2': 491.87,
#     'y1': 75.58,
#     'y2': 119.8}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221883.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 115.83,
#     'x2': 549.49,
#     'y1': 67.97,
#     'y2': 359.9500000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000434877.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 195.24,
#     'x2': 370.29,
#     'y1': 193.99,
#     'y2': 343.07000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000533182.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 339.68,
#     'y1': 148.44,
#     'y2': 312.52}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000017100.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 202.0,
#     'x2': 455.44,
#     'y1': 207.71,
#     'y2': 347.78}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000287437.jpg',
#   'width': 640,
#   'height': 396,
#   'bboxes': [{'class': 'train',
#     'x1': 133.18,
#     'x2': 448.39,
#     'y1': 62.15,
#     'y2': 134.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000492244.jpg',
#   'width': 640,
#   'height': 429,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 100.26,
#     'y2': 374.05}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221909.jpg',
#   'width': 640,
#   'height': 478,
#   'bboxes': [{'class': 'train',
#     'x1': 231.5,
#     'x2': 640.0,
#     'y1': 170.41,
#     'y2': 340.82}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000082650.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 51.78,
#     'x2': 308.49,
#     'y1': 282.88,
#     'y2': 442.52}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000295642.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 87.96,
#     'x2': 225.79,
#     'y1': 148.11,
#     'y2': 262.01}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000123612.jpg',
#   'width': 640,
#   'height': 464,
#   'bboxes': [{'class': 'train',
#     'x1': 84.0,
#     'x2': 333.37,
#     'y1': 232.13,
#     'y2': 278.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000148205.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 147.5,
#     'x2': 334.25,
#     'y1': 150.51,
#     'y2': 344.23}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516849.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 80.41,
#     'x2': 640.0,
#     'y1': 149.8,
#     'y2': 307.74}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000271092.jpg',
#   'width': 640,
#   'height': 423,
#   'bboxes': [{'class': 'train',
#     'x1': 67.49,
#     'x2': 585.55,
#     'y1': 123.57,
#     'y2': 308.93}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000492286.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 40.99,
#     'x2': 497.26,
#     'y1': 21.0,
#     'y2': 348.91}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000434943.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 191.14,
#     'y2': 331.0499999999999}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000131840.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 170.04,
#     'x2': 397.23,
#     'y1': 211.06,
#     'y2': 377.68}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000025343.jpg',
#   'width': 640,
#   'height': 400,
#   'bboxes': [{'class': 'train',
#     'x1': 133.04,
#     'x2': 593.78,
#     'y1': 163.67,
#     'y2': 276.25}],
#   'imageset': 'test'},
# ...
#     'x2': 640.0,
#     'y1': 99.79,
#     'y2': 378.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000568955.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 110.74,
#     'x2': 322.16,
#     'y1': 9.63,
#     'y2': 607.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000511624.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 132.41,
#     'x2': 513.36,
#     'y1': 149.86,
#     'y2': 306.1}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000323208.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 375.34,
#     'x2': 597.8,
#     'y1': 164.47,
#     'y2': 216.14}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000175756.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 182.7,
#     'x2': 467.03,
#     'y1': 168.11,
#     'y2': 240.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000446094.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 39.34,
#     'x2': 376.14,
#     'y1': 154.62,
#     'y2': 323.43}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000437911.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 32.43,
#     'x2': 554.5899999999998,
#     'y1': 106.49,
#     'y2': 282.7}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000020119.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 500.89,
#     'x2': 640.0,
#     'y1': 0.67,
#     'y2': 381.61}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000495258.jpg',
#   'width': 640,
#   'height': 410,
#   'bboxes': [{'class': 'train',
#     'x1': 5.53,
#     'x2': 527.01,
#     'y1': 111.48,
#     'y2': 320.63}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000421531.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 1.38,
#     'x2': 612.0,
#     'y1': 15.85,
#     'y2': 429.36}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000396958.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 146.7,
#     'x2': 464.54,
#     'y1': 76.22,
#     'y2': 418.52}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000323230.jpg',
#   'width': 500,
#   'height': 359,
#   'bboxes': [{'class': 'train',
#     'x1': 10.46,
#     'x2': 479.74,
#     'y1': 168.23,
#     'y2': 243.89}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000503460.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 548.86,
#     'y1': 11.51,
#     'y2': 245.64}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000315045.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 28.79,
#     'x2': 638.0999999999998,
#     'y1': 158.99,
#     'y2': 368.17}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000364201.jpg',
#   'width': 640,
#   'height': 416,
#   'bboxes': [{'class': 'train',
#     'x1': 84.24,
#     'x2': 404.92,
#     'y1': 162.67,
#     'y2': 339.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000224942.jpg',
#   'width': 640,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 1.45,
#     'x2': 612.4300000000002,
#     'y1': 4.84,
#     'y2': 614.36}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000134832.jpg',
#   'width': 375,
#   'height': 500,
#   'bboxes': [{'class': 'train',
#     'x1': 257.53,
#     'x2': 375.0,
#     'y1': 48.61,
#     'y2': 86.74000000000002}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000200369.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 30.57,
#     'x2': 569.2700000000002,
#     'y1': 149.0,
#     'y2': 315.2}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000159409.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 54.17,
#     'x2': 160.74,
#     'y1': 26.59,
#     'y2': 90.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000323252.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 166.0,
#     'x2': 513.36,
#     'y1': 91.4,
#     'y2': 339.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000057870.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000384029.jpg',
#   'width': 640,
#   'height': 429,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000222016.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000520950.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000069675.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000547471.jpg',
#   'width': 383,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000122688.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000392136.jpg',
#   'width': 500,
#   'height': 347,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000398494.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000090570.jpg',
#   'width': 640,
#   'height': 429,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000504616.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000161919.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000457732.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000044404.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000004428.jpg',
#   'width': 429,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000170558.jpg',
#   'width': 481,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000405613.jpg',
#   'width': 640,
#   'height': 383,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000283524.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000037015.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000071631.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000491269.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000365363.jpg',
#   'width': 335,
#   'height': 500,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000064460.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000581674.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000470072.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000344806.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000084427.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000317237.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000409382.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000570608.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000469605.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000356702.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000405207.jpg',
#   'width': 417,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000472925.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000214704.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000279108.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000438422.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000257350.jpg',
#   'width': 500,
#   'height': 375,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000393493.jpg',
#   'width': 500,
#   'height': 400,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000062426.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000019380.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000485894.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000446014.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000530683.jpg',
#   'width': 425,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000292835.jpg',
#   'width': 390,
#   'height': 640,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000262845.jpg',
#   'width': 375,
#   'height': 500,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000299411.jpg',
#   'width': 480,
#   'height': 320,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000042493.jpg',
#   'width': 500,
#   'height': 375,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000239811.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000002024.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}],
#   'imageset': 'test'}]

# %%
val_imgs
# Out:
# [{'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000221190.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 285.47,
#     'x2': 441.75,
#     'y1': 238.49,
#     'y2': 270.02}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000335887.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 4.31,
#     'x2': 628.8499999999998,
#     'y1': 110.02,
#     'y2': 390.47}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000245793.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 97.87,
#     'x2': 498.01,
#     'y1': 144.89,
#     'y2': 356.95}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000057377.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 371.8,
#     'x2': 479.6,
#     'y1': 397.83,
#     'y2': 486.62}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000090155.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 66.68,
#     'x2': 522.09,
#     'y1': 169.52,
#     'y2': 328.3300000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000483374.jpg',
#   'width': 500,
#   'height': 332,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 500.0,
#     'y1': 0.0,
#     'y2': 332.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000507950.jpg',
#   'width': 640,
#   'height': 414,
#   'bboxes': [{'class': 'train',
#     'x1': 75.7,
#     'x2': 639.96,
#     'y1': 193.69,
#     'y2': 214.53}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000393274.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 141.38,
#     'x2': 477.05,
#     'y1': 121.19,
#     'y2': 352.02}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000057415.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 126.07,
#     'x2': 542.47,
#     'y1': 65.9,
#     'y2': 351.4600000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000426061.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 318.48,
#     'x2': 533.33,
#     'y1': 177.14,
#     'y2': 331.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000565331.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 88.58,
#     'x2': 640.0,
#     'y1': 129.82,
#     'y2': 355.73}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000467031.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 224.44,
#     'x2': 535.79,
#     'y1': 115.56,
#     'y2': 383.93}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000155736.jpg',
#   'width': 640,
#   'height': 348,
#   'bboxes': [{'class': 'train',
#     'x1': 210.25,
#     'x2': 424.58,
#     'y1': 141.18,
#     'y2': 269.95000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000532580.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 249.48,
#     'x2': 474.02,
#     'y1': 168.88,
#     'y2': 310.89}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000475238.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 155.45,
#     'x2': 416.44,
#     'y1': 189.99,
#     'y2': 323.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000434279.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 16.27,
#     'x2': 639.48,
#     'y1': 106.26,
#     'y2': 339.8400000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000016499.jpg',
#   'width': 640,
#   'height': 429,
#   'bboxes': [{'class': 'train',
#     'x1': 317.17,
#     'x2': 565.89,
#     'y1': 194.98,
#     'y2': 295.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000024693.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 2.16,
#     'x2': 601.0799999999998,
#     'y1': 260.0,
#     'y2': 344.32}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000065661.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 90.81,
#     'x2': 480.0,
#     'y1': 127.57,
#     'y2': 208.29}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000327807.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 388.46,
#     'y1': 0.0,
#     'y2': 320.56}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000516224.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 340.54,
#     'x2': 640.0,
#     'y1': 117.16,
#     'y2': 232.3}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000450695.jpg',
#   'width': 640,
#   'height': 448,
#   'bboxes': [{'class': 'train',
#     'x1': 112.76,
#     'x2': 638.27,
#     'y1': 232.56,
#     'y2': 430.89}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000508041.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 170.42,
#     'x2': 639.54,
#     'y1': 129.82,
#     'y2': 394.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000082059.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 115.15,
#     'x2': 479.78,
#     'y1': 83.48,
#     'y2': 354.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000008333.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 501.57,
#     'y1': 212.49,
#     'y2': 294.47}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000344205.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 264.71,
#     'x2': 398.41,
#     'y1': 110.3,
#     'y2': 264.56}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000106641.jpg',
#   'width': 640,
#   'height': 384,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 30.34,
#     'y2': 329.01}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000491683.jpg',
#   'width': 366,
#   'height': 500,
#   'bboxes': [{'class': 'train',
#     'x1': 1.22,
#     'x2': 364.59,
#     'y1': 149.04,
#     'y2': 165.48999999999995}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000344229.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 150.47,
#     'y2': 382.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000082085.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 118.3,
#     'x2': 639.5999999999998,
#     'y1': 0.0,
#     'y2': 405.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000573622.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 25.97,
#     'x2': 619.4,
#     'y1': 254.88,
#     'y2': 350.09}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000237758.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 449.96,
#     'x2': 632.73,
#     'y1': 228.03,
#     'y2': 328.43}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000426175.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 18.34,
#     'y2': 244.85}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000032960.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 586.64,
#     'y1': 65.88,
#     'y2': 399.59}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000196799.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 365.3,
#     'x2': 513.6600000000002,
#     'y1': 196.78,
#     'y2': 383.79}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000393411.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 427.0,
#     'y1': 199.91,
#     'y2': 503.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000344271.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 0.0,
#     'y2': 480.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000278747.jpg',
#   'width': 640,
#   'height': 481,
#   'bboxes': [{'class': 'train',
#     'x1': 197.8,
#     'x2': 638.81,
#     'y1': 147.0,
#     'y2': 385.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000131295.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 129.44,
#     'x2': 431.46,
#     'y1': 5.75,
#     'y2': 477.48}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000475365.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 4.79,
#     'x2': 453.7600000000001,
#     'y1': 0.96,
#     'y2': 426.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000278760.jpg',
#   'width': 428,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 308.17,
#     'y1': 514.34,
#     'y2': 640.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000114920.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 247.92,
#     'x2': 546.5699999999998,
#     'y1': 168.95,
#     'y2': 317.31}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000352491.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 124.49,
#     'x2': 639.01,
#     'y1': 147.98,
#     'y2': 425.52}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000565485.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 265.95,
#     'y1': 209.19,
#     'y2': 303.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000491764.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 639.6,
#     'y1': 89.69,
#     'y2': 276.28}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000475387.jpg',
#   'width': 640,
#   'height': 431,
#   'bboxes': [{'class': 'train',
#     'x1': 2.91,
#     'x2': 555.9399999999998,
#     'y1': 139.47,
#     'y2': 363.2}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000409856.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 282.25,
#     'x2': 317.85,
#     'y1': 171.47,
#     'y2': 223.73}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000393478.jpg',
#   'width': 375,
#   'height': 500,
#   'bboxes': [{'class': 'train',
#     'x1': 182.02,
#     'x2': 284.27,
#     'y1': 173.03,
#     'y2': 276.4}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000426268.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 7.68,
#     'x2': 599.7199999999998,
#     'y1': 44.14,
#     'y2': 274.43}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000180510.jpg',
#   'width': 478,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 155.33,
#     'x2': 431.46,
#     'y1': 307.78,
#     'y2': 540.76}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000123176.jpg',
#   'width': 640,
#   'height': 419,
#   'bboxes': [{'class': 'train',
#     'x1': 76.27,
#     'x2': 515.04,
#     'y1': 100.59,
#     'y2': 295.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000074030.jpg',
#   'width': 640,
#   'height': 432,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 639.67,
#     'y1': 45.39,
#     'y2': 424.49}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000524611.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 381.9,
#     'x2': 640.0,
#     'y1': 216.86,
#     'y2': 421.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000041300.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 35.33,
#     'x2': 625.5,
#     'y1': 7.16,
#     'y2': 386.28}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000139623.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 123.11,
#     'x2': 510.71,
#     'y1': 271.23,
#     'y2': 351.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000221547.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 2.16,
#     'x2': 637.48,
#     'y1': 2.16,
#     'y2': 473.53}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000450932.jpg',
#   'width': 500,
#   'height': 375,
#   'bboxes': [{'class': 'train',
#     'x1': 0.84,
#     'x2': 499.72,
#     'y1': 172.75,
#     'y2': 305.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000483722.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 167.16,
#     'x2': 413.42,
#     'y1': 264.36,
#     'y2': 412.12}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000532876.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 1.92,
#     'y2': 402.05}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000065942.jpg',
#   'width': 640,
#   'height': 390,
#   'bboxes': [{'class': 'train',
#     'x1': 0.88,
#     'x2': 638.9,
#     'y1': 51.71,
#     'y2': 258.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000205206.jpg',
#   'width': 428,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 208.59,
#     'x2': 402.96,
#     'y1': 197.53,
#     'y2': 461.43}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000115118.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 82.52,
#     'x2': 504.72,
#     'y1': 86.36,
#     'y2': 343.5200000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000065981.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 266.91,
#     'x2': 390.67,
#     'y1': 49.51,
#     'y2': 429.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000344513.jpg',
#   'width': 640,
#   'height': 478,
#   'bboxes': [{'class': 'train',
#     'x1': 20.36,
#     'x2': 561.6,
#     'y1': 178.98,
#     'y2': 383.69}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000524742.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 7.11,
#     'x2': 640.0,
#     'y1': 0.0,
#     'y2': 480.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000254407.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 40.2,
#     'x2': 580.07,
#     'y1': 79.93,
#     'y2': 348.9000000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000418251.jpg',
#   'width': 456,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 135.19,
#     'x2': 337.98,
#     'y1': 212.85,
#     'y2': 478.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000270810.jpg',
#   'width': 432,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 7.19,
#     'x2': 358.11,
#     'y1': 8.99,
#     'y2': 388.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000483803.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 93.08,
#     'x2': 575.73,
#     'y1': 94.28,
#     'y2': 348.56}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000139740.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 335.14,
#     'x2': 640.0,
#     'y1': 17.84,
#     'y2': 474.05}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000451046.jpg',
#   'width': 360,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 81.8,
#     'x2': 305.31,
#     'y1': 310.7,
#     'y2': 529.05}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000352748.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 2.87,
#     'x2': 640.0,
#     'y1': 88.82,
#     'y2': 363.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000049646.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 426.0,
#     'y1': 154.4,
#     'y2': 487.32000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000188918.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 1.07,
#     'x2': 196.51,
#     'y1': 181.58,
#     'y2': 288.9600000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000238071.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 162.02,
#     'x2': 398.7000000000001,
#     'y1': 31.36,
#     'y2': 305.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000557559.jpg',
#   'width': 640,
#   'height': 394,
#   'bboxes': [{'class': 'train',
#     'x1': 215.15,
#     'x2': 445.35,
#     'y1': 163.8,
#     'y2': 339.99}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000532983.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 2.16,
#     'x2': 640.0,
#     'y1': 1.08,
#     'y2': 353.8}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000295426.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 128.34,
#     'x2': 385.97,
#     'y1': 161.23,
#     'y2': 287.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000401935.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 186.15,
#     'x2': 442.35,
#     'y1': 93.08,
#     'y2': 337.76}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000565778.jpg',
#   'width': 640,
#   'height': 400,
#   'bboxes': [{'class': 'train',
#     'x1': 159.1,
#     'x2': 504.27,
#     'y1': 132.13,
#     'y2': 347.87}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000410141.jpg',
#   'width': 640,
#   'height': 408,
#   'bboxes': [{'class': 'train',
#     'x1': 139.96,
#     'x2': 536.99,
#     'y1': 128.62,
#     'y2': 312.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000459303.jpg',
#   'width': 640,
#   'height': 536,
#   'bboxes': [{'class': 'train',
#     'x1': 167.42,
#     'x2': 504.68,
#     'y1': 132.49,
#     'y2': 458.91}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000442942.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 406.52,
#     'x2': 640.0,
#     'y1': 247.7,
#     'y2': 381.63}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000574015.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 392.93,
#     'x2': 640.0,
#     'y1': 0.0,
#     'y2': 473.83}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000508482.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 480.0,
#     'y1': 2.38,
#     'y2': 536.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000115266.jpg',
#   'width': 446,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 53.21,
#     'x2': 421.39,
#     'y1': 286.2,
#     'y2': 484.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000492102.jpg',
#   'width': 500,
#   'height': 375,
#   'bboxes': [{'class': 'train',
#     'x1': 72.99,
#     'x2': 387.58,
#     'y1': 123.07,
#     'y2': 285.82}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000311883.jpg',
#   'width': 640,
#   'height': 289,
#   'bboxes': [{'class': 'train',
#     'x1': 55.85,
#     'x2': 640.0,
#     'y1': 112.15,
#     'y2': 216.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000533069.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 167.19,
#     'x2': 498.34,
#     'y1': 138.07,
#     'y2': 305.26}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000287318.jpg',
#   'width': 640,
#   'height': 570,
#   'bboxes': [{'class': 'train',
#     'x1': 106.31,
#     'x2': 562.31,
#     'y1': 143.78,
#     'y2': 483.22}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000066135.jpg',
#   'width': 500,
#   'height': 380,
#   'bboxes': [{'class': 'train',
#     'x1': 7.69,
#     'x2': 500.0,
#     'y1': 36.65,
#     'y2': 351.82}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000303704.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 3.16,
#     'x2': 426.67,
#     'y1': 0.0,
#     'y2': 628.94}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000025181.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 356.31,
#     'x2': 640.0,
#     'y1': 142.43,
#     'y2': 301.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000426611.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 10.74,
#     'x2': 637.85,
#     'y1': 2.25,
#     'y2': 480.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000443038.jpg',
#   'width': 640,
#   'height': 248,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 34.36,
#     'y2': 232.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000434867.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 62.52,
#     'x2': 508.79,
#     'y1': 149.08,
#     'y2': 281.81}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000516800.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 77.98,
#     'x2': 637.0,
#     'y1': 161.21,
#     'y2': 340.87}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000500423.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 640.0,
#     'y1': 9.6,
#     'y2': 332.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000565971.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 182.94,
#     'x2': 533.5699999999998,
#     'y1': 118.15,
#     'y2': 350.63}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000074465.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 7.3,
#     'x2': 591.0799999999998,
#     'y1': 59.59,
#     'y2': 292.3}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000565996.jpg',
#   'width': 640,
#   'height': 349,
#   'bboxes': [{'class': 'train',
#     'x1': 6.29,
#     'x2': 362.36,
#     'y1': 145.02,
#     'y2': 294.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000344816.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 143.41,
#     'x2': 505.79,
#     'y1': 52.02,
#     'y2': 378.69}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000303863.jpg',
#   'width': 640,
#   'height': 431,
#   'bboxes': [{'class': 'train',
#     'x1': 1.94,
#     'x2': 585.34,
#     'y1': 119.88,
#     'y2': 344.12}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000295675.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 598.43,
#     'y1': 88.62,
#     'y2': 341.14}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000238332.jpg',
#   'width': 640,
#   'height': 434,
#   'bboxes': [{'class': 'train',
#     'x1': 4.88,
#     'x2': 587.12,
#     'y1': 113.13,
#     'y2': 338.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000025346.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 163.49,
#     'x2': 484.7,
#     'y1': 118.77,
#     'y2': 323.62}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000361221.jpg',
#   'width': 640,
#   'height': 441,
#   'bboxes': [{'class': 'train',
#     'x1': 126.85,
#     'x2': 628.3,
#     'y1': 186.31,
#     'y2': 346.85}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000123663.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 78.86,
#     'x2': 289.48,
#     'y1': 188.98,
#     'y2': 422.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000197420.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 191.38,
#     'x2': 603.95,
#     'y1': 63.95,
#     'y2': 367.85}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000017198.jpg',
#   'width': 640,
#   'height': 383,
#   'bboxes': [{'class': 'train',
#     'x1': 112.5,
#     'x2': 639.76,
#     'y1': 55.82,
#     'y2': 270.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000303926.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 0.52,
#     'x2': 43.34,
#     'y1': 307.82,
#     'y2': 346.84}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000213816.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 3.78,
#     'y2': 435.14}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000230212.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 152.09,
#     'x2': 366.74,
#     'y1': 155.4,
#     'y2': 254.63}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000246616.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 351.79,
#     'y1': 281.52,
#     'y2': 425.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000172924.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 283.94,
#     'x2': 568.8299999999998,
#     'y1': 192.71,
#     'y2': 292.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000082812.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 0.82,
#     'x2': 326.53,
#     'y1': 224.76,
#     'y2': 355.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000484225.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 491.1,
#     'y1': 90.65,
#     'y2': 328.06}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000000923.jpg',
#   'width': 640,
#   'height': 485,
#   'bboxes': [{'class': 'train',
#     'x1': 168.55,
#     'x2': 457.81,
#     'y1': 131.58,
#     'y2': 402.35}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000328607.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 612.0,
#     'y1': 0.34,
#     'y2': 329.04}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000017328.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 606.93,
#     'y1': 83.29,
#     'y2': 319.74}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000091063.jpg',
#   'width': 640,
#   'height': 479,
#   'bboxes': [{'class': 'train',
#     'x1': 148.54,
#     'x2': 494.07,
#     'y1': 337.99,
#     'y2': 472.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000254919.jpg',
#   'width': 640,
#   'height': 414,
#   'bboxes': [{'class': 'train',
#     'x1': 57.4,
#     'x2': 574.47,
#     'y1': 192.52,
#     'y2': 242.33}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000500703.jpg',
#   'width': 427,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 106.67,
#     'x2': 334.41,
#     'y1': 261.62,
#     'y2': 304.86}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000279521.jpg',
#   'width': 640,
#   'height': 338,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 560.31,
#     'y1': 0.0,
#     'y2': 299.51}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000287725.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 214.41,
#     'x2': 539.86,
#     'y1': 107.69,
#     'y2': 248.4}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000500717.jpg',
#   'width': 640,
#   'height': 549,
#   'bboxes': [{'class': 'train',
#     'x1': 32.05,
#     'x2': 553.1899999999998,
#     'y1': 186.11,
#     'y2': 423.28}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000508917.jpg',
#   'width': 640,
#   'height': 370,
#   'bboxes': [{'class': 'train',
#     'x1': 182.92,
#     'x2': 456.47,
#     'y1': 140.72,
#     'y2': 288.72}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000050165.jpg',
#   'width': 640,
#   'height': 431,
#   'bboxes': [{'class': 'train',
#     'x1': 116.22,
#     'x2': 453.28,
#     'y1': 246.98,
#     'y2': 328.33}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000427001.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 426.0,
#     'y1': 218.61,
#     'y2': 496.18}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000140292.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 256.78,
#     'x2': 317.36,
#     'y1': 285.15,
#     'y2': 343.80999999999995}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000369675.jpg',
#   'width': 640,
#   'height': 429,
#   'bboxes': [{'class': 'train',
#     'x1': 2.89,
#     'x2': 639.16,
#     'y1': 90.62,
#     'y2': 413.58}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000058384.jpg',
#   'width': 640,
#   'height': 466,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 210.48,
#     'y1': 179.35,
#     'y2': 220.41}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000492562.jpg',
#   'width': 640,
#   'height': 390,
#   'bboxes': [{'class': 'train',
#     'x1': 0.88,
#     'x2': 525.84,
#     'y1': 231.43,
#     'y2': 331.3400000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000467990.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 40.9,
#     'x2': 544.57,
#     'y1': 93.2,
#     'y2': 395.62}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000377879.jpg',
#   'width': 640,
#   'height': 464,
#   'bboxes': [{'class': 'train',
#     'x1': 199.3,
#     'x2': 638.21,
#     'y1': 67.92,
#     'y2': 415.02}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000156696.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 39.18,
#     'x2': 640.0,
#     'y1': 1.63,
#     'y2': 355.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000074789.jpg',
#   'width': 480,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 89.59,
#     'x2': 328.27,
#     'y1': 151.68,
#     'y2': 490.23}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000525361.jpg',
#   'width': 640,
#   'height': 389,
#   'bboxes': [{'class': 'train',
#     'x1': 147.94,
#     'x2': 545.64,
#     'y1': 80.15,
#     'y2': 344.7000000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000508996.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 364.76,
#     'x2': 387.69,
#     'y1': 301.35,
#     'y2': 331.5900000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000279621.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 163.12,
#     'x2': 447.15,
#     'y1': 94.04,
#     'y2': 373.27}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000296012.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 2.88,
#     'x2': 226.45,
#     'y1': 13.43,
#     'y2': 168.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000509028.jpg',
#   'width': 640,
#   'height': 360,
#   'bboxes': [{'class': 'train',
#     'x1': 58.67,
#     'x2': 520.0,
#     'y1': 8.0,
#     'y2': 346.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000320627.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 2.16,
#     'x2': 344.0900000000001,
#     'y1': 186.88,
#     'y2': 258.07}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000476279.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 317.12,
#     'x2': 636.4,
#     'y1': 119.73,
#     'y2': 354.88}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000287874.jpg',
#   'width': 640,
#   'height': 434,
#   'bboxes': [{'class': 'train',
#     'x1': 200.91,
#     'x2': 403.77,
#     'y1': 126.79,
#     'y2': 314.04}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000263299.jpg',
#   'width': 500,
#   'height': 335,
#   'bboxes': [{'class': 'train',
#     'x1': 6.02,
#     'x2': 298.11,
#     'y1': 3.01,
#     'y2': 321.45}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000558213.jpg',
#   'width': 640,
#   'height': 432,
#   'bboxes': [{'class': 'train',
#     'x1': 314.89,
#     'x2': 640.0,
#     'y1': 190.16,
#     'y2': 316.66}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000001171.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 74.67,
#     'x2': 493.97,
#     'y1': 35.42,
#     'y2': 378.13}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000025747.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 178.26,
#     'x2': 438.12,
#     'y1': 148.29,
#     'y2': 348.02}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000558235.jpg',
#   'width': 640,
#   'height': 468,
#   'bboxes': [{'class': 'train',
#     'x1': 80.43,
#     'x2': 487.72,
#     'y1': 43.36,
#     'y2': 425.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000066717.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 47.46,
#     'x2': 640.0,
#     'y1': 0.0,
#     'y2': 422.83}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000304300.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 70.64,
#     'x2': 430.72,
#     'y1': 91.56,
#     'y2': 308.95}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000050354.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 49.4,
#     'x2': 468.19,
#     'y1': 118.84,
#     'y2': 342.19}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000074937.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 57.17,
#     'x2': 640.0,
#     'y1': 197.21,
#     'y2': 301.8400000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000353489.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 110.02,
#     'x2': 352.72,
#     'y1': 163.96,
#     'y2': 351.64}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000394449.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 418.34,
#     'x2': 640.0,
#     'y1': 160.53,
#     'y2': 388.37}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000500952.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 0.6,
#     'x2': 640.0,
#     'y1': 103.44,
#     'y2': 318.55}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000091359.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 257.16,
#     'x2': 640.0,
#     'y1': 92.12,
#     'y2': 312.81}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000304365.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 245.09,
#     'x2': 406.97,
#     'y1': 234.45,
#     'y2': 398.27}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000148724.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 166.39,
#     'x2': 542.45,
#     'y1': 171.87,
#     'y2': 358.4600000000001}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000476406.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 286.91,
#     'x2': 527.75,
#     'y1': 140.09,
#     'y2': 350.24}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000566524.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 264.27,
#     'x2': 445.48,
#     'y1': 131.6,
#     'y2': 300.94}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000140540.jpg',
#   'width': 479,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 55.97,
#     'x2': 433.02,
#     'y1': 217.0,
#     'y2': 339.73}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000492805.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 169.64,
#     'x2': 636.3299999999998,
#     'y1': 87.18,
#     'y2': 427.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000460049.jpg',
#   'width': 640,
#   'height': 359,
#   'bboxes': [{'class': 'train',
#     'x1': 561.98,
#     'x2': 620.5600000000002,
#     'y1': 114.46,
#     'y2': 159.95999999999995}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000419096.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 1.38,
#     'x2': 587.24,
#     'y1': 229.67,
#     'y2': 446.97}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000009497.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 1.0,
#     'x2': 639.6,
#     'y1': 163.7,
#     'y2': 318.54}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000435481.jpg',
#   'width': 640,
#   'height': 424,
#   'bboxes': [{'class': 'train',
#     'x1': 180.08,
#     'x2': 468.78,
#     'y1': 73.37,
#     'y2': 282.03}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000058651.jpg',
#   'width': 640,
#   'height': 380,
#   'bboxes': [{'class': 'train',
#     'x1': 121.88,
#     'x2': 539.9,
#     'y1': 184.7,
#     'y2': 343.71}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000107800.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 286.92,
#     'x2': 640.0,
#     'y1': 17.33,
#     'y2': 473.6}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000550173.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 266.51,
#     'x2': 564.11,
#     'y1': 131.61,
#     'y2': 295.32000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000410912.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 181.42,
#     'x2': 605.16,
#     'y1': 125.17,
#     'y2': 288.56}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000451896.jpg',
#   'width': 478,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 120.66,
#     'x2': 213.7,
#     'y1': 270.79,
#     'y2': 321.42}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000001342.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 155.47,
#     'x2': 348.67,
#     'y1': 219.01,
#     'y2': 267.93}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000050496.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 47.14,
#     'x2': 353.2,
#     'y1': 88.3,
#     'y2': 259.67}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000034115.jpg',
#   'width': 320,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 320.0,
#     'y1': 0.0,
#     'y2': 478.81}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000001353.jpg',
#   'width': 375,
#   'height': 500,
#   'bboxes': [{'class': 'train',
#     'x1': 66.29,
#     'x2': 256.18,
#     'y1': 323.6,
#     'y2': 462.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000337226.jpg',
#   'width': 640,
#   'height': 474,
#   'bboxes': [{'class': 'train',
#     'x1': 10.63,
#     'x2': 583.47,
#     'y1': 36.77,
#     'y2': 454.44}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000558421.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 299.74,
#     'x2': 533.14,
#     'y1': 241.98,
#     'y2': 351.93}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000001374.jpg',
#   'width': 640,
#   'height': 425,
#   'bboxes': [{'class': 'train',
#     'x1': 46.69,
#     'x2': 544.11,
#     'y1': 68.93,
#     'y2': 350.99}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000345456.jpg',
#   'width': 640,
#   'height': 344,
#   'bboxes': [{'class': 'train',
#     'x1': 215.39,
#     'x2': 516.77,
#     'y1': 47.65,
#     'y2': 322.69}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000058737.jpg',
#   'width': 640,
#   'height': 436,
#   'bboxes': [{'class': 'train',
#     'x1': 68.58,
#     'x2': 640.0,
#     'y1': 138.15,
#     'y2': 339.98}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000279933.jpg',
#   'width': 426,
#   'height': 640,
#   'bboxes': [{'class': 'train',
#     'x1': 140.94,
#     'x2': 297.7100000000001,
#     'y1': 100.77,
#     'y2': 494.84}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000574856.jpg',
#   'width': 640,
#   'height': 237,
#   'bboxes': [{'class': 'train',
#     'x1': 26.67,
#     'x2': 562.9599999999998,
#     'y1': 15.41,
#     'y2': 212.15}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000492937.jpg',
#   'width': 612,
#   'height': 612,
#   'bboxes': [{'class': 'train',
#     'x1': 423.59,
#     'x2': 588.62,
#     'y1': 82.52,
#     'y2': 303.94}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000140686.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 48.94,
#     'x2': 549.8199999999998,
#     'y1': 105.55,
#     'y2': 296.5}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000148910.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 271.46,
#     'x2': 346.42,
#     'y1': 140.94,
#     'y2': 187.75}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000214468.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 57.17,
#     'x2': 640.0,
#     'y1': 250.52,
#     'y2': 473.8}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000517596.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 1.91,
#     'x2': 616.5699999999998,
#     'y1': 46.91,
#     'y2': 368.6}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000509404.jpg',
#   'width': 640,
#   'height': 443,
#   'bboxes': [{'class': 'train',
#     'x1': 47.78,
#     'x2': 639.11,
#     'y1': 176.2,
#     'y2': 303.63}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000091617.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 1.76,
#     'x2': 87.31,
#     'y1': 230.55,
#     'y2': 251.36}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000566757.jpg',
#   'width': 500,
#   'height': 333,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 500.0,
#     'y1': 0.0,
#     'y2': 333.0}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000173547.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 264.27,
#     'x2': 424.99,
#     'y1': 115.42,
#     'y2': 289.08}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000230903.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 65.95,
#     'x2': 530.8100000000002,
#     'y1': 103.24,
#     'y2': 378.92}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000042499.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 173.47,
#     'x2': 501.36,
#     'y1': 99.76,
#     'y2': 376.51}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000148999.jpg',
#   'width': 640,
#   'height': 427,
#   'bboxes': [{'class': 'train',
#     'x1': 83.48,
#     'x2': 566.13,
#     'y1': 312.52,
#     'y2': 417.11}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000468499.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 155.81,
#     'x2': 487.63,
#     'y1': 141.38,
#     'y2': 315.47}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000435742.jpg',
#   'width': 640,
#   'height': 426,
#   'bboxes': [{'class': 'train',
#     'x1': 68.93,
#     'x2': 557.1500000000002,
#     'y1': 124.45,
#     'y2': 314.95}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000312866.jpg',
#   'width': 640,
#   'height': 480,
#   'bboxes': [{'class': 'train',
#     'x1': 0.0,
#     'x2': 640.0,
#     'y1': 0.1,
#     'y2': 376.57000000000005}],
#   'imageset': 'test'},
#  {'filepath': 'COCO_extracted_dataset/train_for_validation/COCO_val2014_000000214575.jpg',
#   'width': 640,
#   'height': 428,
#   'bboxes': [{'class': 'train',
#     'x1': 0.96,
#     'x2': 640.0,
#     'y1': 13.98,
#     'y2': 423.66}],
#   'imageset': 'test'}]

# %%
class_mapping
# Out:
# {'train': 0, 'bg': 1}

# %% [markdown]
# #### Save model weights path and config

# %%
with open(config_output_filename, 'wb') as config_f:
	pickle.dump(C,config_f)
	print(f'Config has been written to {config_output_filename}, and can be loaded when testing to ensure correct results')

#random.shuffle(train_imgs)

num_imgs = len(train_imgs)
print(f'Num train samples {len(train_imgs)}')
print(f'Num val samples {len(val_imgs)}')
# Out:
# Config has been written to coco_config_train.pickle, and can be loaded when testing to ensure correct results
# Num train samples 1000
# Num val samples 200

# %% [markdown]
# #### Training Setup - Faster R-CNN model initialization

# %%
data_gen_train = data_generators.get_anchor_gt(train_imgs, classes_count, C, nn.get_img_output_length, K.common.image_dim_ordering(), mode='train')
data_gen_val = data_generators.get_anchor_gt(val_imgs, classes_count, C, nn.get_img_output_length,K.common.image_dim_ordering(), mode='val')

# %%
data_gen_train
# Out:
# <generator object get_anchor_gt at 0x00000231855BF258>

# %%
data_gen_val
# Out:
# <generator object get_anchor_gt at 0x00000231855BF2B0>

# %%
if K.common.image_dim_ordering() == 'th':
	input_shape_img = (3, None, None)
else:
	input_shape_img = (None, None, 3)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(None, 4))

# %%
img_input
# Out:
# <tf.Tensor 'input_3:0' shape=(None, None, None, 3) dtype=float32>

# %%
roi_input
# Out:
# <tf.Tensor 'input_4:0' shape=(None, None, 4) dtype=float32>

# %%
# define the base network (resnet here, can be VGG, Inception, etc)
shared_layers = nn.nn_base(img_input, trainable=True)
shared_layers
# Out:
# <tf.Tensor 'activation_89/Relu:0' shape=(None, None, None, 1024) dtype=float32>

# %%
C.anchor_box_scales
# Out:
# [128, 256, 512]

# %%
C.anchor_box_ratios
# Out:
# [[1, 1],
#  [0.7071067811865475, 1.414213562373095],
#  [1.414213562373095, 0.7071067811865475]]

# %%
# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
num_anchors
# Out:
# 9

# %%
rpn = nn.rpn(shared_layers, num_anchors)
rpn
# Out:
# [<tf.Tensor 'rpn_out_class_1/Sigmoid:0' shape=(None, None, None, 9) dtype=float32>,
#  <tf.Tensor 'rpn_out_regress_1/BiasAdd:0' shape=(None, None, None, 36) dtype=float32>,
#  <tf.Tensor 'activation_89/Relu:0' shape=(None, None, None, 1024) dtype=float32>]

# %%
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, nb_classes=len(classes_count), trainable=True)
classifier
# Out:
# [<tf.Tensor 'dense_class_2_1/Reshape_1:0' shape=(1, 32, 2) dtype=float32>,
#  <tf.Tensor 'dense_regress_2_1/Reshape_1:0' shape=(1, 32, 4) dtype=float32>]

# %%
model_rpn = Model(img_input, rpn[:2])
model_rpn.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_89[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier = Model([img_input, roi_input], classifier)
model_classifier.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_2 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_89[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 32, 7, 7, 204 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 32, 7, 7, 204 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 7, 7, 204 0           add_32[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_98[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_2[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_2[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
# this is a model that holds both the RPN and the classifier, used to load/save weights for the models
model_all = Model([img_input, roi_input], rpn[:2] + classifier)
model_all.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_2 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_89[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 32, 7, 7, 204 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 32, 7, 7, 204 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 7, 7, 204 0           add_32[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_98[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_89[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_2[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_2[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
try:
	print('loading weights from {C.base_net_weights}')
	model_rpn.load_weights(C.base_net_weights, by_name=True)
	model_classifier.load_weights(C.base_net_weights, by_name=True)    
	#model_rpn.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
	#model_classifier.load_weights('./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5', by_name=True)
except:
	print('Could not load pretrained model weights. Weights can be found in the keras application folder \
		https://github.com/fchollet/keras/tree/master/keras/applications')
# Out:
# loading weights from {C.base_net_weights}

# %%
optimizer = Adam(lr=1e-5)
optimizer_classifier = Adam(lr=1e-5)
model_rpn.compile(optimizer=optimizer, loss=[losses.rpn_loss_cls(num_anchors), losses.rpn_loss_regr(num_anchors)])
model_classifier.compile(optimizer=optimizer_classifier, loss=[losses.class_loss_cls, losses.class_loss_regr(len(classes_count)-1)], metrics={f'dense_class_{len(classes_count)}': 'accuracy'})
model_all.compile(optimizer='sgd', loss='mae')

# %%
model_rpn.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_89[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# ==================================================================================================
# Total params: 13,331,373
# Trainable params: 13,270,189
# Non-trainable params: 61,184
# __________________________________________________________________________________________________

# %%
model_classifier.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_2 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_89[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 32, 7, 7, 204 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 32, 7, 7, 204 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 7, 7, 204 0           add_32[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_98[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_2[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_2[0][0]
# ==================================================================================================
# Total params: 23,600,006
# Trainable params: 23,493,766
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %%
model_all.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (FixedBatchNormalizati (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 6 0           activation_50[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (FixedBatchNormal (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (FixedBatchNormal (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_52[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (FixedBatchNormali (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, None, None, 2 0           add_17[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (FixedBatchNormal (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (FixedBatchNormal (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, None, None, 2 0           add_18[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (FixedBatchNormal (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (FixedBatchNormal (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_58[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (FixedBatchNormal (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, None, None, 2 0           add_19[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (FixedBatchNormal (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (FixedBatchNormal (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_61[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (FixedBatchNormali (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, None, None, 5 0           add_20[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (FixedBatchNormal (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (FixedBatchNormal (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, None, None, 5 0           add_21[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (FixedBatchNormal (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (FixedBatchNormal (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, None, None, 5 0           add_22[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (FixedBatchNormal (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (FixedBatchNormal (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_70[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (FixedBatchNormal (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 5 0           add_23[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_73[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (FixedBatchNormali (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 1 0           add_24[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 1 0           add_25[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           add_26[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           add_27[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 1 0           add_28[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (FixedBatchNormal (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_88[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (FixedBatchNormal (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_86[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           add_29[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 4)      0
# __________________________________________________________________________________________________
# roi_pooling_conv_2 (RoiPoolingC (None, 32, 14, 14, 1 0           activation_89[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (TimeDistributed (None, 32, 7, 7, 512 524800      roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 32, 7, 7, 512 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_91[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (TimeDistributed) (None, 32, 7, 7, 204 2099200     roi_pooling_conv_2[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (TimeDistributed)  (None, 32, 7, 7, 204 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 7, 7, 204 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 32, 7, 7, 204 0           add_30[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 32, 7, 7, 512 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 32, 7, 7, 204 0           bn5b_branch2c[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 32, 7, 7, 204 0           add_31[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (TimeDistributed (None, 32, 7, 7, 512 1049088     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (TimeDistributed (None, 32, 7, 7, 512 2359808     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (TimeDistributed) (None, 32, 7, 7, 512 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 7, 7, 512 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (TimeDistributed (None, 32, 7, 7, 204 1050624     activation_97[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (TimeDistributed) (None, 32, 7, 7, 204 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 32, 7, 7, 204 0           bn5c_branch2c[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 7, 7, 204 0           add_32[0][0]
# __________________________________________________________________________________________________
# avg_pool (TimeDistributed)      (None, 32, 1, 1, 204 0           activation_98[0][0]
# __________________________________________________________________________________________________
# rpn_conv1 (Conv2D)              (None, None, None, 5 4719104     activation_89[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 32, 2048)     0           avg_pool[0][0]
# __________________________________________________________________________________________________
# rpn_out_class (Conv2D)          (None, None, None, 9 4617        rpn_conv1[0][0]
# __________________________________________________________________________________________________
# rpn_out_regress (Conv2D)        (None, None, None, 3 18468       rpn_conv1[0][0]
# __________________________________________________________________________________________________
# dense_class_2 (TimeDistributed) (None, 32, 2)        4098        time_distributed_2[0][0]
# __________________________________________________________________________________________________
# dense_regress_2 (TimeDistribute (None, 32, 4)        8196        time_distributed_2[0][0]
# ==================================================================================================
# Total params: 28,342,195
# Trainable params: 28,235,955
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %% [markdown]
# #### Faster R-CNN model Training - 5 Epochs

# %%
#number of images in the dataset
epoch_length = 1000 
num_epochs = int(5)
iter_num = 0

# %%
losses = np.zeros((epoch_length, 5))
rpn_accuracy_rpn_monitor = []
rpn_accuracy_for_epoch = []
start_time = time.time()

best_loss = np.Inf

# %%
class_mapping_inv = {v: k for k, v in class_mapping.items()}
print('Starting training')

vis = True
index = 0
# Out:
# Starting training

# %%
for epoch_num in range(num_epochs):

	progbar = generic_utils.Progbar(epoch_length)
	print(f'Epoch {epoch_num + 1}/{num_epochs}')

	while True:
		try:

			if len(rpn_accuracy_rpn_monitor) == epoch_length and C.verbose:
				mean_overlapping_bboxes = float(sum(rpn_accuracy_rpn_monitor))/len(rpn_accuracy_rpn_monitor)
				rpn_accuracy_rpn_monitor = []
				print(f'Average number of overlapping bounding boxes from RPN = {mean_overlapping_bboxes} for {epoch_length} previous iterations')
				if mean_overlapping_bboxes == 0:
					print('RPN is not producing bounding boxes that overlap the ground truth boxes. Check RPN settings or keep training.')

			X, Y, img_data = next(data_gen_train)
			print(f'X is {X.shape}')
			print(f'Y is {len(Y)}')
			print(f'img_data is {img_data}')
			print(f'index is {index}')
			index = index + 1

			loss_rpn = model_rpn.train_on_batch(X, Y)

			P_rpn = model_rpn.predict_on_batch(X)

			R = roi_helpers.rpn_to_roi(P_rpn[0], P_rpn[1], C, K.common.image_dim_ordering(), use_regr=True, overlap_thresh=0.7, max_boxes=300)
			# note: calc_iou converts from (x1,y1,x2,y2) to (x,y,w,h) format
			X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)

			if X2 is None:
				rpn_accuracy_rpn_monitor.append(0)
				rpn_accuracy_for_epoch.append(0)
				continue

			neg_samples = np.where(Y1[0, :, -1] == 1)
			pos_samples = np.where(Y1[0, :, -1] == 0)

			if len(neg_samples) > 0:
				neg_samples = neg_samples[0]
			else:
				neg_samples = []

			if len(pos_samples) > 0:
				pos_samples = pos_samples[0]
			else:
				pos_samples = []
			
			rpn_accuracy_rpn_monitor.append(len(pos_samples))
			rpn_accuracy_for_epoch.append((len(pos_samples)))

			if C.num_rois > 1:
				if len(pos_samples) < C.num_rois//2:
					selected_pos_samples = pos_samples.tolist()
				else:
					selected_pos_samples = np.random.choice(pos_samples, C.num_rois//2, replace=False).tolist()
				try:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=False).tolist()
				except:
					selected_neg_samples = np.random.choice(neg_samples, C.num_rois - len(selected_pos_samples), replace=True).tolist()

				sel_samples = selected_pos_samples + selected_neg_samples
			else:
				# in the extreme case where num_rois = 1, we pick a random pos or neg sample
				selected_pos_samples = pos_samples.tolist()
				selected_neg_samples = neg_samples.tolist()
				if np.random.randint(0, 2):
					sel_samples = random.choice(neg_samples)
				else:
					sel_samples = random.choice(pos_samples)

			loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])

			losses[iter_num, 0] = loss_rpn[1]
			losses[iter_num, 1] = loss_rpn[2]

			losses[iter_num, 2] = loss_class[1]
			losses[iter_num, 3] = loss_class[2]
			losses[iter_num, 4] = loss_class[3]

			progbar.update(iter_num+1, [('rpn_cls', losses[iter_num, 0]), ('rpn_regr', losses[iter_num, 1]),
									  ('detector_cls', losses[iter_num, 2]), ('detector_regr', losses[iter_num, 3])])

			iter_num += 1
			
			if iter_num == epoch_length:
				loss_rpn_cls = np.mean(losses[:, 0])
				loss_rpn_regr = np.mean(losses[:, 1])
				loss_class_cls = np.mean(losses[:, 2])
				loss_class_regr = np.mean(losses[:, 3])
				class_acc = np.mean(losses[:, 4])

				mean_overlapping_bboxes = float(sum(rpn_accuracy_for_epoch)) / len(rpn_accuracy_for_epoch)
				rpn_accuracy_for_epoch = []

				if C.verbose:
					print(f'Mean number of bounding boxes from RPN overlapping ground truth boxes: {mean_overlapping_bboxes}')
					print(f'Classifier accuracy for bounding boxes from RPN: {class_acc}')
					print(f'Loss RPN classifier: {loss_rpn_cls}')
					print(f'Loss RPN regression: {loss_rpn_regr}')
					print(f'Loss Detector classifier: {loss_class_cls}')
					print(f'Loss Detector regression: {loss_class_regr}')
					print(f'Elapsed time: {time.time() - start_time}')

				curr_loss = loss_rpn_cls + loss_rpn_regr + loss_class_cls + loss_class_regr
				iter_num = 0
				start_time = time.time()

				if curr_loss < best_loss:
					if C.verbose:
						print(f'Total loss decreased from {best_loss} to {curr_loss}, saving weights')
					best_loss = curr_loss
				model_all.save_weights(model_path_regex.group(1) + "_" + '{:04d}'.format(epoch_num) + model_path_regex.group(2))

				break

		except Exception as e:
			print(f'Exception: {e}')
			continue

print('Training complete, exiting.')
# Out:
# Epoch 1/5
# X is (1, 416, 559, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041116.jpg', 'width': 640, 'height': 476, 'bboxes': [{'class': 'train', 'x1': 16.04, 'x2': 434.28, 'y1': 23.53, 'y2': 415.03}], 'imageset': 'test'}
# index is 0
#    1/1000 [..............................] - ETA: 8:17:05 - rpn_cls: 3.2960 - rpn_regr: 0.2890 - detector_cls: 0.6931 - detector_regr: 0.5205X is (1, 416, 477, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000101315.jpg', 'width': 500, 'height': 436, 'bboxes': [{'class': 'train', 'x1': 134.61, 'x2': 314.12, 'y1': 223.47, 'y2': 366.03}], 'imageset': 'test'}
# index is 1
#    2/1000 [..............................] - ETA: 4:42:23 - rpn_cls: 5.5456 - rpn_regr: 0.2235 - detector_cls: 0.6897 - detector_regr: 0.5264X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000458970.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 33.44, 'x2': 408.81, 'y1': 148.85, 'y2': 347.33}], 'imageset': 'test'}
# index is 2
#    3/1000 [..............................] - ETA: 3:31:47 - rpn_cls: 7.0319 - rpn_regr: 0.1625 - detector_cls: 0.6868 - detector_regr: 0.5420X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516633.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 41.17, 'x2': 536.14, 'y1': 145.84, 'y2': 316.26}], 'imageset': 'test'}
# index is 3
#    4/1000 [..............................] - ETA: 2:58:04 - rpn_cls: 8.0251 - rpn_regr: 0.1651 - detector_cls: 0.6832 - detector_regr: 0.5263X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000221883.jpg', 'width': 640, 'height': 426, 'bboxes': [{'class': 'train', 'x1': 115.83, 'x2': 549.49, 'y1': 67.97, 'y2': 359.9500000000001}], 'imageset': 'test'}
# index is 4
#    5/1000 [..............................] - ETA: 2:37:37 - rpn_cls: 7.9882 - rpn_regr: 0.1921 - detector_cls: 0.6805 - detector_regr: 0.4927X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000287839.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 211.42, 'x2': 429.3, 'y1': 166.11, 'y2': 312.81}], 'imageset': 'test'}
# index is 5
#    6/1000 [..............................] - ETA: 2:22:38 - rpn_cls: 7.7252 - rpn_regr: 0.1818 - detector_cls: 0.6766 - detector_regr: 0.4984X is (1, 416, 614, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000009465.jpg', 'width': 640, 'height': 433, 'bboxes': [{'class': 'train', 'x1': 0.97, 'x2': 75.9, 'y1': 204.58, 'y2': 388.48}], 'imageset': 'test'}
# index is 6
#    7/1000 [..............................] - ETA: 2:12:50 - rpn_cls: 7.6649 - rpn_regr: 0.1706 - detector_cls: 0.6757 - detector_regr: 0.5090X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000387672.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 88.28, 'x2': 446.19000000000005, 'y1': 167.92, 'y2': 334.88}], 'imageset': 'test'}
# index is 7
#    8/1000 [..............................] - ETA: 2:06:58 - rpn_cls: 7.8453 - rpn_regr: 0.1539 - detector_cls: 0.6708 - detector_regr: 0.5270X is (1, 416, 644, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000387764.jpg', 'width': 640, 'height': 413, 'bboxes': [{'class': 'train', 'x1': 168.91, 'x2': 304.41, 'y1': 148.73, 'y2': 257.31}], 'imageset': 'test'}
# index is 8
#    9/1000 [..............................] - ETA: 2:03:27 - rpn_cls: 7.4059 - rpn_regr: 0.1439 - detector_cls: 0.6653 - detector_regr: 0.5028X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000336939.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 105.08, 'x2': 433.69, 'y1': 141.47, 'y2': 359.27}], 'imageset': 'test'}
# index is 9
#   10/1000 [..............................] - ETA: 2:00:03 - rpn_cls: 7.6616 - rpn_regr: 0.1393 - detector_cls: 0.6609 - detector_regr: 0.4992X is (1, 416, 630, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000369633.jpg', 'width': 640, 'height': 422, 'bboxes': [{'class': 'train', 'x1': 18.02, 'x2': 561.4, 'y1': 100.52, 'y2': 396.4}], 'imageset': 'test'}
# index is 10
#   11/1000 [..............................] - ETA: 1:58:20 - rpn_cls: 7.3282 - rpn_regr: 0.1753 - detector_cls: 0.6555 - detector_regr: 0.4904X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172615.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 76.22, 'x2': 299.15, 'y1': 274.79, 'y2': 456.01}], 'imageset': 'test'}
# index is 11
#   12/1000 [..............................] - ETA: 1:57:45 - rpn_cls: 7.1670 - rpn_regr: 0.1766 - detector_cls: 0.6488 - detector_regr: 0.4965X is (1, 416, 640, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000256869.jpg', 'width': 640, 'height': 416, 'bboxes': [{'class': 'train', 'x1': 199.12, 'x2': 640.0, 'y1': 83.2, 'y2': 357.11}], 'imageset': 'test'}
# index is 12
#   13/1000 [..............................] - ETA: 1:57:06 - rpn_cls: 7.0509 - rpn_regr: 0.1888 - detector_cls: 0.6415 - detector_regr: 0.4985X is (1, 416, 719, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000273641.jpg', 'width': 640, 'height': 370, 'bboxes': [{'class': 'train', 'x1': 280.49, 'x2': 384.81, 'y1': 206.61, 'y2': 296.3}], 'imageset': 'test'}
# index is 13
#   14/1000 [..............................] - ETA: 1:56:59 - rpn_cls: 6.6597 - rpn_regr: 0.1824 - detector_cls: 0.6313 - detector_regr: 0.4973X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000377878.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 161.71, 'x2': 601.83, 'y1': 175.27, 'y2': 381.74}], 'imageset': 'test'}
# index is 14
#   15/1000 [..............................] - ETA: 1:55:44 - rpn_cls: 6.8457 - rpn_regr: 0.1765 - detector_cls: 0.6261 - detector_regr: 0.4968X is (1, 416, 758, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000411856.jpg', 'width': 640, 'height': 351, 'bboxes': [{'class': 'train', 'x1': 3.94, 'x2': 640.0, 'y1': 37.07, 'y2': 322.6}], 'imageset': 'test'}
# index is 15
#   16/1000 [..............................] - ETA: 1:56:20 - rpn_cls: 6.8121 - rpn_regr: 0.1664 - detector_cls: 0.6203 - detector_regr: 0.4997X is (1, 416, 617, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000483538.jpg', 'width': 640, 'height': 431, 'bboxes': [{'class': 'train', 'x1': 268.05, 'x2': 513.9200000000002, 'y1': 196.38, 'y2': 421.04}], 'imageset': 'test'}
# index is 16
#   17/1000 [..............................] - ETA: 1:55:35 - rpn_cls: 6.7397 - rpn_regr: 0.1610 - detector_cls: 0.6264 - detector_regr: 0.4980X is (1, 416, 640, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000289040.jpg', 'width': 640, 'height': 416, 'bboxes': [{'class': 'train', 'x1': 232.77, 'x2': 382.35, 'y1': 157.99, 'y2': 275.78000000000003}], 'imageset': 'test'}
# index is 17
#   18/1000 [..............................] - ETA: 1:55:33 - rpn_cls: 6.5591 - rpn_regr: 0.1545 - detector_cls: 0.6159 - detector_regr: 0.4850X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000037015.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 18
# X is (1, 416, 483, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000294954.jpg', 'width': 640, 'height': 551, 'bboxes': [{'class': 'train', 'x1': 67.16, 'x2': 574.53, 'y1': 6.29, 'y2': 548.5}], 'imageset': 'test'}
# index is 19
#   19/1000 [..............................] - ETA: 1:55:55 - rpn_cls: 6.5107 - rpn_regr: 0.1726 - detector_cls: 0.6074 - detector_regr: 0.4878X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000559226.jpg', 'width': 500, 'height': 333, 'bboxes': [{'class': 'train', 'x1': 155.55, 'x2': 470.9, 'y1': 143.16, 'y2': 162.42}], 'imageset': 'test'}
# index is 20
#   20/1000 [..............................] - ETA: 1:55:13 - rpn_cls: 6.5301 - rpn_regr: 0.2265 - detector_cls: 0.5891 - detector_regr: 0.4634X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000477749.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 83.76, 'x2': 637.85, 'y1': 68.37, 'y2': 409.84}], 'imageset': 'test'}
# index is 21
#   21/1000 [..............................] - ETA: 1:54:27 - rpn_cls: 6.3729 - rpn_regr: 0.2358 - detector_cls: 0.5826 - detector_regr: 0.4620X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000077378.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 86.49, 'x2': 571.89, 'y1': 101.08, 'y2': 388.65}], 'imageset': 'test'}
# index is 22
#   22/1000 [..............................] - ETA: 1:53:34 - rpn_cls: 6.4218 - rpn_regr: 0.2320 - detector_cls: 0.5792 - detector_regr: 0.4560X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000222441.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 9.71, 'x2': 569.5300000000002, 'y1': 1.08, 'y2': 401.26}], 'imageset': 'test'}
# index is 23
#   23/1000 [..............................] - ETA: 1:53:07 - rpn_cls: 6.3492 - rpn_regr: 0.2446 - detector_cls: 0.5770 - detector_regr: 0.4603X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000044404.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 24
# X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000345014.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 67.17, 'x2': 477.86, 'y1': 159.29, 'y2': 285.95}], 'imageset': 'test'}
# index is 25
#   24/1000 [..............................] - ETA: 1:54:23 - rpn_cls: 6.2280 - rpn_regr: 0.2405 - detector_cls: 0.5610 - detector_regr: 0.4606X is (1, 416, 627, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000355021.jpg', 'width': 640, 'height': 424, 'bboxes': [{'class': 'train', 'x1': 0.95, 'x2': 640.0, 'y1': 0.0, 'y2': 416.38}], 'imageset': 'test'}
# index is 26
#   25/1000 [..............................] - ETA: 1:54:38 - rpn_cls: 6.2853 - rpn_regr: 0.2682 - detector_cls: 0.5538 - detector_regr: 0.4638X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000560325.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 144.89, 'x2': 534.47, 'y1': 69.89, 'y2': 352.95}], 'imageset': 'test'}
# index is 27
#   26/1000 [..............................] - ETA: 1:54:39 - rpn_cls: 6.0614 - rpn_regr: 0.2643 - detector_cls: 0.5551 - detector_regr: 0.4643X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000272838.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 62.08, 'x2': 616.01, 'y1': 14.33, 'y2': 376.29}], 'imageset': 'test'}
# index is 28
#   27/1000 [..............................] - ETA: 1:55:09 - rpn_cls: 6.0598 - rpn_regr: 0.2781 - detector_cls: 0.5574 - detector_regr: 0.4663X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000452343.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 0.96, 'x2': 532.9200000000002, 'y1': 115.56, 'y2': 290.3400000000001}], 'imageset': 'test'}
# index is 29
#   28/1000 [..............................] - ETA: 1:55:21 - rpn_cls: 6.0527 - rpn_regr: 0.2745 - detector_cls: 0.5523 - detector_regr: 0.4690X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000216393.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 208.18, 'x2': 412.04, 'y1': 142.38, 'y2': 294.47}], 'imageset': 'test'}
# index is 30
#   29/1000 [..............................] - ETA: 1:55:22 - rpn_cls: 5.8560 - rpn_regr: 0.2695 - detector_cls: 0.5522 - detector_regr: 0.4685X is (1, 416, 675, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000289034.jpg', 'width': 640, 'height': 394, 'bboxes': [{'class': 'train', 'x1': 64.63, 'x2': 639.25, 'y1': 107.13, 'y2': 285.1}], 'imageset': 'test'}
# index is 31
#   30/1000 [..............................] - ETA: 1:56:42 - rpn_cls: 5.8272 - rpn_regr: 0.2703 - detector_cls: 0.5462 - detector_regr: 0.4765X is (1, 416, 741, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000412881.jpg', 'width': 640, 'height': 359, 'bboxes': [{'class': 'train', 'x1': 13.75, 'x2': 529.61, 'y1': 41.64, 'y2': 351.32}], 'imageset': 'test'}
# index is 32
#   31/1000 [..............................] - ETA: 1:57:05 - rpn_cls: 5.7180 - rpn_regr: 0.2639 - detector_cls: 0.5435 - detector_regr: 0.4753X is (1, 416, 570, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000436759.jpg', 'width': 640, 'height': 467, 'bboxes': [{'class': 'train', 'x1': 253.0, 'x2': 640.0, 'y1': 67.2, 'y2': 459.36}], 'imageset': 'test'}
# index is 33
#   32/1000 [..............................] - ETA: 1:56:36 - rpn_cls: 5.6250 - rpn_regr: 0.2617 - detector_cls: 0.5442 - detector_regr: 0.4769X is (1, 416, 589, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000066121.jpg', 'width': 640, 'height': 452, 'bboxes': [{'class': 'train', 'x1': 48.65, 'x2': 581.72, 'y1': 156.68, 'y2': 387.75}], 'imageset': 'test'}
# index is 34
#   33/1000 [..............................] - ETA: 1:56:16 - rpn_cls: 5.5353 - rpn_regr: 0.2584 - detector_cls: 0.5531 - detector_regr: 0.4788X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000321302.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 20.15, 'x2': 640.0, 'y1': 171.76, 'y2': 373.27}], 'imageset': 'test'}
# index is 35
#   34/1000 [>.............................] - ETA: 1:56:03 - rpn_cls: 5.5233 - rpn_regr: 0.2594 - detector_cls: 0.5470 - detector_regr: 0.4736X is (1, 416, 589, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000573969.jpg', 'width': 640, 'height': 452, 'bboxes': [{'class': 'train', 'x1': 5.07, 'x2': 623.2700000000002, 'y1': 63.17, 'y2': 312.48}], 'imageset': 'test'}
# index is 36
#   35/1000 [>.............................] - ETA: 1:55:40 - rpn_cls: 5.3833 - rpn_regr: 0.2611 - detector_cls: 0.5445 - detector_regr: 0.4738X is (1, 416, 627, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000444363.jpg', 'width': 640, 'height': 424, 'bboxes': [{'class': 'train', 'x1': 73.37, 'x2': 544.05, 'y1': 136.25, 'y2': 307.76}], 'imageset': 'test'}
# index is 37
#   36/1000 [>.............................] - ETA: 1:55:25 - rpn_cls: 5.4154 - rpn_regr: 0.2571 - detector_cls: 0.5391 - detector_regr: 0.4695X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000069242.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 13.43, 'x2': 640.0, 'y1': 99.79, 'y2': 378.06}], 'imageset': 'test'}
# index is 38
#   37/1000 [>.............................] - ETA: 1:55:11 - rpn_cls: 5.4503 - rpn_regr: 0.2673 - detector_cls: 0.5368 - detector_regr: 0.4694X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000076645.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 93.32, 'x2': 441.89, 'y1': 139.26, 'y2': 258.67}], 'imageset': 'test'}
# index is 39
#   38/1000 [>.............................] - ETA: 1:55:04 - rpn_cls: 5.3211 - rpn_regr: 0.2656 - detector_cls: 0.5312 - detector_regr: 0.4710X is (1, 416, 613, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000566501.jpg', 'width': 640, 'height': 434, 'bboxes': [{'class': 'train', 'x1': 126.79, 'x2': 439.85, 'y1': 183.05, 'y2': 385.91}], 'imageset': 'test'}
# index is 40
#   39/1000 [>.............................] - ETA: 1:55:12 - rpn_cls: 5.2999 - rpn_regr: 0.2615 - detector_cls: 0.5338 - detector_regr: 0.4702X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000395957.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 9.6, 'x2': 640.0, 'y1': 95.96, 'y2': 376.14}], 'imageset': 'test'}
# index is 41
#   40/1000 [>.............................] - ETA: 1:55:22 - rpn_cls: 5.3019 - rpn_regr: 0.2707 - detector_cls: 0.5300 - detector_regr: 0.4654X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000149833.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 162.88, 'x2': 640.0, 'y1': 159.64, 'y2': 447.64}], 'imageset': 'test'}
# index is 42
#   41/1000 [>.............................] - ETA: 1:55:24 - rpn_cls: 5.2200 - rpn_regr: 0.2680 - detector_cls: 0.5401 - detector_regr: 0.4658X is (1, 416, 614, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000298154.jpg', 'width': 640, 'height': 433, 'bboxes': [{'class': 'train', 'x1': 72.98, 'x2': 570.2, 'y1': 126.56, 'y2': 389.28}], 'imageset': 'test'}
# index is 43
#   42/1000 [>.............................] - ETA: 1:55:24 - rpn_cls: 5.1296 - rpn_regr: 0.2670 - detector_cls: 0.5414 - detector_regr: 0.4669X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000164388.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 0.96, 'x2': 578.76, 'y1': 142.3, 'y2': 341.91}], 'imageset': 'test'}
# index is 44
#   43/1000 [>.............................] - ETA: 1:55:18 - rpn_cls: 5.0190 - rpn_regr: 0.2662 - detector_cls: 0.5397 - detector_regr: 0.4667X is (1, 624, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000345648.jpg', 'width': 333, 'height': 500, 'bboxes': [{'class': 'train', 'x1': 113.48, 'x2': 301.12, 'y1': 101.9, 'y2': 390.67}], 'imageset': 'test'}
# index is 45
#   44/1000 [>.............................] - ETA: 1:55:04 - rpn_cls: 5.0526 - rpn_regr: 0.2634 - detector_cls: 0.5439 - detector_regr: 0.4683X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000166421.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 78.87, 'x2': 257.66, 'y1': 205.06, 'y2': 368.14}], 'imageset': 'test'}
# index is 46
#   45/1000 [>.............................] - ETA: 1:54:55 - rpn_cls: 4.9459 - rpn_regr: 0.2610 - detector_cls: 0.5389 - detector_regr: 0.4708X is (1, 416, 687, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000368845.jpg', 'width': 640, 'height': 387, 'bboxes': [{'class': 'train', 'x1': 233.94, 'x2': 483.53, 'y1': 193.07, 'y2': 293.95}], 'imageset': 'test'}
# index is 47
#   46/1000 [>.............................] - ETA: 1:55:49 - rpn_cls: 4.9479 - rpn_regr: 0.2598 - detector_cls: 0.5340 - detector_regr: 0.4606X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000315045.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 28.79, 'x2': 638.0999999999998, 'y1': 158.99, 'y2': 368.17}], 'imageset': 'test'}
# index is 48
#   47/1000 [>.............................] - ETA: 1:57:04 - rpn_cls: 4.8882 - rpn_regr: 0.2605 - detector_cls: 0.5325 - detector_regr: 0.4603X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000320271.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 358.11, 'x2': 486.47, 'y1': 168.27, 'y2': 254.56}], 'imageset': 'test'}
# index is 49
#   48/1000 [>.............................] - ETA: 1:58:06 - rpn_cls: 4.8603 - rpn_regr: 0.2607 - detector_cls: 0.5284 - detector_regr: 0.4629X is (1, 416, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000517958.jpg', 'width': 500, 'height': 500, 'bboxes': [{'class': 'train', 'x1': 149.44, 'x2': 433.71, 'y1': 102.25, 'y2': 358.43}], 'imageset': 'test'}
# index is 50
#   49/1000 [>.............................] - ETA: 1:58:35 - rpn_cls: 4.8108 - rpn_regr: 0.2584 - detector_cls: 0.5314 - detector_regr: 0.4637X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000532629.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 628.85, 'y1': 33.51, 'y2': 388.39}], 'imageset': 'test'}
# index is 51
#   50/1000 [>.............................] - ETA: 1:59:59 - rpn_cls: 4.7247 - rpn_regr: 0.2643 - detector_cls: 0.5304 - detector_regr: 0.4619X is (1, 416, 553, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000363407.jpg', 'width': 640, 'height': 481, 'bboxes': [{'class': 'train', 'x1': 2.16, 'x2': 639.89, 'y1': 2.16, 'y2': 474.5100000000001}], 'imageset': 'test'}
# index is 52
#   51/1000 [>.............................] - ETA: 2:01:21 - rpn_cls: 4.7420 - rpn_regr: 0.2746 - detector_cls: 0.5303 - detector_regr: 0.4645X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000469605.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 53
# X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000198953.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 158.97, 'x2': 519.34, 'y1': 142.2, 'y2': 310.94}], 'imageset': 'test'}
# index is 54
#   52/1000 [>.............................] - ETA: 2:04:43 - rpn_cls: 4.7310 - rpn_regr: 0.2703 - detector_cls: 0.5324 - detector_regr: 0.4647X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000475531.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 16.31, 'x2': 626.5899999999998, 'y1': 141.05, 'y2': 302.26}], 'imageset': 'test'}
# index is 55
#   53/1000 [>.............................] - ETA: 2:05:56 - rpn_cls: 4.6436 - rpn_regr: 0.2708 - detector_cls: 0.5307 - detector_regr: 0.4671X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000238735.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 99.24, 'x2': 605.12, 'y1': 132.67, 'y2': 372.13}], 'imageset': 'test'}
# index is 56
#   54/1000 [>.............................] - ETA: 2:06:45 - rpn_cls: 4.6061 - rpn_regr: 0.2673 - detector_cls: 0.5345 - detector_regr: 0.4676X is (1, 416, 627, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000075965.jpg', 'width': 640, 'height': 424, 'bboxes': [{'class': 'train', 'x1': 52.4, 'x2': 545.01, 'y1': 108.68, 'y2': 267.8}], 'imageset': 'test'}
# index is 57
#   55/1000 [>.............................] - ETA: 2:07:52 - rpn_cls: 4.5753 - rpn_regr: 0.2643 - detector_cls: 0.5330 - detector_regr: 0.4644X is (1, 416, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000511508.jpg', 'width': 612, 'height': 612, 'bboxes': [{'class': 'train', 'x1': 67.39, 'x2': 507.48, 'y1': 171.91, 'y2': 464.84}], 'imageset': 'test'}
# index is 58
#   56/1000 [>.............................] - ETA: 2:08:24 - rpn_cls: 4.5300 - rpn_regr: 0.2619 - detector_cls: 0.5366 - detector_regr: 0.4631X is (1, 416, 619, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000027988.jpg', 'width': 640, 'height': 430, 'bboxes': [{'class': 'train', 'x1': 183.36, 'x2': 510.43, 'y1': 203.8, 'y2': 339.44}], 'imageset': 'test'}
# index is 59
#   57/1000 [>.............................] - ETA: 2:09:16 - rpn_cls: 4.4620 - rpn_regr: 0.2599 - detector_cls: 0.5356 - detector_regr: 0.4629X is (1, 416, 636, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000044232.jpg', 'width': 640, 'height': 418, 'bboxes': [{'class': 'train', 'x1': 127.75, 'x2': 603.99, 'y1': 187.87, 'y2': 389.82}], 'imageset': 'test'}
# index is 60
#   58/1000 [>.............................] - ETA: 2:10:29 - rpn_cls: 4.4705 - rpn_regr: 0.2569 - detector_cls: 0.5385 - detector_regr: 0.4622X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000322734.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 20.11, 'x2': 624.22, 'y1': 124.08, 'y2': 346.2}], 'imageset': 'test'}
# index is 61
#   59/1000 [>.............................] - ETA: 2:11:44 - rpn_cls: 4.4569 - rpn_regr: 0.2574 - detector_cls: 0.5370 - detector_regr: 0.4613X is (1, 555, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000051465.jpg', 'width': 479, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 214.17, 'x2': 479.0, 'y1': 16.63, 'y2': 640.0}], 'imageset': 'test'}
# index is 62
#   60/1000 [>.............................] - ETA: 2:12:45 - rpn_cls: 4.5406 - rpn_regr: 0.2579 - detector_cls: 0.5339 - detector_regr: 0.4638X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000306447.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 127.31, 'x2': 450.84, 'y1': 80.88, 'y2': 346.99}], 'imageset': 'test'}
# index is 63
#   61/1000 [>.............................] - ETA: 2:14:09 - rpn_cls: 4.4934 - rpn_regr: 0.2547 - detector_cls: 0.5359 - detector_regr: 0.4652X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000516849.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 80.41, 'x2': 640.0, 'y1': 149.8, 'y2': 307.74}], 'imageset': 'test'}
# index is 64
#   62/1000 [>.............................] - ETA: 2:15:10 - rpn_cls: 4.4231 - rpn_regr: 0.2541 - detector_cls: 0.5340 - detector_regr: 0.4644X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000550534.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 187.11, 'x2': 473.06, 'y1': 110.19, 'y2': 328.01}], 'imageset': 'test'}
# index is 65
#   63/1000 [>.............................] - ETA: 2:16:11 - rpn_cls: 4.4060 - rpn_regr: 0.2520 - detector_cls: 0.5350 - detector_regr: 0.4646X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000024923.jpg', 'width': 500, 'height': 332, 'bboxes': [{'class': 'train', 'x1': 64.16, 'x2': 342.72, 'y1': 105.2, 'y2': 214.87}], 'imageset': 'test'}
# index is 66
#   64/1000 [>.............................] - ETA: 2:16:42 - rpn_cls: 4.4007 - rpn_regr: 0.2506 - detector_cls: 0.5328 - detector_regr: 0.4624X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000434943.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 640.0, 'y1': 191.14, 'y2': 331.0499999999999}], 'imageset': 'test'}
# index is 67
#   65/1000 [>.............................] - ETA: 2:17:42 - rpn_cls: 4.3331 - rpn_regr: 0.2526 - detector_cls: 0.5319 - detector_regr: 0.4641X is (1, 520, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000207677.jpg', 'width': 512, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 81.32, 'x2': 430.05, 'y1': 100.44, 'y2': 477.11}], 'imageset': 'test'}
# index is 68
#   66/1000 [>.............................] - ETA: 2:18:10 - rpn_cls: 4.2897 - rpn_regr: 0.2498 - detector_cls: 0.5348 - detector_regr: 0.4651X is (1, 416, 522, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000347111.jpg', 'width': 640, 'height': 510, 'bboxes': [{'class': 'train', 'x1': 16.04, 'x2': 317.4600000000001, 'y1': 16.04, 'y2': 168.47}], 'imageset': 'test'}
# index is 69
#   67/1000 [=>............................] - ETA: 2:18:33 - rpn_cls: 4.3888 - rpn_regr: 0.2498 - detector_cls: 0.5343 - detector_regr: 0.4672X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172148.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 621.62, 'y1': 172.43, 'y2': 257.84000000000003}], 'imageset': 'test'}
# index is 70
#   68/1000 [=>............................] - ETA: 2:19:14 - rpn_cls: 4.3687 - rpn_regr: 0.2562 - detector_cls: 0.5290 - detector_regr: 0.4603X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000493767.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 137.83, 'x2': 545.13, 'y1': 195.2, 'y2': 371.01}], 'imageset': 'test'}
# index is 71
#   69/1000 [=>............................] - ETA: 2:19:37 - rpn_cls: 4.3653 - rpn_regr: 0.2529 - detector_cls: 0.5316 - detector_regr: 0.4594X is (1, 416, 551, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000073976.jpg', 'width': 500, 'height': 377, 'bboxes': [{'class': 'train', 'x1': 325.63, 'x2': 440.69, 'y1': 295.92, 'y2': 319.5200000000001}], 'imageset': 'test'}
# index is 72
#   70/1000 [=>............................] - ETA: 2:19:47 - rpn_cls: 4.3795 - rpn_regr: 0.2612 - detector_cls: 0.5274 - detector_regr: 0.4528X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000412248.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 38.24, 'x2': 240.29, 'y1': 13.22, 'y2': 109.47}], 'imageset': 'test'}
# index is 73
#   71/1000 [=>............................] - ETA: 2:20:09 - rpn_cls: 4.4418 - rpn_regr: 0.2578 - detector_cls: 0.5258 - detector_regr: 0.4539X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000224670.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 617.99, 'y1': 96.31, 'y2': 189.48}], 'imageset': 'test'}
# index is 74
#   72/1000 [=>............................] - ETA: 2:20:11 - rpn_cls: 4.3827 - rpn_regr: 0.2628 - detector_cls: 0.5217 - detector_regr: 0.4476X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000568955.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 110.74, 'x2': 322.16, 'y1': 9.63, 'y2': 607.92}], 'imageset': 'test'}
# index is 75
#   73/1000 [=>............................] - ETA: 2:20:41 - rpn_cls: 4.3548 - rpn_regr: 0.2634 - detector_cls: 0.5230 - detector_regr: 0.4524X is (1, 416, 596, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000534464.jpg', 'width': 640, 'height': 446, 'bboxes': [{'class': 'train', 'x1': 87.95, 'x2': 456.82, 'y1': 35.32, 'y2': 339.9}], 'imageset': 'test'}
# index is 76
#   74/1000 [=>............................] - ETA: 2:20:51 - rpn_cls: 4.3191 - rpn_regr: 0.2608 - detector_cls: 0.5261 - detector_regr: 0.4534X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041138.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.64, 'x2': 266.47, 'y1': 107.48, 'y2': 376.66}], 'imageset': 'test'}
# index is 77
#   75/1000 [=>............................] - ETA: 2:20:56 - rpn_cls: 4.2649 - rpn_regr: 0.2587 - detector_cls: 0.5297 - detector_regr: 0.4534X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000352498.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 97.87, 'x2': 407.81, 'y1': 161.2, 'y2': 301.2999999999999}], 'imageset': 'test'}
# index is 78
#   76/1000 [=>............................] - ETA: 2:21:15 - rpn_cls: 4.2101 - rpn_regr: 0.2573 - detector_cls: 0.5270 - detector_regr: 0.4544X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000271190.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 43.18, 'x2': 573.81, 'y1': 231.32, 'y2': 318.63}], 'imageset': 'test'}
# index is 79
#   77/1000 [=>............................] - ETA: 2:21:30 - rpn_cls: 4.1586 - rpn_regr: 0.2609 - detector_cls: 0.5210 - detector_regr: 0.4485X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000098800.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 3.24, 'x2': 640.0, 'y1': 158.23, 'y2': 445.15}], 'imageset': 'test'}
# index is 80
#   78/1000 [=>............................] - ETA: 2:21:56 - rpn_cls: 4.1062 - rpn_regr: 0.2618 - detector_cls: 0.5217 - detector_regr: 0.4488X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000411825.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 12.5, 'x2': 617.42, 'y1': 144.74, 'y2': 309.19}], 'imageset': 'test'}
# index is 81
#   79/1000 [=>............................] - ETA: 2:22:38 - rpn_cls: 4.0546 - rpn_regr: 0.2617 - detector_cls: 0.5213 - detector_regr: 0.4500X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000472925.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 82
# X is (1, 416, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000428390.jpg', 'width': 612, 'height': 612, 'bboxes': [{'class': 'train', 'x1': 320.44, 'x2': 490.98, 'y1': 244.8, 'y2': 379.58}], 'imageset': 'test'}
# index is 83
#   80/1000 [=>............................] - ETA: 2:23:46 - rpn_cls: 4.1375 - rpn_regr: 0.2603 - detector_cls: 0.5182 - detector_regr: 0.4503X is (1, 416, 622, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000019435.jpg', 'width': 640, 'height': 428, 'bboxes': [{'class': 'train', 'x1': 221.83, 'x2': 355.39, 'y1': 191.41, 'y2': 298.0900000000001}], 'imageset': 'test'}
# index is 84
#   81/1000 [=>............................] - ETA: 2:24:26 - rpn_cls: 4.1594 - rpn_regr: 0.2578 - detector_cls: 0.5144 - detector_regr: 0.4480X is (1, 520, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000420887.jpg', 'width': 512, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 30.2, 'x2': 394.07, 'y1': 87.73, 'y2': 520.63}], 'imageset': 'test'}
# index is 85
#   82/1000 [=>............................] - ETA: 2:24:40 - rpn_cls: 4.1097 - rpn_regr: 0.2562 - detector_cls: 0.5175 - detector_regr: 0.4477X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000279421.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 378.06, 'x2': 639.06, 'y1': 209.18, 'y2': 421.24}], 'imageset': 'test'}
# index is 86
#   83/1000 [=>............................] - ETA: 2:25:04 - rpn_cls: 4.0603 - rpn_regr: 0.2540 - detector_cls: 0.5177 - detector_regr: 0.4462X is (1, 559, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000223612.jpg', 'width': 476, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 348.26, 'x2': 379.62, 'y1': 423.27, 'y2': 594.06}], 'imageset': 'test'}
# index is 87
#   84/1000 [=>............................] - ETA: 2:25:00 - rpn_cls: 4.0732 - rpn_regr: 0.2592 - detector_cls: 0.5136 - detector_regr: 0.4409X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000172091.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 191.35, 'x2': 351.35, 'y1': 218.92, 'y2': 342.16}], 'imageset': 'test'}
# index is 88
#   85/1000 [=>............................] - ETA: 2:25:10 - rpn_cls: 4.1455 - rpn_regr: 0.2567 - detector_cls: 0.5090 - detector_regr: 0.4376X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000354644.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 64.72, 'x2': 462.74, 'y1': 94.74, 'y2': 308.31}], 'imageset': 'test'}
# index is 89
#   86/1000 [=>............................] - ETA: 2:25:08 - rpn_cls: 4.1020 - rpn_regr: 0.2544 - detector_cls: 0.5097 - detector_regr: 0.4369X is (1, 416, 556, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000509682.jpg', 'width': 640, 'height': 478, 'bboxes': [{'class': 'train', 'x1': 19.33, 'x2': 640.0, 'y1': 77.61, 'y2': 378.37}], 'imageset': 'test'}
# index is 90
#   87/1000 [=>............................] - ETA: 2:25:09 - rpn_cls: 4.0698 - rpn_regr: 0.2572 - detector_cls: 0.5088 - detector_regr: 0.4353X is (1, 416, 665, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000009990.jpg', 'width': 640, 'height': 400, 'bboxes': [{'class': 'train', 'x1': 72.81, 'x2': 590.56, 'y1': 203.15, 'y2': 342.47}], 'imageset': 'test'}
# index is 91
#   88/1000 [=>............................] - ETA: 2:25:18 - rpn_cls: 4.0236 - rpn_regr: 0.2565 - detector_cls: 0.5088 - detector_regr: 0.4347X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000323208.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 375.34, 'x2': 597.8, 'y1': 164.47, 'y2': 216.14}], 'imageset': 'test'}
# index is 92
#   89/1000 [=>............................] - ETA: 2:25:25 - rpn_cls: 4.0499 - rpn_regr: 0.2573 - detector_cls: 0.5033 - detector_regr: 0.4298X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000272679.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 335.09, 'x2': 514.12, 'y1': 47.49, 'y2': 351.94}], 'imageset': 'test'}
# index is 93
#   90/1000 [=>............................] - ETA: 2:25:30 - rpn_cls: 4.0608 - rpn_regr: 0.2556 - detector_cls: 0.5055 - detector_regr: 0.4320X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000508502.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 2.15, 'x2': 302.42, 'y1': 40.18, 'y2': 454.53}], 'imageset': 'test'}
# index is 94
#   91/1000 [=>............................] - ETA: 2:25:33 - rpn_cls: 4.0467 - rpn_regr: 0.2545 - detector_cls: 0.5074 - detector_regr: 0.4339X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000491269.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 95
# X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000337875.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 110.35, 'x2': 594.92, 'y1': 135.3, 'y2': 332.9600000000001}], 'imageset': 'test'}
# index is 96
#   92/1000 [=>............................] - ETA: 2:26:33 - rpn_cls: 4.0291 - rpn_regr: 0.2527 - detector_cls: 0.5082 - detector_regr: 0.4331X is (1, 416, 647, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000246396.jpg', 'width': 640, 'height': 411, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 411.0}], 'imageset': 'test'}
# index is 97
#   93/1000 [=>............................] - ETA: 2:26:38 - rpn_cls: 3.9939 - rpn_regr: 0.2599 - detector_cls: 0.5080 - detector_regr: 0.4346X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000501661.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 287.02, 'x2': 457.49, 'y1': 127.43, 'y2': 321.42}], 'imageset': 'test'}
# index is 98
#   94/1000 [=>............................] - ETA: 2:26:51 - rpn_cls: 4.0077 - rpn_regr: 0.2612 - detector_cls: 0.5054 - detector_regr: 0.4352X is (1, 416, 641, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000378035.jpg', 'width': 640, 'height': 415, 'bboxes': [{'class': 'train', 'x1': 0.93, 'x2': 216.8, 'y1': 248.44, 'y2': 336.8400000000001}], 'imageset': 'test'}
# index is 99
#   95/1000 [=>............................] - ETA: 2:26:57 - rpn_cls: 4.0362 - rpn_regr: 0.2589 - detector_cls: 0.5006 - detector_regr: 0.4306X is (1, 416, 629, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000059622.jpg', 'width': 640, 'height': 423, 'bboxes': [{'class': 'train', 'x1': 249.44, 'x2': 612.69, 'y1': 174.13, 'y2': 294.58}], 'imageset': 'test'}
# index is 100
#   96/1000 [=>............................] - ETA: 2:27:10 - rpn_cls: 3.9947 - rpn_regr: 0.2580 - detector_cls: 0.4982 - detector_regr: 0.4303X is (1, 554, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000062426.jpg', 'width': 480, 'height': 640, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 101
# X is (1, 416, 773, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000239269.jpg', 'width': 640, 'height': 344, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 380.17, 'y1': 83.19, 'y2': 340.23}], 'imageset': 'test'}
# index is 102
#   97/1000 [=>............................] - ETA: 2:28:13 - rpn_cls: 3.9751 - rpn_regr: 0.2575 - detector_cls: 0.4983 - detector_regr: 0.4311X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000560655.jpg', 'width': 500, 'height': 332, 'bboxes': [{'class': 'train', 'x1': 163.39, 'x2': 436.45, 'y1': 92.51, 'y2': 314.8400000000001}], 'imageset': 'test'}
# index is 103
#   98/1000 [=>............................] - ETA: 2:28:17 - rpn_cls: 3.9362 - rpn_regr: 0.2557 - detector_cls: 0.4997 - detector_regr: 0.4328X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000010343.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 69.09, 'x2': 573.8100000000002, 'y1': 173.39, 'y2': 267.42}], 'imageset': 'test'}
# index is 104
#   99/1000 [=>............................] - ETA: 2:28:15 - rpn_cls: 3.9505 - rpn_regr: 0.2573 - detector_cls: 0.4947 - detector_regr: 0.4284X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000435228.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 107.87, 'x2': 381.12, 'y1': 210.07, 'y2': 483.33}], 'imageset': 'test'}
# index is 105
#  100/1000 [==>...........................] - ETA: 2:28:13 - rpn_cls: 3.9249 - rpn_regr: 0.2550 - detector_cls: 0.4960 - detector_regr: 0.4288X is (1, 416, 622, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000278921.jpg', 'width': 640, 'height': 428, 'bboxes': [{'class': 'train', 'x1': 364.85, 'x2': 594.69, 'y1': 0.0, 'y2': 178.73}], 'imageset': 'test'}
# index is 106
#  101/1000 [==>...........................] - ETA: 2:28:15 - rpn_cls: 3.9060 - rpn_regr: 0.2550 - detector_cls: 0.4977 - detector_regr: 0.4294X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000016538.jpg', 'width': 500, 'height': 333, 'bboxes': [{'class': 'train', 'x1': 64.65, 'x2': 454.77, 'y1': 65.96, 'y2': 281.7}], 'imageset': 'test'}
# index is 107
#  102/1000 [==>...........................] - ETA: 2:28:13 - rpn_cls: 3.8679 - rpn_regr: 0.2549 - detector_cls: 0.4989 - detector_regr: 0.4304X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000009064.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 5.76, 'x2': 569.01, 'y1': 166.0, 'y2': 350.24}], 'imageset': 'test'}
# index is 108
#  103/1000 [==>...........................] - ETA: 2:28:13 - rpn_cls: 3.8337 - rpn_regr: 0.2540 - detector_cls: 0.4996 - detector_regr: 0.4309X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000280423.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 72.27, 'x2': 498.34, 'y1': 104.63, 'y2': 454.11}], 'imageset': 'test'}
# index is 109
#  104/1000 [==>...........................] - ETA: 2:28:13 - rpn_cls: 3.7999 - rpn_regr: 0.2547 - detector_cls: 0.5007 - detector_regr: 0.4329X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000380306.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 317.12, 'y1': 143.28, 'y2': 334.2}], 'imageset': 'test'}
# index is 110
#  105/1000 [==>...........................] - ETA: 2:28:10 - rpn_cls: 3.7647 - rpn_regr: 0.2538 - detector_cls: 0.5022 - detector_regr: 0.4328X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000534259.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 30.2, 'x2': 638.5600000000002, 'y1': 1.15, 'y2': 366.81}], 'imageset': 'test'}
# index is 111
#  106/1000 [==>...........................] - ETA: 2:28:02 - rpn_cls: 3.7624 - rpn_regr: 0.2560 - detector_cls: 0.5021 - detector_regr: 0.4332X is (1, 416, 523, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000540769.jpg', 'width': 640, 'height': 509, 'bboxes': [{'class': 'train', 'x1': 75.49, 'x2': 633.6800000000002, 'y1': 134.97, 'y2': 438.08}], 'imageset': 'test'}
# index is 112
#  107/1000 [==>...........................] - ETA: 2:27:51 - rpn_cls: 3.7275 - rpn_regr: 0.2552 - detector_cls: 0.5031 - detector_regr: 0.4340X is (1, 553, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000170558.jpg', 'width': 481, 'height': 640, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 113
# X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000322530.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 427.0, 'y1': 4.31, 'y2': 631.3699999999999}], 'imageset': 'test'}
# index is 114
#  108/1000 [==>...........................] - ETA: 2:28:19 - rpn_cls: 3.6941 - rpn_regr: 0.2633 - detector_cls: 0.5038 - detector_regr: 0.4356X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000173163.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 1.92, 'x2': 409.73, 'y1': 97.87, 'y2': 419.32}], 'imageset': 'test'}
# index is 115
#  109/1000 [==>...........................] - ETA: 2:28:13 - rpn_cls: 3.6625 - rpn_regr: 0.2628 - detector_cls: 0.5045 - detector_regr: 0.4368X is (1, 416, 551, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000150958.jpg', 'width': 640, 'height': 483, 'bboxes': [{'class': 'train', 'x1': 181.87, 'x2': 605.56, 'y1': 136.08, 'y2': 324.48}], 'imageset': 'test'}
# index is 116
#  110/1000 [==>...........................] - ETA: 2:28:05 - rpn_cls: 3.6432 - rpn_regr: 0.2608 - detector_cls: 0.5052 - detector_regr: 0.4366X is (1, 416, 622, 3)
# Y is 2
# ...
# index is 5265
#  964/1000 [===========================>..] - ETA: 3:52 - rpn_cls: 1.3010 - rpn_regr: 0.2130 - detector_cls: 0.2528 - detector_regr: 0.1647X is (1, 554, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000363302.jpg', 'width': 480, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 153.07, 'x2': 413.42, 'y1': 168.08, 'y2': 458.72}], 'imageset': 'test'}
# index is 5266
#  965/1000 [===========================>..] - ETA: 3:45 - rpn_cls: 1.2999 - rpn_regr: 0.2130 - detector_cls: 0.2527 - detector_regr: 0.1646X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000500945.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 165.03, 'x2': 628.85, 'y1': 96.0, 'y2': 395.87}], 'imageset': 'test'}
# index is 5267
#  966/1000 [===========================>..] - ETA: 3:39 - rpn_cls: 1.2986 - rpn_regr: 0.2129 - detector_cls: 0.2528 - detector_regr: 0.1647X is (1, 416, 662, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000035497.jpg', 'width': 640, 'height': 402, 'bboxes': [{'class': 'train', 'x1': 35.07, 'x2': 640.0, 'y1': 85.52, 'y2': 322.05}], 'imageset': 'test'}
# index is 5268
#  967/1000 [============================>.] - ETA: 3:33 - rpn_cls: 1.2972 - rpn_regr: 0.2128 - detector_cls: 0.2529 - detector_regr: 0.1647X is (1, 416, 633, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000541280.jpg', 'width': 640, 'height': 420, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 640.0, 'y1': 146.29, 'y2': 376.58}], 'imageset': 'test'}
# index is 5269
#  968/1000 [============================>.] - ETA: 3:26 - rpn_cls: 1.2959 - rpn_regr: 0.2129 - detector_cls: 0.2530 - detector_regr: 0.1647X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000403334.jpg', 'width': 500, 'height': 375, 'bboxes': [{'class': 'train', 'x1': 79.21, 'x2': 409.55, 'y1': 74.37, 'y2': 313.69}], 'imageset': 'test'}
# index is 5270
#  969/1000 [============================>.] - ETA: 3:20 - rpn_cls: 1.2945 - rpn_regr: 0.2127 - detector_cls: 0.2529 - detector_regr: 0.1646X is (1, 416, 559, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000041116.jpg', 'width': 640, 'height': 476, 'bboxes': [{'class': 'train', 'x1': 16.04, 'x2': 434.28, 'y1': 23.53, 'y2': 415.03}], 'imageset': 'test'}
# index is 5271
#  970/1000 [============================>.] - ETA: 3:13 - rpn_cls: 1.2933 - rpn_regr: 0.2127 - detector_cls: 0.2528 - detector_regr: 0.1646X is (1, 416, 627, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000353402.jpg', 'width': 640, 'height': 424, 'bboxes': [{'class': 'train', 'x1': 32.23, 'x2': 343.62, 'y1': 205.73, 'y2': 369.66}], 'imageset': 'test'}
# index is 5272
#  971/1000 [============================>.] - ETA: 3:07 - rpn_cls: 1.2920 - rpn_regr: 0.2126 - detector_cls: 0.2528 - detector_regr: 0.1645X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000017810.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 29.12, 'x2': 488.63, 'y1': 231.91, 'y2': 417.44}], 'imageset': 'test'}
# index is 5273
#  972/1000 [============================>.] - ETA: 3:00 - rpn_cls: 1.2918 - rpn_regr: 0.2124 - detector_cls: 0.2528 - detector_regr: 0.1647X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000492286.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 40.99, 'x2': 497.26, 'y1': 21.0, 'y2': 348.91}], 'imageset': 'test'}
# index is 5274
#  973/1000 [============================>.] - ETA: 2:54 - rpn_cls: 1.2904 - rpn_regr: 0.2123 - detector_cls: 0.2527 - detector_regr: 0.1646X is (1, 416, 721, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000298004.jpg', 'width': 640, 'height': 369, 'bboxes': [{'class': 'train', 'x1': 67.17, 'x2': 506.65, 'y1': 151.75, 'y2': 352.42}], 'imageset': 'test'}
# index is 5275
#  974/1000 [============================>.] - ETA: 2:47 - rpn_cls: 1.2891 - rpn_regr: 0.2122 - detector_cls: 0.2526 - detector_regr: 0.1645X is (1, 416, 624, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000314377.jpg', 'width': 500, 'height': 333, 'bboxes': [{'class': 'train', 'x1': 23.83, 'x2': 441.04, 'y1': 135.95, 'y2': 310.99}], 'imageset': 'test'}
# index is 5276
#  975/1000 [============================>.] - ETA: 2:41 - rpn_cls: 1.2878 - rpn_regr: 0.2122 - detector_cls: 0.2528 - detector_regr: 0.1647X is (1, 416, 607, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000085179.jpg', 'width': 640, 'height': 438, 'bboxes': [{'class': 'train', 'x1': 0.0, 'x2': 640.0, 'y1': 0.0, 'y2': 371.41}], 'imageset': 'test'}
# index is 5277
#  976/1000 [============================>.] - ETA: 2:35 - rpn_cls: 1.2865 - rpn_regr: 0.2123 - detector_cls: 0.2528 - detector_regr: 0.1648X is (1, 416, 665, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000025343.jpg', 'width': 640, 'height': 400, 'bboxes': [{'class': 'train', 'x1': 133.04, 'x2': 593.78, 'y1': 163.67, 'y2': 276.25}], 'imageset': 'test'}
# index is 5278
#  977/1000 [============================>.] - ETA: 2:28 - rpn_cls: 1.2852 - rpn_regr: 0.2121 - detector_cls: 0.2527 - detector_regr: 0.1648X is (1, 416, 594, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000435164.jpg', 'width': 640, 'height': 448, 'bboxes': [{'class': 'train', 'x1': 13.09, 'x2': 618.14, 'y1': 25.17, 'y2': 392.63}], 'imageset': 'test'}
# index is 5279
#  978/1000 [============================>.] - ETA: 2:22 - rpn_cls: 1.2839 - rpn_regr: 0.2121 - detector_cls: 0.2527 - detector_regr: 0.1648X is (1, 626, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000402308.jpg', 'width': 425, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 8.63, 'x2': 422.83, 'y1': 109.3, 'y2': 529.26}], 'imageset': 'test'}
# index is 5280
#  979/1000 [============================>.] - ETA: 2:15 - rpn_cls: 1.2826 - rpn_regr: 0.2121 - detector_cls: 0.2527 - detector_regr: 0.1648X is (1, 416, 646, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000034608.jpg', 'width': 640, 'height': 412, 'bboxes': [{'class': 'train', 'x1': 6.48, 'x2': 242.57, 'y1': 200.91, 'y2': 373.11}], 'imageset': 'test'}
# index is 5281
#  980/1000 [============================>.] - ETA: 2:09 - rpn_cls: 1.2813 - rpn_regr: 0.2121 - detector_cls: 0.2528 - detector_regr: 0.1650X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000355742.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 90.8, 'x2': 576.6899999999998, 'y1': 103.7, 'y2': 404.99}], 'imageset': 'test'}
# index is 5282
#  981/1000 [============================>.] - ETA: 2:02 - rpn_cls: 1.2800 - rpn_regr: 0.2121 - detector_cls: 0.2528 - detector_regr: 0.1651X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000116006.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 77.72, 'x2': 558.46, 'y1': 124.74, 'y2': 311.85}], 'imageset': 'test'}
# index is 5283
#  982/1000 [============================>.] - ETA: 1:56 - rpn_cls: 1.2791 - rpn_regr: 0.2120 - detector_cls: 0.2528 - detector_regr: 0.1650X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000304151.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 86.36, 'x2': 640.0, 'y1': 181.36, 'y2': 303.22}], 'imageset': 'test'}
# index is 5284
#  983/1000 [============================>.] - ETA: 1:49 - rpn_cls: 1.2789 - rpn_regr: 0.2120 - detector_cls: 0.2527 - detector_regr: 0.1650X is (1, 416, 554, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000044389.jpg', 'width': 640, 'height': 480, 'bboxes': [{'class': 'train', 'x1': 4.31, 'x2': 640.0, 'y1': 237.3, 'y2': 355.9600000000001}], 'imageset': 'test'}
# index is 5285
#  984/1000 [============================>.] - ETA: 1:43 - rpn_cls: 1.2776 - rpn_regr: 0.2120 - detector_cls: 0.2531 - detector_regr: 0.1651X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000263101.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 163.36, 'x2': 407.78, 'y1': 122.22, 'y2': 278.39}], 'imageset': 'test'}
# index is 5286
#  985/1000 [============================>.] - ETA: 1:36 - rpn_cls: 1.2763 - rpn_regr: 0.2120 - detector_cls: 0.2530 - detector_regr: 0.1650X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000315045.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 28.79, 'x2': 638.0999999999998, 'y1': 158.99, 'y2': 368.17}], 'imageset': 'test'}
# index is 5287
#  986/1000 [============================>.] - ETA: 1:30 - rpn_cls: 1.2750 - rpn_regr: 0.2120 - detector_cls: 0.2530 - detector_regr: 0.1650X is (1, 554, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000062426.jpg', 'width': 480, 'height': 640, 'bboxes': [{'class': 'bg', 'x1': -1.0, 'x2': -1.0, 'y1': -1.0, 'y2': -1.0}], 'imageset': 'test'}
# index is 5288
# X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000147616.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 1.62, 'x2': 425.11, 'y1': 390.55, 'y2': 599.65}], 'imageset': 'test'}
# index is 5289
#  987/1000 [============================>.] - ETA: 1:24 - rpn_cls: 1.2737 - rpn_regr: 0.2118 - detector_cls: 0.2529 - detector_regr: 0.1650X is (1, 416, 749, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000337853.jpg', 'width': 640, 'height': 355, 'bboxes': [{'class': 'train', 'x1': 29.58, 'x2': 598.0600000000002, 'y1': 128.78, 'y2': 228.72}], 'imageset': 'test'}
# index is 5290
#  988/1000 [============================>.] - ETA: 1:17 - rpn_cls: 1.2725 - rpn_regr: 0.2118 - detector_cls: 0.2528 - detector_regr: 0.1651X is (1, 416, 586, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000002545.jpg', 'width': 640, 'height': 454, 'bboxes': [{'class': 'train', 'x1': 115.29, 'x2': 479.5100000000001, 'y1': 208.98, 'y2': 328.34}], 'imageset': 'test'}
# index is 5291
#  989/1000 [============================>.] - ETA: 1:11 - rpn_cls: 1.2712 - rpn_regr: 0.2119 - detector_cls: 0.2527 - detector_regr: 0.1651X is (1, 624, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000453545.jpg', 'width': 426, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 1.44, 'x2': 425.71, 'y1': 1.8, 'y2': 631.7299999999998}], 'imageset': 'test'}
# index is 5292
#  990/1000 [============================>.] - ETA: 1:04 - rpn_cls: 1.2751 - rpn_regr: 0.2122 - detector_cls: 0.2527 - detector_regr: 0.1652X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000560325.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 144.89, 'x2': 534.47, 'y1': 69.89, 'y2': 352.95}], 'imageset': 'test'}
# index is 5293
#  991/1000 [============================>.] - ETA: 58s - rpn_cls: 1.2739 - rpn_regr: 0.2121 - detector_cls: 0.2528 - detector_regr: 0.1652 X is (1, 416, 611, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000114829.jpg', 'width': 500, 'height': 340, 'bboxes': [{'class': 'train', 'x1': 12.63, 'x2': 437.03, 'y1': 62.21, 'y2': 188.37}], 'imageset': 'test'}
# index is 5294
#  992/1000 [============================>.] - ETA: 51s - rpn_cls: 1.2726 - rpn_regr: 0.2119 - detector_cls: 0.2527 - detector_regr: 0.1652X is (1, 416, 626, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000224524.jpg', 'width': 640, 'height': 425, 'bboxes': [{'class': 'train', 'x1': 1.05, 'x2': 638.55, 'y1': 0.63, 'y2': 419.35}], 'imageset': 'test'}
# index is 5295
#  993/1000 [============================>.] - ETA: 45s - rpn_cls: 1.2713 - rpn_regr: 0.2122 - detector_cls: 0.2527 - detector_regr: 0.1653X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000147843.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 193.96, 'x2': 331.75, 'y1': 168.41, 'y2': 278.76}], 'imageset': 'test'}
# index is 5296
#  994/1000 [============================>.] - ETA: 38s - rpn_cls: 1.2705 - rpn_regr: 0.2120 - detector_cls: 0.2525 - detector_regr: 0.1652X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000008385.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 0.96, 'x2': 640.0, 'y1': 0.67, 'y2': 419.03}], 'imageset': 'test'}
# index is 5297
#  995/1000 [============================>.] - ETA: 32s - rpn_cls: 1.2692 - rpn_regr: 0.2123 - detector_cls: 0.2526 - detector_regr: 0.1652X is (1, 623, 416, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000166421.jpg', 'width': 427, 'height': 640, 'bboxes': [{'class': 'train', 'x1': 78.87, 'x2': 257.66, 'y1': 205.06, 'y2': 368.14}], 'imageset': 'test'}
# index is 5298
#  996/1000 [============================>.] - ETA: 25s - rpn_cls: 1.2679 - rpn_regr: 0.2122 - detector_cls: 0.2526 - detector_regr: 0.1652X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000075902.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 116.11, 'x2': 613.15, 'y1': 143.93, 'y2': 322.41}], 'imageset': 'test'}
# index is 5299
#  997/1000 [============================>.] - ETA: 19s - rpn_cls: 1.2667 - rpn_regr: 0.2121 - detector_cls: 0.2525 - detector_regr: 0.1652X is (1, 416, 559, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000199695.jpg', 'width': 640, 'height': 476, 'bboxes': [{'class': 'train', 'x1': 115.52, 'x2': 358.27, 'y1': 134.6, 'y2': 280.41}], 'imageset': 'test'}
# index is 5300
#  998/1000 [============================>.] - ETA: 12s - rpn_cls: 1.2709 - rpn_regr: 0.2123 - detector_cls: 0.2523 - detector_regr: 0.1650X is (1, 416, 623, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000213510.jpg', 'width': 640, 'height': 427, 'bboxes': [{'class': 'train', 'x1': 138.18, 'x2': 511.44, 'y1': 218.78, 'y2': 391.5}], 'imageset': 'test'}
# index is 5301
#  999/1000 [============================>.] - ETA: 6s - rpn_cls: 1.2698 - rpn_regr: 0.2122 - detector_cls: 0.2524 - detector_regr: 0.1651 X is (1, 416, 627, 3)
# Y is 2
# img_data is {'filepath': 'COCO_extracted_dataset/train_for_train/COCO_train2014_000000238203.jpg', 'width': 640, 'height': 424, 'bboxes': [{'class': 'train', 'x1': 0.95, 'x2': 512.61, 'y1': 178.18, 'y2': 228.67}], 'imageset': 'test'}
# index is 5302
# 1000/1000 [==============================] - 6479s 6s/step - rpn_cls: 1.2738 - rpn_regr: 0.2127 - detector_cls: 0.2521 - detector_regr: 0.1649
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 9.739791073124406
# Classifier accuracy for bounding boxes from RPN: 0.88978125
# Loss RPN classifier: 1.2737576403694917
# Loss RPN regression: 0.21268641856487375
# Loss Detector classifier: 0.25211531717716573
# Loss Detector regression: 0.1648934075422585
# Elapsed time: 6479.1905217170715
# Total loss decreased from 2.1527772084393058 to 1.9034527836537898, saving weights
# Training complete, exiting.
